# %% [markdown]
# ## Tobias Reaper
#
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 1*
#
# ---

# %% [markdown]
# # Define ML problems
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your decisions.
#
# - [ ] Choose your target. Which column in your tabular dataset will you predict?
# - [ ] Choose which observations you will use to train, validate, and test your model. And which observations, if any, to exclude.
# - [ ] Determine whether your problem is regression or classification.
# - [ ] Choose your evaluation metric.
# - [ ] Begin to clean and explore your data.
# - [ ] Begin to choose which features, if any, to exclude. Would some features "leak" information from the future?

# %% [markdown]
# ---
# ---

# %%
# Three musketeers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Extras
import pandas_profiling
import janitor
import os

# Plotly imports
import plotly.express as px
import plotly.figure_factory as ff

# %%
# Jupyter + Plotly imports (if running in Colab or Visual Studio Code, comment out the 3 lines below)
import plotly.offline as pyo
import plotly.graph_objs as go
pyo.init_notebook_mode()  # Set plotly to notebook mode / work offline

# %%
# the basix
import category_encoders as ce
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Ignore this Numpy warning when using Plotly Express:
# FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='numpy')

# %%
# Set pandas display options to allow for more columns and rows
pd.options.display.max_columns = 200
pd.options.display.max_rows = 200

# %% [markdown]
# ---
#
# ## 🔬👀 Explorations 🔭👀

# %%
# define directory path to the data
datapath = "../data/NSF_Awards"
filename = "2018-nsf_awards.csv"  # testing it out first with only one year - 2018
fullpath = os.path.join(datapath, filename)  # full filepath

print(fullpath)
# Out:
# ../data/NSF_Awards/2018-nsf_awards.csv

# %%
# Read in the csv and do initial cleanup with pyjanitor
df_0 = (pd
        .read_csv(fullpath)  # read the csv
        .clean_names()  # remove whitespace, punctuation, capitalization
#         .remove_empty()  # removes rows/cols that are completely empty
       )

# %%
print(df_0.shape)
df_0.head()
# Out:
# (12603, 45)
#                                     awardee  \
# 0     UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 1                  UNIVERSITY OF WASHINGTON
# 2                        CLEMSON UNIVERSITY
# 3  TEXAS A&M ENGINEERING EXPERIMENT STATION
# 4              UNIVERSITY OF PITTSBURGH THE
#
#                      doing_business_as_name           pd_pi_name  \
# 0      University of California-Los Angeles  Seth G Claudepierre
# 1                  University of Washington               Mo  Li
# 2                        Clemson University        Yongjia  Song
# 3  Texas A&M Engineering Experiment Station             Ya  Wang
# 4                  University of Pittsburgh       Masoud  Barati
#
#       pd_pi_phone                  pd_pi_email co_pd_s_co_pi_s_  \
# 0  (303) 641-2461  seth.claudepierre@gmail.com              NaN
# 1  (612) 638-8958                moli96@uw.edu              NaN
# 2  (864) 656-9832          yongjis@clemson.edu              NaN
# 3  (631) 632-8322     ya.s.wang@stonybrook.edu              NaN
# 4  (225) 578-1054              mbarati@lsu.edu              NaN
#
#       award_date estimated_total_award_amount funds_obligated_to_date  \
# 0  ="09/21/2018"                   ="$64,446"              ="$64,446"
# 1  ="09/21/2018"                  ="$149,665"             ="$149,665"
# 2  ="09/21/2018"                   ="$84,855"              ="$84,855"
# 3  ="09/21/2018"                  ="$500,000"             ="$500,000"
# 4  ="09/21/2018"                  ="$199,893"             ="$199,893"
#
#       start_date       end_date transaction_type agency awarding_agency_code  \
# 0  ="08/01/2018"  ="07/31/2019"            Grant    NSF              ="4900"
# 1  ="09/01/2018"  ="08/31/2020"            Grant    NSF              ="4900"
# 2  ="09/01/2018"  ="05/31/2019"            Grant    NSF              ="4900"
# 3  ="09/01/2018"  ="07/31/2023"            Grant    NSF              ="4900"
# 4  ="08/28/2018"  ="08/31/2020"            Grant    NSF              ="4900"
#
#   funding_agency_code cfda_number                 primary_program_source  \
# 0             ="4900"   ="47.050"  040100 NSF RESEARCH & RELATED ACTIVIT
# 1             ="4900"   ="47.041"  040100 NSF RESEARCH & RELATED ACTIVIT
# 2             ="4900"   ="47.041"  040100 NSF RESEARCH & RELATED ACTIVIT
# 3             ="4900"   ="47.041"  040100 NSF RESEARCH & RELATED ACTIVIT
# 4             ="4900"   ="47.041"  040100 NSF RESEARCH & RELATED ACTIVIT
#
#                           award_title_or_description federal_award_id_number  \
# 0  Collaborative Research:   GEM--The Effect of M...              ="1854440"
# 1  Collaborative Research:  Conformal and robust ...              ="1854974"
# 2  An Adaptive Partition-based Approach for Solvi...              ="1854960"
# 3  CAREER: Understanding Dynamics of Ultra-small ...              ="1851635"
# 4  Collaborative Research: A Global Algorithm for...              ="1851602"
#
#         duns_id parent_duns_id                         program  \
# 0  ="092530369"   ="071549000"          MAGNETOSPHERIC PHYSICS
# 1  ="605799469"   ="042803536"      COMMS, CIRCUITS & SENS SYS
# 2  ="042629816"   ="042629816"       OE Operations Engineering
# 3  ="847205572"   ="847205572"  Dynamics, Control and System D
# 4  ="004514360"   ="004514360"       ENERGY,POWER,ADAPTIVE SYS
#
#    program_officer_name program_officer_phone program_officer_email  \
# 0       Carrie E. Black        (703) 292-8519        cblack@nsf.gov
# 1  Shubhra Gangopadhyay        (703) 292-2485      sgangopa@nsf.gov
# 2    Georgia-Ann Klutke        (703) 292-8360      gaklutke@nsf.gov
# 3      Irina Dolinskaya        (703) 292-7078      idolinsk@nsf.gov
# 4            Anil Pahwa        (703) 292-2285        apahwa@nsf.gov
#
#                   awardee_street     awardee_city awardee_state awardee_zip  \
# 0       10889 Wilshire Boulevard      LOS ANGELES            CA  90095-1406
# 1           4333 Brooklyn Ave NE          Seattle            WA  98195-0001
# 2               230 Kappa Street          CLEMSON            SC  29634-5701
# 3  TEES State Headquarters Bldg.  College Station            TX  77845-4645
# 4                University Club       Pittsburgh            PA  15213-2303
#
#     awardee_county awardee_country awardee_cong_district  \
# 0      Los Angeles              US                 ="33"
# 1          Seattle              US                 ="07"
# 2              NaN              US                 ="03"
# 3  College Station              US                 ="17"
# 4       Pittsburgh              US                 ="14"
#
#               primary_organization_name    primary_street     primary_city  \
# 0  University of California-Los Angeles               NaN              NaN
# 1              University of Washington               NaN              NaN
# 2                    Clemson University  230 Kappa Street          Clemson
# 3                  Texas A&M University               NaN  College Station
# 4              University of Pittsburgh               NaN       Pittsburgh
#
#   primary_state primary_zip   primary_county primary_country  \
# 0            CA  90095-1406      Los Angeles              US
# 1            WA  98195-0001          Seattle              US
# 2            SC  29634-0001          Clemson              US
# 3            TX  77843-3578  College Station              US
# 4            PA  15213-2303       Pittsburgh              US
#
#   primary_cong_district                          abstract_at_time_of_award  \
# 0                 ="33"  This project aims to address the electromagnet...
# 1                 ="07"  The program aims to pioneer a flexible optical...
# 2                 ="03"  Stochastic programs are popular models for pro...
# 3                 ="17"  This Faculty Early Career Development Program ...
# 4                 ="14"  Non-convex programming involves optimization p...
#
#   publications_produced_as_a_result_of_this_research  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    publications_produced_as_conference_proceedings projectoutcomesreport  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
#
#    unnamed_44
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
def wrangle(data):
    """Another one o' dem virtual lassoooos."""
    
    # Prevent the slice/copy warning
    data = data.copy()

    # Columns with the same mistake: ="value"
    
    cols_to_date = [  # to be converted to date
        "award_date",
        "start_date",
        "end_date",
    ]

    cols_to_int = [  # to be converted to integer
        "estimated_total_award_amount",
        "funds_obligated_to_date",
        "awarding_agency_code",
        "funding_agency_code",
        "cfda_number",
        "federal_award_id_number",
        "duns_id",
        "parent_duns_id",
        "awardee_cong_district",
        "primary_cong_district",
    ]

    for col in cols_to_date + cols_to_int:
        data[col] = data[col].str.strip(to_strip='="$')
        data[col] = data[col].str.replace(".", "")
        data[col] = data[col].str.replace(",", "")
        
    # Convert date columns to datetime
    for col in cols_to_date:
        data[col] = pd.to_datetime(data[col], infer_datetime_format=True)
        
    return data

# %%
# Apply above wranglemations to the dataframe
df_1 = wrangle(df_0)

# %%
df_1.head()
# Out:
#                                     awardee  \
# 0     UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 1                  UNIVERSITY OF WASHINGTON
# 2                        CLEMSON UNIVERSITY
# 3  TEXAS A&M ENGINEERING EXPERIMENT STATION
# 4              UNIVERSITY OF PITTSBURGH THE
#
#                      doing_business_as_name           pd_pi_name  \
# 0      University of California-Los Angeles  Seth G Claudepierre
# 1                  University of Washington               Mo  Li
# 2                        Clemson University        Yongjia  Song
# 3  Texas A&M Engineering Experiment Station             Ya  Wang
# 4                  University of Pittsburgh       Masoud  Barati
#
#       pd_pi_phone                  pd_pi_email co_pd_s_co_pi_s_ award_date  \
# 0  (303) 641-2461  seth.claudepierre@gmail.com              NaN 2018-09-21
# 1  (612) 638-8958                moli96@uw.edu              NaN 2018-09-21
# 2  (864) 656-9832          yongjis@clemson.edu              NaN 2018-09-21
# 3  (631) 632-8322     ya.s.wang@stonybrook.edu              NaN 2018-09-21
# 4  (225) 578-1054              mbarati@lsu.edu              NaN 2018-09-21
#
#   estimated_total_award_amount funds_obligated_to_date start_date   end_date  \
# 0                        64446                   64446 2018-08-01 2019-07-31
# 1                       149665                  149665 2018-09-01 2020-08-31
# 2                        84855                   84855 2018-09-01 2019-05-31
# 3                       500000                  500000 2018-09-01 2023-07-31
# 4                       199893                  199893 2018-08-28 2020-08-31
#
#   transaction_type agency awarding_agency_code funding_agency_code  \
# 0            Grant    NSF                 4900                4900
# 1            Grant    NSF                 4900                4900
# 2            Grant    NSF                 4900                4900
# 3            Grant    NSF                 4900                4900
# 4            Grant    NSF                 4900                4900
#
#   cfda_number                 primary_program_source  \
# 0       47050  040100 NSF RESEARCH & RELATED ACTIVIT
# 1       47041  040100 NSF RESEARCH & RELATED ACTIVIT
# 2       47041  040100 NSF RESEARCH & RELATED ACTIVIT
# 3       47041  040100 NSF RESEARCH & RELATED ACTIVIT
# 4       47041  040100 NSF RESEARCH & RELATED ACTIVIT
#
#                           award_title_or_description federal_award_id_number  \
# 0  Collaborative Research:   GEM--The Effect of M...                 1854440
# 1  Collaborative Research:  Conformal and robust ...                 1854974
# 2  An Adaptive Partition-based Approach for Solvi...                 1854960
# 3  CAREER: Understanding Dynamics of Ultra-small ...                 1851635
# 4  Collaborative Research: A Global Algorithm for...                 1851602
#
#      duns_id parent_duns_id                         program  \
# 0  092530369      071549000          MAGNETOSPHERIC PHYSICS
# 1  605799469      042803536      COMMS, CIRCUITS & SENS SYS
# 2  042629816      042629816       OE Operations Engineering
# 3  847205572      847205572  Dynamics, Control and System D
# 4  004514360      004514360       ENERGY,POWER,ADAPTIVE SYS
#
#    program_officer_name program_officer_phone program_officer_email  \
# 0       Carrie E. Black        (703) 292-8519        cblack@nsf.gov
# 1  Shubhra Gangopadhyay        (703) 292-2485      sgangopa@nsf.gov
# 2    Georgia-Ann Klutke        (703) 292-8360      gaklutke@nsf.gov
# 3      Irina Dolinskaya        (703) 292-7078      idolinsk@nsf.gov
# 4            Anil Pahwa        (703) 292-2285        apahwa@nsf.gov
#
#                   awardee_street     awardee_city awardee_state awardee_zip  \
# 0       10889 Wilshire Boulevard      LOS ANGELES            CA  90095-1406
# 1           4333 Brooklyn Ave NE          Seattle            WA  98195-0001
# 2               230 Kappa Street          CLEMSON            SC  29634-5701
# 3  TEES State Headquarters Bldg.  College Station            TX  77845-4645
# 4                University Club       Pittsburgh            PA  15213-2303
#
#     awardee_county awardee_country awardee_cong_district  \
# 0      Los Angeles              US                    33
# 1          Seattle              US                    07
# 2              NaN              US                    03
# 3  College Station              US                    17
# 4       Pittsburgh              US                    14
#
#               primary_organization_name    primary_street     primary_city  \
# 0  University of California-Los Angeles               NaN              NaN
# 1              University of Washington               NaN              NaN
# 2                    Clemson University  230 Kappa Street          Clemson
# 3                  Texas A&M University               NaN  College Station
# 4              University of Pittsburgh               NaN       Pittsburgh
#
#   primary_state primary_zip   primary_county primary_country  \
# 0            CA  90095-1406      Los Angeles              US
# 1            WA  98195-0001          Seattle              US
# 2            SC  29634-0001          Clemson              US
# 3            TX  77843-3578  College Station              US
# 4            PA  15213-2303       Pittsburgh              US
#
#   primary_cong_district                          abstract_at_time_of_award  \
# 0                    33  This project aims to address the electromagnet...
# 1                    07  The program aims to pioneer a flexible optical...
# 2                    03  Stochastic programs are popular models for pro...
# 3                    17  This Faculty Early Career Development Program ...
# 4                    14  Non-convex programming involves optimization p...
#
#   publications_produced_as_a_result_of_this_research  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    publications_produced_as_conference_proceedings projectoutcomesreport  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
#
#    unnamed_44
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_1.dtypes

# %%
def wrangle_ints(data):
    """Another one o' dem virtual lassoooos."""
    
    # Prevent the slice/copy warning
    data = data.copy()

    cols_to_int = [  # to be converted to integer
        "estimated_total_award_amount",
        "funds_obligated_to_date",
    ]

    # Convert columns to integer
    for col in cols_to_int:
        data[col] = data[col].astype(int)
        
    return data

# %%
df_2 = wrangle_ints(df_1)

# %%
df_2.head()
# Out:
#                                     awardee  \
# 0     UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 1                  UNIVERSITY OF WASHINGTON
# 2                        CLEMSON UNIVERSITY
# 3  TEXAS A&M ENGINEERING EXPERIMENT STATION
# 4              UNIVERSITY OF PITTSBURGH THE
#
#                      doing_business_as_name           pd_pi_name  \
# 0      University of California-Los Angeles  Seth G Claudepierre
# 1                  University of Washington               Mo  Li
# 2                        Clemson University        Yongjia  Song
# 3  Texas A&M Engineering Experiment Station             Ya  Wang
# 4                  University of Pittsburgh       Masoud  Barati
#
#       pd_pi_phone                  pd_pi_email co_pd_s_co_pi_s_ award_date  \
# 0  (303) 641-2461  seth.claudepierre@gmail.com              NaN 2018-09-21
# 1  (612) 638-8958                moli96@uw.edu              NaN 2018-09-21
# 2  (864) 656-9832          yongjis@clemson.edu              NaN 2018-09-21
# 3  (631) 632-8322     ya.s.wang@stonybrook.edu              NaN 2018-09-21
# 4  (225) 578-1054              mbarati@lsu.edu              NaN 2018-09-21
#
#    estimated_total_award_amount  funds_obligated_to_date start_date  \
# 0                         64446                    64446 2018-08-01
# 1                        149665                   149665 2018-09-01
# 2                         84855                    84855 2018-09-01
# 3                        500000                   500000 2018-09-01
# 4                        199893                   199893 2018-08-28
#
#     end_date transaction_type agency awarding_agency_code funding_agency_code  \
# 0 2019-07-31            Grant    NSF                 4900                4900
# 1 2020-08-31            Grant    NSF                 4900                4900
# 2 2019-05-31            Grant    NSF                 4900                4900
# 3 2023-07-31            Grant    NSF                 4900                4900
# 4 2020-08-31            Grant    NSF                 4900                4900
#
#   cfda_number                 primary_program_source  \
# 0       47050  040100 NSF RESEARCH & RELATED ACTIVIT
# 1       47041  040100 NSF RESEARCH & RELATED ACTIVIT
# 2       47041  040100 NSF RESEARCH & RELATED ACTIVIT
# 3       47041  040100 NSF RESEARCH & RELATED ACTIVIT
# 4       47041  040100 NSF RESEARCH & RELATED ACTIVIT
#
#                           award_title_or_description federal_award_id_number  \
# 0  Collaborative Research:   GEM--The Effect of M...                 1854440
# 1  Collaborative Research:  Conformal and robust ...                 1854974
# 2  An Adaptive Partition-based Approach for Solvi...                 1854960
# 3  CAREER: Understanding Dynamics of Ultra-small ...                 1851635
# 4  Collaborative Research: A Global Algorithm for...                 1851602
#
#      duns_id parent_duns_id                         program  \
# 0  092530369      071549000          MAGNETOSPHERIC PHYSICS
# 1  605799469      042803536      COMMS, CIRCUITS & SENS SYS
# 2  042629816      042629816       OE Operations Engineering
# 3  847205572      847205572  Dynamics, Control and System D
# 4  004514360      004514360       ENERGY,POWER,ADAPTIVE SYS
#
#    program_officer_name program_officer_phone program_officer_email  \
# 0       Carrie E. Black        (703) 292-8519        cblack@nsf.gov
# 1  Shubhra Gangopadhyay        (703) 292-2485      sgangopa@nsf.gov
# 2    Georgia-Ann Klutke        (703) 292-8360      gaklutke@nsf.gov
# 3      Irina Dolinskaya        (703) 292-7078      idolinsk@nsf.gov
# 4            Anil Pahwa        (703) 292-2285        apahwa@nsf.gov
#
#                   awardee_street     awardee_city awardee_state awardee_zip  \
# 0       10889 Wilshire Boulevard      LOS ANGELES            CA  90095-1406
# 1           4333 Brooklyn Ave NE          Seattle            WA  98195-0001
# 2               230 Kappa Street          CLEMSON            SC  29634-5701
# 3  TEES State Headquarters Bldg.  College Station            TX  77845-4645
# 4                University Club       Pittsburgh            PA  15213-2303
#
#     awardee_county awardee_country awardee_cong_district  \
# 0      Los Angeles              US                    33
# 1          Seattle              US                    07
# 2              NaN              US                    03
# 3  College Station              US                    17
# 4       Pittsburgh              US                    14
#
#               primary_organization_name    primary_street     primary_city  \
# 0  University of California-Los Angeles               NaN              NaN
# 1              University of Washington               NaN              NaN
# 2                    Clemson University  230 Kappa Street          Clemson
# 3                  Texas A&M University               NaN  College Station
# 4              University of Pittsburgh               NaN       Pittsburgh
#
#   primary_state primary_zip   primary_county primary_country  \
# 0            CA  90095-1406      Los Angeles              US
# 1            WA  98195-0001          Seattle              US
# 2            SC  29634-0001          Clemson              US
# 3            TX  77843-3578  College Station              US
# 4            PA  15213-2303       Pittsburgh              US
#
#   primary_cong_district                          abstract_at_time_of_award  \
# 0                    33  This project aims to address the electromagnet...
# 1                    07  The program aims to pioneer a flexible optical...
# 2                    03  Stochastic programs are popular models for pro...
# 3                    17  This Faculty Early Career Development Program ...
# 4                    14  Non-convex programming involves optimization p...
#
#   publications_produced_as_a_result_of_this_research  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    publications_produced_as_conference_proceedings projectoutcomesreport  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
#
#    unnamed_44
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_2.isnull().sum()

# %%
def drop_cols(data):
    """Another one o' dem virtual lassoooos."""
    
    # Prevent the slice/copy warning
    data = data.copy()

    cols_to_keep = [  # to be converted to integer
        "doing_business_as_name",
        "award_date",
        "estimated_total_award_amount",
        "funds_obligated_to_date",
        "start_date",
        "end_date",
        "transaction_type",
        "agency",
        "cfda_number",
        "primary_program_source",
        "award_title_or_description",
        "federal_award_id_number",
        "program",
        "awardee_city",
        "awardee_state",
        "awardee_zip",
        "awardee_county",
        "awardee_country",
        "awardee_cong_district",
        "abstract_at_time_of_award",
    ]

    data = data[cols_to_keep]
        
    return data

# %%
df_3 = drop_cols(df_2)

# %%
df_3.head()
# Out:
#                      doing_business_as_name award_date  \
# 0      University of California-Los Angeles 2018-09-21
# 1                  University of Washington 2018-09-21
# 2                        Clemson University 2018-09-21
# 3  Texas A&M Engineering Experiment Station 2018-09-21
# 4                  University of Pittsburgh 2018-09-21
#
#    estimated_total_award_amount  funds_obligated_to_date start_date  \
# 0                         64446                    64446 2018-08-01
# 1                        149665                   149665 2018-09-01
# 2                         84855                    84855 2018-09-01
# 3                        500000                   500000 2018-09-01
# 4                        199893                   199893 2018-08-28
#
#     end_date transaction_type agency cfda_number  \
# 0 2019-07-31            Grant    NSF       47050
# 1 2020-08-31            Grant    NSF       47041
# 2 2019-05-31            Grant    NSF       47041
# 3 2023-07-31            Grant    NSF       47041
# 4 2020-08-31            Grant    NSF       47041
#
#                   primary_program_source  \
# 0  040100 NSF RESEARCH & RELATED ACTIVIT
# 1  040100 NSF RESEARCH & RELATED ACTIVIT
# 2  040100 NSF RESEARCH & RELATED ACTIVIT
# 3  040100 NSF RESEARCH & RELATED ACTIVIT
# 4  040100 NSF RESEARCH & RELATED ACTIVIT
#
#                           award_title_or_description federal_award_id_number  \
# 0  Collaborative Research:   GEM--The Effect of M...                 1854440
# 1  Collaborative Research:  Conformal and robust ...                 1854974
# 2  An Adaptive Partition-based Approach for Solvi...                 1854960
# 3  CAREER: Understanding Dynamics of Ultra-small ...                 1851635
# 4  Collaborative Research: A Global Algorithm for...                 1851602
#
#                           program     awardee_city awardee_state awardee_zip  \
# 0          MAGNETOSPHERIC PHYSICS      LOS ANGELES            CA  90095-1406
# 1      COMMS, CIRCUITS & SENS SYS          Seattle            WA  98195-0001
# 2       OE Operations Engineering          CLEMSON            SC  29634-5701
# 3  Dynamics, Control and System D  College Station            TX  77845-4645
# 4       ENERGY,POWER,ADAPTIVE SYS       Pittsburgh            PA  15213-2303
#
#     awardee_county awardee_country awardee_cong_district  \
# 0      Los Angeles              US                    33
# 1          Seattle              US                    07
# 2              NaN              US                    03
# 3  College Station              US                    17
# 4       Pittsburgh              US                    14
#
#                            abstract_at_time_of_award
# 0  This project aims to address the electromagnet...
# 1  The program aims to pioneer a flexible optical...
# 2  Stochastic programs are popular models for pro...
# 3  This Faculty Early Career Development Program ...
# 4  Non-convex programming involves optimization p...

# %%
# Check out non-numeric columns
df_3.select_dtypes(exclude='number').describe().T.sort_values(by='unique')
# Out:
#                             count unique  \
# agency                      12603      1
# transaction_type            12603      2
# primary_program_source      12603      4
# awardee_country             12603      6
# cfda_number                 12603      9
# awardee_cong_district       12586     53
# awardee_state               12588     53
# end_date                    12603     79
# start_date                  12603    169
# award_date                  12603    265
# program                     12603    394
# awardee_county              12077    690
# awardee_city                12603    810
# awardee_zip                 12589   1570
# doing_business_as_name      12603   1586
# abstract_at_time_of_award   12603  10821
# award_title_or_description  12603  10859
# federal_award_id_number     12603  12603
#
#                                                                           top  \
# agency                                                                    NSF
# transaction_type                                                        Grant
# primary_program_source                  040100 NSF RESEARCH & RELATED ACTIVIT
# awardee_country                                                            US
# cfda_number                                                             47049
# awardee_cong_district                                                      02
# awardee_state                                                              CA
# end_date                                                  2021-08-31 00:00:00
# start_date                                                2018-09-01 00:00:00
# award_date                                                2018-08-07 00:00:00
# program                                        Secure &Trustworthy Cyberspace
# awardee_county                                                       New York
# awardee_city                                                        Cambridge
# awardee_zip                                                        48109-1274
# doing_business_as_name                       University of Michigan Ann Arbor
# abstract_at_time_of_award   The National Science Foundation (NSF) Graduate...
# award_title_or_description     NSF Postdoctoral Fellowship in Biology FY 2018
# federal_award_id_number                                               1753761
#
#                              freq      first       last
# agency                      12603        NaT        NaT
# transaction_type            12504        NaT        NaT
# primary_program_source      11461        NaT        NaT
# awardee_country             12588        NaT        NaT
# cfda_number                  2751        NaT        NaT
# awardee_cong_district        1584        NaT        NaT
# awardee_state                1602        NaT        NaT
# end_date                     1635 2018-01-31 2024-08-31
# start_date                   2373 2014-06-30 2019-08-01
# award_date                    194 2017-10-12 2018-09-21
# program                       258        NaT        NaT
# awardee_county                333        NaT        NaT
# awardee_city                  274        NaT        NaT
# awardee_zip                   196        NaT        NaT
# doing_business_as_name        196        NaT        NaT
# abstract_at_time_of_award      35        NaT        NaT
# award_title_or_description     40        NaT        NaT
# federal_award_id_number         1        NaT        NaT

# %%
df_3.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f22b151f5682> in <module>
# ----> 1 df_3.describe()
#
# NameError: name 'df_3' is not defined

# %%
# define the target
target = "estimated_total_award_amount"

# %%
X = df_3.drop(columns=[target, "funds_obligated_to_date"])
