# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas_profiling

# %%
df = pd.read_csv('Documents/Police Project/Stop - Basic Details/ripa_stops_datasd.csv')
df.head()
# Out:
# //anaconda3/envs/unit2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    stop_id        ori agency  exp_years    stopdate  stoptime  stopduration  \
# 0     2443  CA0371100     SD         10  2018-07-01  00:01:37            30
# 1     2444  CA0371100     SD         18  2018-07-01  00:03:34            10
# 2     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 3     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 4     2448  CA0371100     SD          3  2018-07-01  00:19:06             5
#
#    stop_in_response_to_cfs  officer_assignment_key  \
# 0                        0                       1
# 1                        0                       1
# 2                        1                      10
# ...

# %%
pandas_profiling.ProfileReport(df)
# Out:
# //anaconda3/envs/unit2/lib/python3.7/site-packages/pandas_profiling/model/correlations.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
# //anaconda3/envs/unit2/lib/python3.7/site-packages/pandas_profiling/model/correlations.py:124: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'No data; `observed` has size 0.')
#   correlation_name=correlation_name, error=error
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
# ...

# %%
cols = df.columns.tolist()
cols
# Out:
# ['stop_id',
#  'ori',
#  'agency',
#  'exp_years',
#  'stopdate',
#  'stoptime',
#  'stopduration',
#  'stop_in_response_to_cfs',
#  'officer_assignment_key',
#  'assignment',
#  'intersection',
#  'block',
#  'land_mark',
#  'street',
#  'highway_exit',
#  'isschool',
#  'school_name',
#  'cityname',
#  'beat',
#  'beat_name',
#  'pid',
#  'isstudent',
#  'perceived_limited_english',
#  'perceived_age',
#  'perceived_gender',
#  'gender_nonconforming',
#  'gend',
#  'gend_nc',
#  'perceived_lgbt']

# %%
df.cityname.value_counts()
# Out:
# SAN DIEGO                               176659
# SAN YSIDRO                                1066
# CHULA VISTA                                351
# NATIONAL CITY                              292
# LEMON GROVE                                278
# EL CAJON                                   171
# LA JOLLA                                   148
# SANTEE                                     146
# LA MESA                                    106
# ESCONDIDO                                  103
# SPRING VALLEY                               72
# SAN MARCOS                                  59
# FALLBROOK                                   54
# IMPERIAL BEACH                              43
# LAKESIDE                                    32
# SAN DIMAS                                   22
# TEMECULA                                    17
# SAN LUIS REY                                15
# POWAY                                       15
# BONITA                                      15
# ...

# %%
df.shape
# Out:
# (179725, 29)

# %%
# dropping columns for missing values, constant values, etc.
df = df.drop(['agency', 'ori', 'block', 'gend_nc', 
         'highway_exit', 'intersection', 'land_mark',
         'school_name', 'street', 'gender_nonconforming', 
              'pid', 'beat'], axis=1)
df.shape
# Out:
# (179725, 17)

# %%
df2 = pd.read_csv('Documents/Police Project/Stop - Reason for stop/ripa_stop_reason_datasd.csv')
df2.head()
# Out:
# //anaconda3/envs/unit2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    stop_id  pid       reason_for_stop reason_for_stopcode  \
# 0     2443    1  Reasonable Suspicion               64005
# 1     2444    1     Traffic Violation               54106
# 2     2447    1  Reasonable Suspicion               53072
# 3     2447    2  Reasonable Suspicion               53072
# 4     2448    1     Traffic Violation               54106
#
#                         reason_for_stop_code_text  \
# 0    647(F) PC - DISORD CONDUCT:ALCOHOL (M) 64005
# 1  22350 VC - UNSAFE SPEED:PREVAIL COND (I) 54106
# 2     415(1) PC - FIGHT IN PUBLIC PLACE (M) 53072
# 3     415(1) PC - FIGHT IN PUBLIC PLACE (M) 53072
# 4  22350 VC - UNSAFE SPEED:PREVAIL COND (I) 54106
#
# ...

# %%
df.shape,df2.shape
# Out:
# ((179725, 17), (185074, 7))

# %%
df3 = pd.merge(df, df2, how='inner')

df3.shape
# Out:
# (262545, 23)

# %%
df4 = pd.read_csv('Documents/Police Project/Stop - Race/ripa_race_datasd.csv')
df5 = pd.read_csv('Documents/Police Project/Stop - Result/ripa_stop_result_datasd.csv')
df6 = pd.read_csv('Documents/Police Project/Stop - Actions Taken/ripa_actions_taken_datasd.csv')

df4.shape, df5.shape, df6.shape
# Out:
# ((181678, 3), (194689, 6), (270402, 4))

# %%
df6.head()
# Out:
#    stop_id  pid              action consented
# 0     2443    1                None       NaN
# 1     2444    1                None       NaN
# 2     2447    1  Curbside detention       NaN
# 3     2447    2  Curbside detention       NaN
# 4     2448    1                None       NaN

# %%
df6.action.value_counts()
# Out:
# None                                                    115352
# Handcuffed or flex cuffed                                44767
# Search of person was conducted                           32417
# Curbside detention                                       20899
# Search of property was conducted                         15497
# Patrol car detention                                     13539
# Person removed from vehicle by order                      7201
# Asked for consent to search person                        4359
# Property was seized                                       3930
# Asked for consent to search property                      2578
# Person photographed                                       2237
# Physical or Vehicle contact                               2144
# Field sobriety test conducted                             2088
# Vehicle impounded                                         1796
# Firearm pointed at person                                  646
# ...

# %%
df5.head()
# Out:
#    stop_id  pid  resultkey                            result     code  \
# 0     2443    1          6  Custodial Arrest without warrant  64005.0
# 1     2444    1          2       Warning (verbal or written)  54395.0
# 2     2447    1          1                         No Action      NaN
# 3     2447    2          1                         No Action      NaN
# 4     2448    1          1                         No Action      NaN
#
#                                           resulttext
# 0       647(F) PC - DISORD CONDUCT:ALCOHOL (M) 64005
# 1  22349(B) VC - EXC 55MPH SPEED:2 LANE RD (I) 54395
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df5.result.value_counts()
# Out:
# Field interview card completed                                               41683
# Citation for infraction                                                      41029
# Warning (verbal or written)                                                  30400
# No Action                                                                    25002
# Custodial Arrest without warrant                                             21210
# In-field cite and release                                                    17237
# Custodial Arrest pursuant to outstanding warrant                              7465
# Psychiatric hold                                                              7026
# Noncriminal transport or caretaking transport                                 3012
# Contacted parent/legal guardian or other person responsible for the minor      574
# Referral to school administrator                                                25
# ...

# %%
df4.shape, df5.shape, df6.shape
# Out:
# ((181678, 3), (194689, 6), (270402, 4))

# %%
df3.shape
# Out:
# (262545, 23)

# %%
df7 = pd.merge(df4, df5, how='inner')
df7.shape
# Out:
# (196894, 7)

# %%
df_semifinal = pd.merge(df6, df7, how='inner')
df_semifinal.shape
# Out:
# (305174, 9)

# %%
df_merged = pd.merge(df3, df_semifinal, how='inner')
print(df_merged.shape)
df_merged.head()
# Out:
# (441897, 30)
#    stop_id  exp_years    stopdate  stoptime  stopduration  \
# 0     2443         10  2018-07-01  00:01:37            30
# 1     2444         18  2018-07-01  00:03:34            10
# 2     2447          1  2018-07-01  00:05:43            15
# 3     2447          1  2018-07-01  00:05:43            15
# 4     2447          1  2018-07-01  00:05:43            15
#
#    stop_in_response_to_cfs  officer_assignment_key  \
# 0                        0                       1
# 1                        0                       1
# 2                        1                      10
# 3                        1                      10
# 4                        1                      10
#
#                                       assignment  isschool   cityname  ...  \
# 0  Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# 1  Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# ...

# %%
# Will need to drop 'consented'. Not because consent isn't important, 
# but for a citation, consent isn't necessary. It also has several NaN values
# Will revisit if it needs to be addressed
mask = (df_merged['result'] == 'Citation for infraction')
print(df_merged[mask].shape)
df_merged[mask].head()
# Out:
# (67602, 30)
#      stop_id  exp_years    stopdate  stoptime  stopduration  \
# 27      2462          1  2018-07-01  01:03:00            15
# 35      2473          2  2018-07-01  01:52:51            12
# 106     2512          1  2018-07-01  05:00:49            20
# 108     2514         10  2018-07-01  05:29:26            15
# 122     2520          1  2018-07-01  05:42:21            83
#
#      stop_in_response_to_cfs  officer_assignment_key  \
# 27                         0                       1
# 35                         0                       1
# 106                        0                       1
# 108                        0                       1
# 122                        0                       1
#
#                                         assignment  isschool   cityname  ...  \
# 27   Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# 35   Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# ...

# %%
test = df_merged[mask]
test.head()
# Out:
#      stop_id  exp_years    stopdate  stoptime  stopduration  \
# 27      2462          1  2018-07-01  01:03:00            15
# 35      2473          2  2018-07-01  01:52:51            12
# 106     2512          1  2018-07-01  05:00:49            20
# 108     2514         10  2018-07-01  05:29:26            15
# 122     2520          1  2018-07-01  05:42:21            83
#
#      stop_in_response_to_cfs  officer_assignment_key  \
# 27                         0                       1
# 35                         0                       1
# 106                        0                       1
# 108                        0                       1
# 122                        0                       1
#
#                                         assignment  isschool   cityname  ...  \
# 27   Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# 35   Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# ...

# %%
# df_merged['result'] == 'Warning (verbal or written)'
# df_merged['result'] == 'No Action'
# df_merged['result'] == 'Field interview card completed'
# df[df.result.isin(list)]
mask = (df_merged['result'] == 'Citation for infraction')
print(df_merged[mask].shape)
df_merged[mask].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-32487de56816> in <module>
#       2 # df_merged['result'] == 'No Action'
#       3 # df_merged['result'] == 'Field interview card completed'
# ----> 4 df[df.result.isin(list)]
#       5 mask = (df_merged['result'] == 'Citation for infraction')
#       6 print(df_merged[mask].shape)
#
# //anaconda3/envs/unit2/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'result'

# %%
list = ['No Action','Warning (verbal or written)', 'Field interview card completed', 'Citation for infraction']
test = df_merged[df_merged.result.isin(list)]
test.shape
# Out:
# (263252, 30)

# %%
test.result.value_counts()
# Out:
# Field interview card completed    101420
# Citation for infraction            67602
# Warning (verbal or written)        48370
# No Action                          45860
# Name: result, dtype: int64

# %%
df_compressed = df_merged[df_merged.result.isin(list)]
df_compressed.shape
# Out:
# (263252, 30)

# %%
df_compressed.head()
# Out:
#    stop_id  exp_years    stopdate  stoptime  stopduration  \
# 1     2444         18  2018-07-01  00:03:34            10
# 2     2447          1  2018-07-01  00:05:43            15
# 3     2447          1  2018-07-01  00:05:43            15
# 4     2447          1  2018-07-01  00:05:43            15
# 5     2447          1  2018-07-01  00:05:43            15
#
#    stop_in_response_to_cfs  officer_assignment_key  \
# 1                        0                       1
# 2                        1                      10
# 3                        1                      10
# 4                        1                      10
# 5                        1                      10
#
#                                       assignment  isschool   cityname  ...  \
# 1  Patrol, traffic enforcement, field operations         0  SAN DIEGO  ...
# 2                                          Other         0  SAN DIEGO  ...
# 3                                          Other         0  SAN DIEGO  ...
# ...

# %%
# df_compressed.stoptime = pd.to_datetime(df_compressed.stoptime, infer_datetime_format=True)
df_compressed.stoptime.describe()
# Out:
# count       263252
# unique       50340
# top       18:57:10
# freq          1602
# Name: stoptime, dtype: object

# %%
df_compressed.stopdate = pd.to_datetime(df_compressed.stopdate)
df_compressed.stopdate.describe()
# Out:
# count                  263252
# unique                    365
# top       2019-06-13 00:00:00
# freq                     2511
# first     2018-07-01 00:00:00
# last      2019-06-30 00:00:00
# Name: stopdate, dtype: object

# %%
# Engineering month, year features
df_compressed['month'] = df_compressed.stopdate.dt.month
df_compressed['year'] = df_compressed.stopdate.dt.year

df_compressed.head()
# Out:
# //anaconda3/envs/unit2/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# //anaconda3/envs/unit2/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    stop_id  exp_years   stopdate  stoptime  stopduration  \
# 1     2444         18 2018-07-01  00:03:34            10
# 2     2447          1 2018-07-01  00:05:43            15
# ...

# %%
# get features and target

target = 'result'

features = df_compressed.columns.drop('result')

# %%
features
# Out:
# Index(['stop_id', 'exp_years', 'stopdate', 'stoptime', 'stopduration',
#        'stop_in_response_to_cfs', 'officer_assignment_key', 'assignment',
#        'isschool', 'cityname', 'beat_name', 'isstudent',
#        'perceived_limited_english', 'perceived_age', 'perceived_gender',
#        'gend', 'perceived_lgbt', 'pid', 'reason_for_stop',
#        'reason_for_stopcode', 'reason_for_stop_code_text',
#        'reason_for_stop_detail', 'reason_for_stop_explanation', 'action',
#        'consented', 'race', 'resultkey', 'code', 'resulttext', 'month',
#        'year'],
#       dtype='object')

# %%
df_compressed.shape
# Out:
# (263252, 32)

# %%
train = df_compressed
train.shape
# Out:
# (263252, 32)

# %%
from sklearn.model_selection import train_test_split

# Split train into train & test, then will split train again into train and val
train, test = train_test_split(train, train_size=0.80, test_size=0.20, 
                              stratify=train[target], random_state=42)
train.shape, test.shape
# Out:
# ((210601, 32), (52651, 32))

# %%
# Split train into train & val
train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              stratify=train['result'], random_state=42)
train.shape,val.shape,test.shape
# Out:
# ((168480, 32), (42121, 32), (52651, 32))

# %%
# Arrange data into X features matrix and y target vector
target = 'result'
X_train = train.drop(columns=target)
y_train = train[target]
X_val = val.drop(columns=target)
y_val = val[target]
X_test = test
y_test = test[target]
# Check shapes
print('X_train shape', X_train.shape)
print('y_train shape', y_train.shape)
print('X_val shape', X_val.shape)
print('y_val shape', y_val.shape)
print('X_test shape', X_test.shape)
print('y_test shape', y_test.shape)
# Out:
# X_train shape (168480, 31)
# y_train shape (168480,)
# X_val shape (42121, 31)
# y_val shape (42121,)
# X_test shape (52651, 32)
# y_test shape (52651,)

# %% [markdown]
# # Get accuracy score for majority baseline

# %%
# Get accuracy score for majority class baseline
y_train.value_counts(normalize=True)
# Out:
# Field interview card completed    0.385256
# Citation for infraction           0.256796
# Warning (verbal or written)       0.183743
# No Action                         0.174205
# Name: result, dtype: float64

# %%
import numpy as np
from sklearn.metrics import accuracy_score

majority_class = y_train.mode()[0]
y_pred = np.full_like(y_val, fill_value=majority_class)
accuracy_score(y_val, y_pred)
# Out:
# 0.3852710049618955

# %%
train.isnull().sum()
# Out:
# stop_id                             0
# exp_years                           0
# stopdate                            0
# stoptime                            0
# stopduration                        0
# stop_in_response_to_cfs             0
# officer_assignment_key              0
# assignment                          0
# isschool                            0
# cityname                            0
# beat_name                           0
# isstudent                           0
# perceived_limited_english           0
# perceived_age                       0
# perceived_gender                   58
# gend                                0
# perceived_lgbt                      0
# pid                                 0
# reason_for_stop                     0
# reason_for_stopcode             10373
# reason_for_stop_code_text       10373
# reason_for_stop_detail          10372
# reason_for_stop_explanation         0
# action                              0
# consented                      163442
# ...

# %%
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
#     SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)
)

pipeline.fit(X_train, y_train);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-48adae2de8e1> in <module>
#      10 )
#      11
# ---> 12 pipeline.fit(X_train, y_train);
#
# //anaconda3/envs/unit2/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     354                                  self._log_message(len(self.steps) - 1)):
#     355             if self._final_estimator != 'passthrough':
# --> 356                 self._final_estimator.fit(Xt, y, **fit_params)
#     357         return self
#     358
#
# //anaconda3/envs/unit2/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
# ...
