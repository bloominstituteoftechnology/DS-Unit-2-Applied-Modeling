# %% [markdown]
# # Hospital Inpatient Discharges (SPARCS De-identified): 2017
# Source: New York State Health Department
# https://health.data.ny.gov/dataset/Hospital-Inpatient-Discharges-SPARCS-De-Identified/22g3-z7e7

# %% [markdown]
# Goal is to predict Risk of Mortality to better inform treatment, aggresivness of approach, expectations of family...

# %%
import pandas as pd
import numpy as np

# %%
# Using Hospital Inpatient Discharge information for the State of New York from 2017

df= pd.read_csv('Hospital_Inpatient_Discharges__SPARCS_De-Identified___2017.csv', low_memory= False)

# %%
print(df.shape)
df.head()
# Out:
# (2343569, 34)
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5903001.0
# 1         Hudson Valley     Westchester                     5903001.0
# 2         Hudson Valley     Westchester                     5903001.0
# 3         Hudson Valley     Westchester                     5903001.0
# 4         Hudson Valley     Westchester                     5903001.0
#
#    Permanent Facility Id                     Facility Name Age Group  \
# 0                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 1                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
# 2                 1061.0  Montefiore Mount Vernon Hospital  30 to 49
# 3                 1061.0  Montefiore Mount Vernon Hospital  50 to 69
# 4                 1061.0  Montefiore Mount Vernon Hospital  18 to 29
#
#   Zip Code - 3 digits Gender   Race          Ethnicity Length of Stay  \
# 0                 NaN      M  White  Not Span/Hispanic             21
# 1                 105      M  White   Spanish/Hispanic              8
# 2                 105      F  White            Unknown              6
# 3                 105      F  White  Not Span/Hispanic              4
# 4                 105      F  White   Spanish/Hispanic              4
#
#   Type of Admission  ... APR Severity of Illness Code  \
# 0          Elective  ...                            2
# 1         Emergency  ...                            3
# 2         Emergency  ...                            2
# 3         Emergency  ...                            2
# 4         Emergency  ...                            2
#
#    APR Severity of Illness Description  APR Risk of Mortality  \
# 0                             Moderate                  Minor
# 1                                Major               Moderate
# 2                             Moderate               Moderate
# 3                             Moderate               Moderate
# 4                             Moderate                  Minor
#
#   APR Medical Surgical Description         Payment Typology 1  \
# 0                          Medical                   Medicare
# 1                          Medical                   Medicaid
# 2                          Medical  Department of Corrections
# 3                          Medical                   Medicaid
# 4                          Medical  Department of Corrections
#
#   Payment Typology 2  Payment Typology 3 Birth Weight  \
# 0           Medicare            Self-Pay          NaN
# 1           Medicaid            Self-Pay          NaN
# 2           Self-Pay                 NaN          NaN
# 3           Medicaid            Self-Pay          NaN
# 4           Self-Pay                 NaN          NaN
#
#    Abortion Edit Indicator Emergency Department Indicator  Total Charges  \
# 0                        N                              N      114168.00
# 1                        N                              N       58517.00
# 2                        N                              N       39647.04
# 3                        N                              N       36031.09
# 4                        N                              N       30534.00
#
#   Total Costs
# 0    40464.04
# 1    26046.50
# 2    17397.59
# 3    16118.84
# 4    11921.05
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Exploration of target

# %% [markdown]
# **The target that I want to predict is APR Risk of Mortality.**
#
# This is an important target as it will dictate certain decisions such as treatments, aggresiveness of care, familial preparations for the worst outcome etc...
# - Ordinal rank Minor(1), Moderate(2), Major(3), Extreme(4)
#
# It is important to determine this metric early on in the process of treating the patient as this is a crucial piece of information in creating efficient and effective treatment plans for higher risk patients.
#
# As such, while doing feature selection we will consider the time frame of when certain features are available in order to implement the model earlier in the inpatient process.

# %%
# Ordinal encode
df['APR Risk of Mortality'] = df['APR Risk of Mortality'].replace({
    'Minor': 1,
    "Moderate": 2,
    "Major": 3,
    "Extreme": 4
})

# %%
# Target is 'APR Risk of Mortality'

# Look at target statistics
df['APR Risk of Mortality'].describe()
# Out:
# count    2.343329e+06
# mean     1.691481e+00
# std      9.164827e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      4.000000e+00
# Name: APR Risk of Mortality, dtype: float64

# %%
# Value counts

df['APR Risk of Mortality'].value_counts()
# Out:
# 1.0    1338452
# 2.0     508068
# 3.0     378128
# 4.0     118681
# Name: APR Risk of Mortality, dtype: int64

# %%
# Visual exploration of the column

import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df['APR Risk of Mortality']);

# %% [markdown]
# My problem is a multi-class classification

# %%
# Distribution of target classes

df['APR Risk of Mortality'].value_counts(normalize= True)
# Out:
# 1.0    0.571175
# 2.0    0.216815
# 3.0    0.161364
# 4.0    0.050646
# Name: APR Risk of Mortality, dtype: float64

# %% [markdown]
# The majority class (1) for my target is is 57%. <br>
# I will use accuracy and average weighted f1 score as my evaluation metrics
# - Average f1-scores are used for multi-class targets
# - Weighted average f1-score will account for the label inbalance in my target

# %% [markdown]
# I will use a random split to train/val/test my data as all observations are within the same year. <br>

# %% [markdown]
# ## Feature Exploration

# %% [markdown]
# **Features to exclude** <br>
# Not applicable to target (Either unique identifier or information gathered at the end of a patients treatment which is not useful as the model needs to be applied earlier)
# - Operating Certificate Number (Unique ID for the hospital)
# - Patient Disposition (Destination upon discharge)
# - Discharge year (The entire dataset is for the year 2017)
# - Total charges (Information not collected until the end of treatment)
# - Total cost (Information not collected until the end of treatment)
# - Birth weight (only applicable to newborns)
#
#
# Redundant: All of the codes have a description column. I will pull them out as a reference table, but for my model they are redundant.
# - CCS Diagnosis Description
# - CCS Procedure Description
# - APR DRG Description
# - APR MDC Description
#
#
# Potential data leakage:
# - APR Severity of Illness code (Might have a direct correlation to APR Risk of Mortality)
#     - Every time there is a 0 for APR Severity of Illness Code, there is a np.nan for APR Risk of Mortality
#     - Upon further exploration below, I have decided to omit this column as 60% of the time it is the exact same value as APR Risk of Mortality
#
#
# Use the below features to create an engineered feature of patient distance to hospital
#
# - Permanent Facility Id
# - Facility Name
# - Hospital Service Area
# - Hospital Country
# - Zip code

# %% [markdown]
# ## Reference Tables
# - Matches descriptions with codes

# %%
# Create a reference table for codes and their descriptions
# We will be dropping the descriptions

# CCS Diagnosis
codes_diagnosis = df.groupby('CCS Diagnosis Description')['CCS Diagnosis Code'].mean()
codes_diagnosis = pd.DataFrame(codes_diagnosis)

# CCS Procedure
codes_procedure = df.groupby('CCS Procedure Description')['CCS Procedure Code'].mean()
codes_procedure = pd.DataFrame(codes_procedure)

# APR DRG
codes_drg = df.groupby('APR DRG Description')['APR DRG Code'].mean()
codes_drg = pd.DataFrame(codes_drg)

# APR MDC
codes_mdc = df.groupby('APR MDC Description')['APR MDC Code'].mean()
codes_mdc = pd.DataFrame(codes_mdc)

# APR Severity of Illness
codes_illness = df.groupby('APR Severity of Illness Description')['APR Severity of Illness Code'].mean()
codes_illness = pd.DataFrame(codes_illness)

# %% [markdown]
# ## Initial Data Cleaning

# %%
# Change pandas display so you can see all of the columns at once

pd.set_option('display.max_columns', 25)

# %%
# Drop unnecessary features as commented above

df_cleaned = df.drop([
    'Operating Certificate Number',
    'Patient Disposition',
    'Discharge Year',
    'CCS Diagnosis Description',
    'CCS Procedure Description',
    'APR DRG Description',
    'APR MDC Description',
    'Birth Weight',
    'Total Charges',
    'Total Costs',
    'APR Severity of Illness Description'
],
    axis= 1

)
df_cleaned.head()
# Out:
#   Hospital Service Area Hospital County  Permanent Facility Id  \
# 0         Hudson Valley     Westchester                 1061.0
# 1         Hudson Valley     Westchester                 1061.0
# 2         Hudson Valley     Westchester                 1061.0
# 3         Hudson Valley     Westchester                 1061.0
# 4         Hudson Valley     Westchester                 1061.0
#
#                       Facility Name Age Group Zip Code - 3 digits Gender  \
# 0  Montefiore Mount Vernon Hospital  30 to 49                 NaN      M
# 1  Montefiore Mount Vernon Hospital  50 to 69                 105      M
# 2  Montefiore Mount Vernon Hospital  30 to 49                 105      F
# 3  Montefiore Mount Vernon Hospital  50 to 69                 105      F
# 4  Montefiore Mount Vernon Hospital  18 to 29                 105      F
#
#     Race          Ethnicity Length of Stay Type of Admission  \
# 0  White  Not Span/Hispanic             21          Elective
# 1  White   Spanish/Hispanic              8         Emergency
# 2  White            Unknown              6         Emergency
# 3  White  Not Span/Hispanic              4         Emergency
# 4  White   Spanish/Hispanic              4         Emergency
#
#    CCS Diagnosis Code  CCS Procedure Code  APR DRG Code  APR MDC Code  \
# 0                 659                   0           750            19
# 1                  99                 108           194             5
# 2                 161                 102           465            11
# 3                 238                 222           721            18
# 4                   2                   0           720            18
#
#    APR Severity of Illness Code  APR Risk of Mortality  \
# 0                             2                    1.0
# 1                             3                    2.0
# 2                             2                    2.0
# 3                             2                    2.0
# 4                             2                    1.0
#
#   APR Medical Surgical Description         Payment Typology 1  \
# 0                          Medical                   Medicare
# 1                          Medical                   Medicaid
# 2                          Medical  Department of Corrections
# 3                          Medical                   Medicaid
# 4                          Medical  Department of Corrections
#
#   Payment Typology 2 Payment Typology 3 Abortion Edit Indicator  \
# 0           Medicare           Self-Pay                       N
# 1           Medicaid           Self-Pay                       N
# 2           Self-Pay                NaN                       N
# 3           Medicaid           Self-Pay                       N
# 4           Self-Pay                NaN                       N
#
#   Emergency Department Indicator
# 0                              N
# 1                              N
# 2                              N
# 3                              N
# 4                              N

# %%
# Look at null values
df_cleaned.isnull().sum()
# Out:
# Hospital Service Area                  5155
# Hospital County                        5155
# Permanent Facility Id                  5155
# Facility Name                             0
# Age Group                                 0
# Zip Code - 3 digits                   39019
# Gender                                    0
# Race                                      0
# Ethnicity                                 0
# Length of Stay                            0
# Type of Admission                         0
# CCS Diagnosis Code                        0
# CCS Procedure Code                        0
# APR DRG Code                              0
# APR MDC Code                              0
# APR Severity of Illness Code              0
# APR Risk of Mortality                   240
# APR Medical Surgical Description          0
# Payment Typology 1                        0
# Payment Typology 2                   878722
# Payment Typology 3                  1737244
# Abortion Edit Indicator                   0
# Emergency Department Indicator            0
# dtype: int64

# %%
# Explore missing values in target

missing_illness = df[df['APR Risk of Mortality'].isnull() == True]
missing_illness['Type of Admission'].value_counts(normalize = True)
# Out:
# Newborn      0.745833
# Emergency    0.120833
# Urgent       0.070833
# Elective     0.062500
# Name: Type of Admission, dtype: float64

# %%
# Drop missing values in target (only 0.01%)
# They were mostly (74.5%) newborn babies which we are not including in our model

df_cleaned.dropna(subset= ['APR Risk of Mortality'], inplace= True)

# %% [markdown]
# ## Data exploration

# %%
# Look at numeric traits
df_cleaned.describe()
# Out:
#        Permanent Facility Id  CCS Diagnosis Code  CCS Procedure Code  \
# count           2.338179e+06        2.343329e+06        2.343329e+06
# mean            1.038966e+03        1.898662e+02        1.013940e+02
# std             7.202033e+02        1.649466e+02        8.681344e+01
# min             1.000000e+00        1.000000e+00        0.000000e+00
# 25%             5.410000e+02        1.010000e+02        0.000000e+00
# 50%             1.097000e+03        1.570000e+02        9.800000e+01
# 75%             1.453000e+03        2.180000e+02        1.800000e+02
# max             9.431000e+03        2.617000e+03        2.310000e+02
#
#        APR DRG Code  APR MDC Code  APR Severity of Illness Code  \
# count  2.343329e+06  2.343329e+06                  2.343329e+06
# mean   4.161252e+02  1.031172e+01                  2.020953e+00
# std    2.424451e+02  5.899823e+00                  8.889587e-01
# min    1.000000e+00  1.000000e+00                  1.000000e+00
# 25%    1.980000e+02  5.000000e+00                  1.000000e+00
# 50%    3.830000e+02  9.000000e+00                  2.000000e+00
# 75%    6.400000e+02  1.500000e+01                  3.000000e+00
# max    9.520000e+02  2.500000e+01                  4.000000e+00
#
#        APR Risk of Mortality
# count           2.343329e+06
# mean            1.691481e+00
# std             9.164827e-01
# min             1.000000e+00
# 25%             1.000000e+00
# 50%             1.000000e+00
# 75%             2.000000e+00
# max             4.000000e+00

# %%
# Look at categorical traits
df_cleaned.describe(exclude= 'number')
# Out:
#        Hospital Service Area Hospital County         Facility Name  \
# count                2338179         2338179               2343329
# unique                     8              57                   211
# top            New York City       Manhattan  Mount Sinai Hospital
# freq                 1070407          395687                 52335
#
#           Age Group Zip Code - 3 digits   Gender     Race          Ethnicity  \
# count       2343329             2304316  2343329  2343329            2343329
# unique            5                  50        3        4                  4
# top     70 or Older                 112        F    White  Not Span/Hispanic
# freq         664780              293826  1296822  1316956            1895507
#
#        Length of Stay Type of Admission APR Medical Surgical Description  \
# count         2343329           2343329                          2343329
# unique            120                 6                                2
# top                 2         Emergency                          Medical
# freq           546084           1500436                          1742545
#
#        Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# count             2343329            1464708             606295
# unique                 10                 10                 10
# top              Medicare           Medicaid           Self-Pay
# freq               906899             529653             400972
#
#        Abortion Edit Indicator Emergency Department Indicator
# count                  2343329                        2343329
# unique                       2                              2
# top                          N                              Y
# freq                   2339978                        1373723

# %%
# Look at different label names for spelling mistakes etc...
df_cleaned['Emergency Department Indicator'].value_counts().index.tolist()
# Out:
# ['Y', 'N']

# %%
# Look at null values, we will need to impute
df_cleaned.isnull().sum()
# Out:
# Hospital Service Area               0
# Hospital County                     0
# Permanent Facility Id               0
# Facility Name                       0
# Age Group                           0
# Zip Code - 3 digits                 0
# Gender                              0
# Race                                0
# Ethnicity                           0
# Length of Stay                      0
# Type of Admission                   0
# CCS Diagnosis Code                  0
# CCS Procedure Code                  0
# APR DRG Code                        0
# APR MDC Code                        0
# APR Severity of Illness Code        0
# APR Risk of Mortality               0
# APR Medical Surgical Description    0
# Payment Typology 1                  0
# Payment Typology 2                  0
# Payment Typology 3                  0
# Abortion Edit Indicator             0
# Emergency Department Indicator      0
# dtype: int64

# %% [markdown]
# ### Explore relationship between APR Severity of Illness and target for potential data leakage

# %%
# Create subset of just the two columns
data_leak = df_cleaned[['APR Severity of Illness Code', 'APR Risk of Mortality']]
data_leak
# Out:
#          APR Severity of Illness Code  APR Risk of Mortality
# 0                                   2                    1.0
# 1                                   3                    2.0
# 2                                   2                    2.0
# 3                                   2                    2.0
# 4                                   2                    1.0
# ...                               ...                    ...
# 2343564                             1                    2.0
# 2343565                             2                    2.0
# 2343566                             1                    1.0
# 2343567                             2                    1.0
# 2343568                             2                    1.0
#
# [2343329 rows x 2 columns]

# %%
# Look a statistical features
data_leak.describe()
# Out:
#        APR Severity of Illness Code  APR Risk of Mortality
# count                  2.343329e+06           2.343329e+06
# mean                   2.020953e+00           1.691481e+00
# std                    8.889587e-01           9.164827e-01
# min                    1.000000e+00           1.000000e+00
# 25%                    1.000000e+00           1.000000e+00
# 50%                    2.000000e+00           1.000000e+00
# 75%                    3.000000e+00           2.000000e+00
# max                    4.000000e+00           4.000000e+00

# %%
# Count how many times they are not equivalent

# Convert APR Risk of Mortality to integer
data_leak['APR Risk of Mortality'] = data_leak['APR Risk of Mortality'].astype(int)

# Pull out subset of when the two columns are not equivalent
subset = data_leak[data_leak['APR Risk of Mortality'] != data_leak['APR Severity of Illness Code']]
subset
# Out:
# /Users/stevenchase/opt/anaconda3/envs/yourenvname/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#          APR Severity of Illness Code  APR Risk of Mortality
# 0                                   2                      1
# 1                                   3                      2
# 4                                   2                      1
# 6                                   2                      1
# 10                                  2                      1
# ...                               ...                    ...
# 2343561                             3                      2
# 2343563                             2                      1
# 2343564                             1                      2
# 2343567                             2                      1
# 2343568                             2                      1
#
# [957581 rows x 2 columns]

# %%
# Proportion of when these two columns are the same
1 - len(subset) / len(df_cleaned)
# Out:
# 0.5913587037927666

# %%
# Visual of relationship
import seaborn as sns
sns.catplot(x= 'APR Severity of Illness Code', y= 'APR Risk of Mortality', kind= 'box', data= data_leak);

# %% [markdown]
# **In conclusion I will drop APR Severity of Illness code for two reasons**
# - First, it is too similar to the target. 59% of the time they are the exact same value.
# - Second, in practice I would want to implement the model before necessarily knowing the severity of the illness. By the time you know the severity of the illness, my model would not provide you with very much additional useful information.

# %% [markdown]
# ### Explore Redacted Data
# - 5150 rows with redacted geographic information
# - Labeled 'Redacted for Confidentiality'

# %%
# Pull out the redacted information
redacted = df_cleaned[df_cleaned['Facility Name'] == 'Redacted for Confidentiality']
redacted
# Out:
#         Hospital Service Area Hospital County  Permanent Facility Id  \
# 28                        NaN             NaN                    NaN
# 595                       NaN             NaN                    NaN
# 839                       NaN             NaN                    NaN
# 2227                      NaN             NaN                    NaN
# 2723                      NaN             NaN                    NaN
# ...                       ...             ...                    ...
# 2342722                   NaN             NaN                    NaN
# 2342742                   NaN             NaN                    NaN
# 2342768                   NaN             NaN                    NaN
# 2342862                   NaN             NaN                    NaN
# 2343089                   NaN             NaN                    NaN
#
#                         Facility Name    Age Group Zip Code - 3 digits Gender  \
# 28       Redacted for Confidentiality      0 to 17                 NaN      F
# 595      Redacted for Confidentiality     18 to 29                 NaN      F
# 839      Redacted for Confidentiality     18 to 29                 NaN      F
# 2227     Redacted for Confidentiality      0 to 17                 NaN      F
# 2723     Redacted for Confidentiality     30 to 49                 NaN      F
# ...                               ...          ...                 ...    ...
# 2342722  Redacted for Confidentiality      0 to 17                 NaN      M
# 2342742  Redacted for Confidentiality  70 or Older                 NaN      U
# 2342768  Redacted for Confidentiality     30 to 49                 NaN      M
# 2342862  Redacted for Confidentiality     30 to 49                 NaN      F
# 2343089  Redacted for Confidentiality     18 to 29                 NaN      U
#
#                            Race          Ethnicity Length of Stay  \
# 28                        White  Not Span/Hispanic              2
# 595                       White  Not Span/Hispanic              1
# 839      Black/African American  Not Span/Hispanic              1
# 2227                 Other Race   Spanish/Hispanic              1
# 2723     Black/African American  Not Span/Hispanic              1
# ...                         ...                ...            ...
# 2342722                   White   Spanish/Hispanic              2
# 2342742                   White  Not Span/Hispanic              4
# 2342768  Black/African American  Not Span/Hispanic              1
# 2342862                   White  Not Span/Hispanic              1
# 2343089              Other Race  Not Span/Hispanic              3
#
#         Type of Admission  CCS Diagnosis Code  CCS Procedure Code  \
# 28              Emergency                 229                 148
# 595                Urgent                 181                 222
# 839             Emergency                 177                 127
# 2227            Emergency                 195                 126
# 2723            Emergency                 180                 123
# ...                   ...                 ...                 ...
# 2342722           Newborn                 218                 115
# 2342742         Emergency                  99                   0
# 2342768         Emergency                  83                   0
# 2342862         Emergency                 178                 127
# 2343089            Trauma                 228                   0
#
#          APR DRG Code  APR MDC Code  APR Severity of Illness Code  \
# 28                315             8                             2
# 595               564            14                             1
# 839               544            14                             1
# 2227              560            14                             2
# 2723              545            14                             1
# ...               ...           ...                           ...
# 2342722           640            15                             1
# 2342742           194             5                             2
# 2342768            53             1                             1
# 2342862           544            14                             2
# 2343089           115             3                             3
#
#          APR Risk of Mortality APR Medical Surgical Description  \
# 28                         1.0                         Surgical
# 595                        1.0                          Medical
# 839                        1.0                         Surgical
# 2227                       1.0                          Medical
# 2723                       1.0                         Surgical
# ...                        ...                              ...
# 2342722                    1.0                          Medical
# 2342742                    2.0                          Medical
# 2342768                    1.0                          Medical
# 2342862                    1.0                         Surgical
# 2343089                    1.0                          Medical
#
#              Payment Typology 1         Payment Typology 2 Payment Typology 3  \
# 28       Blue Cross/Blue Shield                   Self-Pay                NaN
# 595      Blue Cross/Blue Shield                   Medicaid                NaN
# 839                    Medicaid                   Medicaid           Self-Pay
# 2227                   Medicaid                        NaN                NaN
# 2723                   Medicaid                        NaN                NaN
# ...                         ...                        ...                ...
# 2342722                Medicaid                        NaN                NaN
# 2342742                Medicare                   Medicaid                NaN
# 2342768                Medicaid                        NaN                NaN
# 2342862                Medicaid                   Medicaid                NaN
# 2343089     Miscellaneous/Other  Managed Care, Unspecified                NaN
#
#         Abortion Edit Indicator Emergency Department Indicator
# 28                            N                              N
# 595                           Y                              N
# 839                           Y                              N
# 2227                          Y                              Y
# 2723                          Y                              Y
# ...                         ...                            ...
# 2342722                       N                              N
# 2342742                       N                              Y
# 2342768                       N                              Y
# 2342862                       Y                              Y
# 2343089                       N                              Y
#
# [5150 rows x 23 columns]

# %%
# Explore redacted rows
redacted.describe()
# Out:
#        Permanent Facility Id  CCS Diagnosis Code  CCS Procedure Code  \
# count                    0.0         5150.000000         5150.000000
# mean                     NaN          196.830097          110.588544
# std                      NaN          125.279172           67.198097
# min                      NaN            2.000000            0.000000
# 25%                      NaN          177.000000           87.000000
# 50%                      NaN          179.000000          126.000000
# 75%                      NaN          180.000000          131.000000
# max                      NaN         2617.000000          231.000000
#
#        APR DRG Code  APR MDC Code  APR Severity of Illness Code  \
# count   5150.000000   5150.000000                   5150.000000
# mean     526.164854     13.269320                      1.726602
# std      158.935758      3.970063                      0.755514
# min        4.000000      1.000000                      1.000000
# 25%      544.000000     14.000000                      1.000000
# 50%      545.000000     14.000000                      2.000000
# 75%      564.000000     14.000000                      2.000000
# max      952.000000     25.000000                      4.000000
#
#        APR Risk of Mortality
# count            5150.000000
# mean                1.329903
# std                 0.659645
# min                 1.000000
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max                 4.000000

# %%
redacted.describe(exclude = 'number')
# Out:
#        Hospital Service Area Hospital County                 Facility Name  \
# count                      0               0                          5150
# unique                     0               0                             1
# top                      NaN             NaN  Redacted for Confidentiality
# freq                     NaN             NaN                          5150
#
#        Age Group Zip Code - 3 digits Gender        Race          Ethnicity  \
# count       5150                   0   5150        5150               5150
# unique         5                   0      3           4                  4
# top     30 to 49                 NaN      F  Other Race  Not Span/Hispanic
# freq        2175                 NaN   4215        1788               2755
#
#        Length of Stay Type of Admission APR Medical Surgical Description  \
# count            5150              5150                             5150
# unique             55                 6                                2
# top                 1         Emergency                         Surgical
# freq             2537              3873                             2693
#
#        Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# count                5150               2519                877
# unique                 10                 10                  7
# top              Medicaid           Medicaid           Self-Pay
# freq                 2671               1409                705
#
#        Abortion Edit Indicator Emergency Department Indicator
# count                     5150                           5150
# unique                       2                              2
# top                          Y                              Y
# freq                      3351                           3559

# %%
# 65% of the redacted information was because they were abortions
# Will drop these rows because abortion indicator has zero effect on my model
redacted['Abortion Edit Indicator'].value_counts(normalize= True)
# Out:
# Y    0.65068
# N    0.34932
# Name: Abortion Edit Indicator, dtype: float64

# %%
# Look at the distribution of various features within redacted subset
# Looking to see if there is a specific reason these were redacted

redacted['APR Severity of Illness Code'].value_counts(normalize= True)
# Out:
# 1    0.436505
# 2    0.423301
# 3    0.117282
# 4    0.022913
# Name: APR Severity of Illness Code, dtype: float64

# %% [markdown]
# Will drop rows with redacted information because 65% are redacted due to being an abortion (abortion indicator has zero impact on my model). The rest maintain a normal distribution throughout the features so I will not be losing any information by dropping them (0.078% of observations).

# %%
# Dropped redacted observations
df_cleaned.dropna(subset= ['Hospital County'], inplace= True)

# %%
# Check that redacted observations were dropped
print(df_cleaned.shape)
df_cleaned.isnull().sum()
# Out:
# (2338179, 23)
# Hospital Service Area                     0
# Hospital County                           0
# Permanent Facility Id                     0
# Facility Name                             0
# Age Group                                 0
# Zip Code - 3 digits                   33863
# Gender                                    0
# Race                                      0
# Ethnicity                                 0
# Length of Stay                            0
# Type of Admission                         0
# CCS Diagnosis Code                        0
# CCS Procedure Code                        0
# APR DRG Code                              0
# APR MDC Code                              0
# APR Severity of Illness Code              0
# APR Risk of Mortality                     0
# APR Medical Surgical Description          0
# Payment Typology 1                        0
# Payment Typology 2                   875990
# Payment Typology 3                  1732761
# Abortion Edit Indicator                   0
# Emergency Department Indicator            0
# dtype: int64

# %% [markdown]
# ### Clean zip code
# - I want to replace missing zip codes with the most frequent for the county that the hospital is located in

# %%
# Define a function that will take the most frequent 

def manual_mode(X):
    manmode = X.copy()
    try: manmode = manmode.value_counts().index[0]
    except: pass
    return manmode

# %%
# Use the previously defined function to fill null values with most frequent zip code grouped by Hospital County

df_cleaned['Zip Code - 3 digits'] = df_cleaned['Zip Code - 3 digits'].fillna(df_cleaned.groupby('Hospital County')['Zip Code - 3 digits'].transform(manual_mode))

# %%
df_cleaned.isnull().sum()
# Out:
# Hospital Service Area                     0
# Hospital County                           0
# Permanent Facility Id                     0
# Facility Name                             0
# Age Group                                 0
# Zip Code - 3 digits                       0
# Gender                                    0
# Race                                      0
# Ethnicity                                 0
# Length of Stay                            0
# Type of Admission                         0
# CCS Diagnosis Code                        0
# CCS Procedure Code                        0
# APR DRG Code                              0
# APR MDC Code                              0
# APR Severity of Illness Code              0
# APR Risk of Mortality                     0
# APR Medical Surgical Description          0
# Payment Typology 1                        0
# Payment Typology 2                   875990
# Payment Typology 3                  1732761
# Abortion Edit Indicator                   0
# Emergency Department Indicator            0
# dtype: int64

# %% [markdown]
# ### Clean Payment Typology 2 and 3
# - Replace missing values with 'None'
# - These patients only used one type of payment, didn't need type 2 or 3

# %%
# Replace missing values of Payment Typology 2 and 3 with 'None', they only used one type of payment
df_cleaned['Payment Typology 2']= df_cleaned['Payment Typology 2'].replace({np.nan: 'None'})
df_cleaned['Payment Typology 3']= df_cleaned['Payment Typology 3'].replace({np.nan: 'None'})

# %%
# Check which null values are left to clean

df_cleaned.isnull().sum()
# Out:
# Hospital Service Area               0
# Hospital County                     0
# Permanent Facility Id               0
# Facility Name                       0
# Age Group                           0
# Zip Code - 3 digits                 0
# Gender                              0
# Race                                0
# Ethnicity                           0
# Length of Stay                      0
# Type of Admission                   0
# CCS Diagnosis Code                  0
# CCS Procedure Code                  0
# APR DRG Code                        0
# APR MDC Code                        0
# APR Severity of Illness Code        0
# APR Risk of Mortality               0
# APR Medical Surgical Description    0
# Payment Typology 1                  0
# Payment Typology 2                  0
# Payment Typology 3                  0
# Abortion Edit Indicator             0
# Emergency Department Indicator      0
# dtype: int64

# %% [markdown]
# ## Split into train/val/test using random split

# %%
from sklearn.model_selection import train_test_split

# Split train data into train and test, 80/20 split

train, test = train_test_split(df_cleaned, train_size=0.85, test_size=0.15, 
                              stratify=df_cleaned['APR Risk of Mortality'], random_state=42)

# Then split train into train and validate
train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              stratify=train['APR Risk of Mortality'], random_state=42)

train.shape, val.shape, test.shape
# Out:
# ((1589961, 23), (397491, 23), (350727, 23))

# %% [markdown]
# ## Baseline model:
# Majority class (1, minor risk) is 57%

# %%
df_cleaned['APR Risk of Mortality'].value_counts(normalize= True)
# Out:
# 1.0    0.571175
# 2.0    0.216815
# 3.0    0.161364
# 4.0    0.050646
# Name: APR Risk of Mortality, dtype: float64

# %%
# Baseline classification report
from sklearn.metrics import classification_report

# Looking at weighted average f1-score as an evaluation metric 
guess= [1] * len(df_cleaned)

print(classification_report(df_cleaned['APR Risk of Mortality'], guess))
# Out:
# /Users/stevenchase/opt/anaconda3/envs/yourenvname/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          1.0       0.57      1.00      0.73   1338452
#          2.0       0.00      0.00      0.00    508068
#          3.0       0.00      0.00      0.00    378128
#          4.0       0.00      0.00      0.00    118681
#
#     accuracy                           0.57   2343329
#    macro avg       0.14      0.25      0.18   2343329
# weighted avg       0.33      0.57      0.42   2343329

# %% [markdown]
# ## First Model

# %%
# Set features and target
# Define target vector and feature matrices

target = 'APR Risk of Mortality'

features = [
    'Age Group',
    'Gender',
    'Race',
    'Ethnicity',
    'Type of Admission',
    'CCS Diagnosis Code',
    'CCS Procedure Code',
    'APR DRG Code',
    'APR MDC Code',
    'APR Medical Surgical Description',
    'Emergency Department Indicator',
]

# Split into train, validate and test target vector and feature matrices
X_train= train[features]
y_train= train[target]

X_val= val[features]
y_val= val[target]

# Set test feature matrix
X_test= test[features]
y_test= test[target]

# %%
# Install category encoders in anaconda environment
# conda install -c conda-forge category_encoders

# %%
# Create a pipeline to do encoding and fit a random forest model

# Imports
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Create pipeline (encode, standardize, model)
pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    RandomForestClassifier(random_state= 42, max_depth= 10, n_estimators= 10)
)

# Fit on training data
pipeline.fit(X_train, y_train)

# Validation score
print('Train Accuracy:', pipeline.score(X_train, y_train))
print('Validation Accuracy:', pipeline.score(X_val, y_val))
# Out:
# Train Accuracy: 0.6816669103706833
# Validation Accuracy: 0.6794078811946803

# %% [markdown]
# #### First model evaluation metric results (Without feature APR Severity of Illness Code)
# Train Accuracy: 0.6816669103706833 <br>
# Validation Accuracy: 0.6794078811946803

# %%
# Feature importances

# %matplotlib inline
import matplotlib.pyplot as plt

# Pull out encoded X_train matrix
encoder = pipeline.named_steps['ordinalencoder']
encoded= encoder.transform(X_train)

# Get feature importances
rf = pipeline.named_steps['randomforestclassifier']
importances = pd.Series(rf.feature_importances_, encoded.columns)

# Plot top n feature importances
n = 50
plt.figure(figsize=(10,n/2))
plt.title(f'Top {n} features')
importances.sort_values()[-n:].plot.barh();

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion matrix
from sklearn.metrics import plot_confusion_matrix

# Plot
plot_confusion_matrix(pipeline, X_val, y_val, xticks_rotation= 'vertical', normalize= 'pred')

# Enlarge
plt.rcParams['figure.dpi']= 200

# %% [markdown]
# ### Scores for Model 1

# %%
# Look at precision and recall for each class
# Using weighted average f1-score as an evaluation metric

from sklearn.metrics import classification_report

# Make predictions
y_pred= pipeline.predict(X_val)

# Print scores
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.78      0.92      0.85    227537
#          2.0       0.45      0.35      0.40     86371
#          3.0       0.47      0.43      0.45     64282
#          4.0       0.71      0.16      0.26     20176
#
#     accuracy                           0.68    398366
#    macro avg       0.60      0.47      0.49    398366
# weighted avg       0.66      0.68      0.65    398366

# %% [markdown]
# Remember that the baseline model had an accuracy of 57% with a weighted average f1-score of 0.42

# %% [markdown]
# ## Model 2
# - Include all of the features except for geographic data

# %%
# Set features and target
# Define target vector and feature matrices

# Including all features except for target and geographic data

target = 'APR Risk of Mortality'

features = [
    'Age Group',
    'Gender',
    'Race',
    'Ethnicity',
    'Length of Stay',
    'Type of Admission',
    'CCS Diagnosis Code',
    'CCS Procedure Code',
    'APR DRG Code',
    'APR MDC Code',
    'APR Medical Surgical Description',
    'Payment Typology 1',
    'Payment Typology 2',
    'Payment Typology 3',
    'Abortion Edit Indicator',
    'Emergency Department Indicator',
]

# Split into train, validate and test target vector and feature matrices
X_train= train[features]
y_train= train[target]

X_val= val[features]
y_val= val[target]

# Set test feature matrix
X_test= test[features]
y_test= test[target]

# %%
# Create a pipeline to do encoding and fit a random forest model

# Imports
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Create pipeline
pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    RandomForestClassifier(random_state= 42, max_depth= 20, n_estimators= 30, n_jobs= -1)
)

# Fit pipeline on training data
pipeline.fit(X_train, y_train)

# Validation score
print('Train Accuracy:', pipeline.score(X_train, y_train))
print('Validation Accuracy:', pipeline.score(X_val, y_val))
# Out:
# Train Accuracy: 0.8089287294402192
# Validation Accuracy: 0.7036494078309896

# %% [markdown]
# ### Scores for Model 2

# %%
# Make predictions
y_pred= pipeline.predict(X_val)

# Print recall, precision and f1 scores
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.90      0.87    227537
#          2.0       0.48      0.44      0.46     86371
#          3.0       0.50      0.49      0.49     64282
#          4.0       0.60      0.27      0.38     20176
#
#     accuracy                           0.70    398366
#    macro avg       0.60      0.53      0.55    398366
# weighted avg       0.69      0.70      0.69    398366

# %% [markdown]
# Model 2 bumped the evaluation scores up 2-3 points each.

# %%
# Feature importances

# %matplotlib inline
import matplotlib.pyplot as plt

# Pull out encoded X_train matrix
encoder = pipeline.named_steps['ordinalencoder']
encoded= encoder.transform(X_train)

# Get feature importances
rf = pipeline.named_steps['randomforestclassifier']
importances = pd.Series(rf.feature_importances_, encoded.columns)

# Plot top n feature importances
n = 50
plt.figure(figsize=(10,n/2))
plt.title(f'Top {n} features')
importances.sort_values()[-n:].plot.barh();

# %% [markdown]
# #### Permutation importances

# %%
# You can't use a pipeline in eli5
# Need to transform data and fit model before inputting into PermutationImportance

# Create pipeline to transform data
processor = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler()
)

# Transform the data
X_train_transformed = processor.fit_transform(X_train)
X_val_transformed = processor.transform(X_val)

# Define model with parameters
model = RandomForestClassifier(random_state= 42, max_depth= 20, n_estimators= 30, n_jobs= -1)

# Fit the model to train data
model.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=-1,
#                        oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# Install eli5 on anaconda environment
# conda install -c conda-forge eli5

# %%
# Import
import eli5
from eli5.sklearn import PermutationImportance

# Define permuter and parameters
permuter= PermutationImportance(model, scoring= 'accuracy', n_iter= 5, random_state= 42)

# Fit permutation importance to transformed validation data
permuter.fit(X_val_transformed, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestClassifier(bootstrap=True,
#                                                        ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=20,
#                                                        max_features='auto',
#                                                        max_leaf_nodes=None,
#                                                        max_samples=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=30,
#                                                        n_jobs=-1,
#                                                        oob_score=False,
#                                                        random_state=42,
#                                                        verbose=0,
#                                                        warm_start=False),
#                       n_iter=5, random_state=42, refit=True,
#                       scoring='accuracy')

# %%
# Show weights graphic

# Define feature labels
feature_labels = X_val.columns.tolist()

# Run and print function
eli5.show_weights(permuter, top= None, feature_names= feature_labels)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0717
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Age Group
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0397
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CCS Diagnosis Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0396
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length of Stay
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0204
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 APR DRG Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0204
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CCS Procedure Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0156
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 APR MDC Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0097
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payment Typology 1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0082
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 APR Medical Surgical Description
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Type of Admission
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Emergency Department Indicator
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payment Typology 2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gender
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0012
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Race
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Ethnicity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0006
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payment Typology 3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Abortion Edit Indicator
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ### XGBoost

# %%
# Import
from xgboost import XGBClassifier

# Create pipeline using XGBoostClassifier
pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    XGBClassifier(n_estimators= 30, random_state= 42, n_jobs= -1)
)

# Fit pipeline to train data
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['Age Group', 'Gender', 'Race',
#                                       'Ethnicity', 'Length of Stay',
#                                       'Type of Admission',
#                                       'APR Medical Surgical Description',
#                                       'Payment Typology 1',
#                                       'Payment Typology 2',
#                                       'Payment Typology 3',
#                                       'Abortion Edit Indicator',
#                                       'Emergency Department Indicator'],
#                                 drop_invariant=False, handle_missing='value',
#                                 handle_unknown='value'...
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=30, n_jobs=-1, nthread=None,
#                                objective='multi:softprob', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)

# %%
# Import
from sklearn.metrics import accuracy_score

# Make predictions
y_pred= pipeline.predict(X_val)

# Print error metric
print('Validation Accuracy', accuracy_score(y_val, y_pred))
# Out:
# Validation Accuracy 0.6711491442542787

# %%
# Print recall, precision and f1 scores
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.77      0.92      0.84    227537
#          2.0       0.44      0.34      0.38     86371
#          3.0       0.47      0.39      0.43     64282
#          4.0       0.65      0.13      0.21     20176
#
#     accuracy                           0.67    398366
#    macro avg       0.58      0.45      0.47    398366
# weighted avg       0.64      0.67      0.64    398366

# %% [markdown]
# XGBoost did not improve the evaluation metrics from random forest

# %% [markdown]
# ## Model 3
# - Feature engineer: distance to hospital
# - Feature engineer: did they require multiple methods of payment
# - Clean up feature selection. Don't include ones that have low importance in the model

# %%
# Set features and target
# Define target vector and feature matrices

# Including all features except for target and geographic data

target = 'APR Risk of Mortality'

features = [
    'Age Group',
    'Gender',
    'Race',
    'Ethnicity',
    'Length of Stay',
    'Type of Admission',
    'CCS Diagnosis Code',
    'CCS Procedure Code',
    'APR DRG Code',
    'APR MDC Code',
    'APR Medical Surgical Description',
    'Payment Typology 1',
    'Payment Typology 2',
    'Payment Typology 3',
    'Abortion Edit Indicator',
    'Emergency Department Indicator',
    'Zip Code - 3 digits',
    'Hospital Service Area',
    'Hospital County',
    'Facility Name'
    
]

# Split into train, validate and test target vector and feature matrices
X_train= train[features]
y_train= train[target]

X_val= val[features]
y_val= val[target]

# Set test feature matrix
X_test= test[features]
y_test= test[target]

# %%
# Create a pipeline to do encoding and fit a random forest model

# Imports
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Create pipeline
pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    RandomForestClassifier(random_state= 42, max_depth= 20, n_estimators= 30, n_jobs= -1)
)

# Fit pipeline on training data
pipeline.fit(X_train, y_train)

# Validation score
print('Train Accuracy:', pipeline.score(X_train, y_train))
print('Validation Accuracy:', pipeline.score(X_val, y_val))
# Out:
# Train Accuracy: 0.8193358201867844
# Validation Accuracy: 0.7028184285933518

# %% [markdown]
# Scores

# %%
# Make predictions
y_pred= pipeline.predict(X_val)

# Print recall, precision and f1 scores
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.83      0.91      0.87    226874
#          2.0       0.48      0.44      0.46     86218
#          3.0       0.50      0.48      0.49     64241
#          4.0       0.62      0.26      0.36     20158
#
#     accuracy                           0.70    397491
#    macro avg       0.61      0.52      0.54    397491
# weighted avg       0.69      0.70      0.69    397491

# %%
# Feature importances

# %matplotlib inline
import matplotlib.pyplot as plt

# Pull out encoded X_train matrix
encoder = pipeline.named_steps['ordinalencoder']
encoded= encoder.transform(X_train)

# Get feature importances
rf = pipeline.named_steps['randomforestclassifier']
importances = pd.Series(rf.feature_importances_, encoded.columns)

# Plot top n feature importances
n = 50
plt.figure(figsize=(10,n/2))
plt.title(f'Top {n} features')
importances.sort_values()[-n:].plot.barh();

# %%
# You can't use a pipeline in eli5
# Need to transform data and fit model before inputting into PermutationImportance

# Create processor pipeline to transform data
processor = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler()
)

# Transform the data
X_train_transformed = processor.fit_transform(X_train)
X_val_transformed = processor.transform(X_val)

# Define model with parameters
model = RandomForestClassifier(random_state= 42, max_depth= 20, n_estimators= 30, n_jobs= -1)

# Fit the model to train data
model.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=-1,
#                        oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# Import
import eli5
from eli5.sklearn import PermutationImportance

# Define permuter and parameters
permuter= PermutationImportance(model, scoring= 'accuracy', n_iter= 5, random_state= 42)

# Fit permutation importance to transformed validation data
permuter.fit(X_val_transformed, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestClassifier(bootstrap=True,
#                                                        ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=20,
#                                                        max_features='auto',
#                                                        max_leaf_nodes=None,
#                                                        max_samples=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=30,
#                                                        n_jobs=-1,
#                                                        oob_score=False,
#                                                        random_state=42,
#                                                        verbose=0,
#                                                        warm_start=False),
#                       n_iter=5, random_state=42, refit=True,
#                       scoring='accuracy')

# %%
# Show weights graphic

# Define feature labels
feature_labels = X_val.columns.tolist()

# Run and print function
eli5.show_weights(permuter, top= None, feature_names= feature_labels)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0491
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Age Group
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0434
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CCS Diagnosis Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0359
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Length of Stay
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0182
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 APR DRG Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0163
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CCS Procedure Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payment Typology 1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0120
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 APR MDC Code
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0051
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 APR Medical Surgical Description
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Type of Admission
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0029
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Emergency Department Indicator
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Facility Name
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Hospital County
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0015
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gender
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Zip Code - 3 digits
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payment Typology 2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0007
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Hospital Service Area
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Ethnicity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align

# %% [markdown]
# ### Work on engineering feature 'patient in or out of county'

# %%
geo = df_cleaned[['Hospital Service Area', 'Hospital County', 'Permanent Facility Id', 'Facility Name', 'Zip Code - 3 digits']]
geo
# Out:
#         Hospital Service Area Hospital County  Permanent Facility Id  \
# 0               Hudson Valley     Westchester                 1061.0
# 1               Hudson Valley     Westchester                 1061.0
# 2               Hudson Valley     Westchester                 1061.0
# 3               Hudson Valley     Westchester                 1061.0
# 4               Hudson Valley     Westchester                 1061.0
# ...                       ...             ...                    ...
# 2343564         Hudson Valley        Rockland                  779.0
# 2343565         Hudson Valley        Rockland                  779.0
# 2343566         Hudson Valley        Rockland                  779.0
# 2343567         New York City           Bronx                 3058.0
# 2343568          Finger Lakes         Steuben                  870.0
#
#                                              Facility Name Zip Code - 3 digits
# 0                         Montefiore Mount Vernon Hospital                 105
# 1                         Montefiore Mount Vernon Hospital                 105
# 2                         Montefiore Mount Vernon Hospital                 105
# 3                         Montefiore Mount Vernon Hospital                 105
# 4                         Montefiore Mount Vernon Hospital                 105
# ...                                                    ...                 ...
# 2343564                 Good Samaritan Hospital of Suffern                 109
# 2343565                 Good Samaritan Hospital of Suffern                 109
# 2343566                 Good Samaritan Hospital of Suffern                 109
# 2343567  Montefiore Med Center - Jack D Weiler Hosp of ...                 104
# 2343568                            St James Mercy Hospital                 148
#
# [2338179 rows x 5 columns]

# %%
geo.isnull().sum()
# Out:
# Hospital Service Area    0
# Hospital County          0
# Permanent Facility Id    0
# Facility Name            0
# Zip Code - 3 digits      0
# dtype: int64

# %%
vernon = geo[geo['Facility Name']== 'Montefiore Mount Vernon Hospital']
vernon
# Out:
#         Hospital Service Area Hospital County  Permanent Facility Id  \
# 0               Hudson Valley     Westchester                 1061.0
# 1               Hudson Valley     Westchester                 1061.0
# 2               Hudson Valley     Westchester                 1061.0
# 3               Hudson Valley     Westchester                 1061.0
# 4               Hudson Valley     Westchester                 1061.0
# ...                       ...             ...                    ...
# 2291379         Hudson Valley     Westchester                 1061.0
# 2291382         Hudson Valley     Westchester                 1061.0
# 2291386         Hudson Valley     Westchester                 1061.0
# 2291389         Hudson Valley     Westchester                 1061.0
# 2343553         Hudson Valley     Westchester                 1061.0
#
#                             Facility Name Zip Code - 3 digits
# 0        Montefiore Mount Vernon Hospital                 NaN
# 1        Montefiore Mount Vernon Hospital                 105
# 2        Montefiore Mount Vernon Hospital                 105
# 3        Montefiore Mount Vernon Hospital                 105
# 4        Montefiore Mount Vernon Hospital                 105
# ...                                   ...                 ...
# 2291379  Montefiore Mount Vernon Hospital                 105
# 2291382  Montefiore Mount Vernon Hospital                 104
# 2291386  Montefiore Mount Vernon Hospital                 105
# 2291389  Montefiore Mount Vernon Hospital                 105
# 2343553  Montefiore Mount Vernon Hospital                 105
#
# [3031 rows x 5 columns]

# %%
vernon['Zip Code - 3 digits'].value_counts(dropna= False, normalize= True)
# Out:
# 105    0.730782
# 125    0.072583
# 108    0.065985
# 104    0.055097
# NaN    0.037281
# 107    0.022105
# 106    0.005609
# OOS    0.004289
# 127    0.001980
# 112    0.001320
# 126    0.000990
# 114    0.000660
# 109    0.000660
# 100    0.000660
# Name: Zip Code - 3 digits, dtype: float64

# %%
westchester = geo[geo['Hospital County']== 'Westchester']
westchester
# Out:
#         Hospital Service Area Hospital County  Permanent Facility Id  \
# 0               Hudson Valley     Westchester                 1061.0
# 1               Hudson Valley     Westchester                 1061.0
# 2               Hudson Valley     Westchester                 1061.0
# 3               Hudson Valley     Westchester                 1061.0
# 4               Hudson Valley     Westchester                 1061.0
# ...                       ...             ...                    ...
# 2338420         Hudson Valley     Westchester                 1117.0
# 2338421         Hudson Valley     Westchester                 1117.0
# 2340790         Hudson Valley     Westchester                 1072.0
# 2343008         Hudson Valley     Westchester                 1047.0
# 2343553         Hudson Valley     Westchester                 1061.0
#
#                                              Facility Name Zip Code - 3 digits
# 0                         Montefiore Mount Vernon Hospital                 NaN
# 1                         Montefiore Mount Vernon Hospital                 105
# 2                         Montefiore Mount Vernon Hospital                 105
# 3                         Montefiore Mount Vernon Hospital                 105
# 4                         Montefiore Mount Vernon Hospital                 105
# ...                                                    ...                 ...
# 2338420                      Northern Westchester Hospital                 125
# 2338421                      Northern Westchester Hospital                 105
# 2340790                   Montefiore New Rochelle Hospital                 NaN
# 2343008  New York Presbyterian Hospital - Westchester D...                 104
# 2343553                   Montefiore Mount Vernon Hospital                 105
#
# [119296 rows x 5 columns]

# %%
westchester['Zip Code - 3 digits'].value_counts(dropna= False, normalize= True)
# Out:
# 105    0.394682
# 107    0.191683
# 104    0.090531
# 106    0.066574
# 108    0.056448
# 109    0.041167
# 125    0.037386
# 100    0.026598
# OOS    0.025407
# NaN    0.019347
# 112    0.014351
# 127    0.007611
# 126    0.006505
# 124    0.004510
# 113    0.003873
# 117    0.002532
# 114    0.002355
# 115    0.001450
# 111    0.001308
# 103    0.001048
# 120    0.000704
# 101    0.000553
# 119    0.000545
# 116    0.000453
# 110    0.000360
# 128    0.000327
# 121    0.000293
# 123    0.000268
# 122    0.000251
# 133    0.000117
# 139    0.000084
# 118    0.000075
# 148    0.000075
# 145    0.000075
# 134    0.000059
# 129    0.000059
# 137    0.000059
# 132    0.000050
# 149    0.000042
# 142    0.000042
# 146    0.000034
# 138    0.000034
# 130    0.000025
# 141    0.000017
# 136    0.000017
# 140    0.000017
# Name: Zip Code - 3 digits, dtype: float64

# %% [markdown]
# Make a true/false column for if the patient lives in the same county as the hospital is located
# - Make a list of zip code prefixes that the county includes, plus NaN values as we will assume they were in the county as that is the majority
# - Then if the value in column 'Zip Code - 3 digits' is in the list, return true. Else return flase
# - Put these results in a new column called 'In County'

# %%
westchester_zip_codes = ['105', '106', '107', '108', np.nan]

# %%
in_westchester= westchester['Zip Code - 3 digits'].isin(westchester_zip_codes)
in_westchester
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 2338420    False
# 2338421     True
# 2340790     True
# 2343008    False
# 2343553     True
# Name: Zip Code - 3 digits, Length: 119296, dtype: bool

# %%
in_westchester.value_counts(normalize=True)
# Out:
# True     0.728734
# False    0.271266
# Name: Zip Code - 3 digits, dtype: float64

# %%
len(geo['Hospital County'].value_counts())
# Out:
# 57

# %% [markdown]
# ### Linear Classification Model
# - Logistic regression
# - SVC (Support Vector Classification)

# %% [markdown]
# ### Partial Dependence Plot - 1 Isolated Variable

# %%
# # Install pdpbox in anaconda environment
# conda install -c conda-forge pdpbox
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/stevenchase/opt/anaconda3/envs/yourenvname
#
#   added / updated specs:
#     - pdpbox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pdpbox-0.2.0               |             py_0        55.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        55.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pdpbox             conda-forge/noarch::pdpbox-0.2.0-py_0
#
#
#
# Downloading and Extracting Packages
# pdpbox-0.2.0         | 55.1 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use Ordinal Encoder, outside of a pipeline, no scaler to increase readabliity

encoder = ce.OrdinalEncoder()
X_val_encoded = encoder.fit_transform(X_val)
X_train_encoded = encoder.fit_transform(X_train)

# %%
# Import Partial Dependence Plot
from pdpbox.pdp import pdp_isolate, pdp_plot

# %%
# Model plot

# Choose feature
feature = 'Age Group'

# Set model
isolated = pdp_isolate(
    model= model,
    dataset= pd.DataFrame(X_val_encoded, columns= X_val.columns),
    model_features= X_val.columns,
    feature = feature
)

# View plot
pdp_plot(isolated, feature);

# %%
# # View plot
# pdp_plot(isolated, feature);

# %% [markdown]
# ### PDP with Two Interacting Variables

# %%
# Partial Dependence Plot with 2 fetures

# Import
from pdpbox.pdp import pdp_interact, pdp_interact_plot

# Define features you want to examine
features = ['Age Group', 'Type of Admission']

# Create Model
interaction = pdp_interact(
    model= model, 
    dataset= pd.DataFrame(X_val_encoded, columns= X_val.columns),
    model_features= X_val.columns,
    features= features
)

# Plot Results
pdp_interact_plot(interaction, plot_type='grid', feature_names=features);

# %% [markdown]
# ### Shapley Force Plot

# %%
# Install shap in anaconda environment
# conda install -c conda-forge shap
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/stevenchase/opt/anaconda3/envs/yourenvname
#
#   added / updated specs:
#     - shap
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libcxx-9.0.1               |                1        1011 KB  conda-forge
#     shap-0.35.0                |   py37h94625e5_0         394 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   shap               conda-forge/osx-64::shap-0.35.0-py37h94625e5_0
#
# The following packages will be UPDATED:
#
#   libcxx                 pkgs/main::libcxx-4.0.1-hcfea43d_1 --> conda-forge::libcxx-9.0.1-1
#
#
#
# Downloading and Extracting Packages
# libcxx-9.0.1         | 1011 KB   | ##################################### | 100%
# shap-0.35.0          | 394 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import shap
import shap

# %%
# Pick row of test to examine
row= X_val.iloc[[0]]
row
# Out:
#         Age Group Gender   Race          Ethnicity Length of Stay  \
# 1983797  30 to 49      M  White  Not Span/Hispanic              1
#
#         Type of Admission  CCS Diagnosis Code  CCS Procedure Code  \
# 1983797          Elective                  58                  74
#
#          APR DRG Code  APR MDC Code APR Medical Surgical Description  \
# 1983797           403            10                         Surgical
#
#              Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# 1983797  Blue Cross/Blue Shield               None               None
#
#         Abortion Edit Indicator Emergency Department Indicator  \
# 1983797                       N                              N
#
#         Zip Code - 3 digits Hospital Service Area Hospital County  \
# 1983797                 110           Long Island          Nassau
#
#                            Facility Name
# 1983797  North Shore University Hospital

# %%
# Get Shapley values
explainer = shap.TreeExplainer(model)
row_processed = processor.transform(row)
shap_values = explainer.shap_values(row_processed)

# Plot
shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value[0], 
    shap_values=shap_values[0], 
    features=row, 
    link='logit' 
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iV0CLLKUSRQ6MIRLS6XFC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": 0.5706218580204167, "outValue": 0.9414521543563876, "link": "logit", "featureNames": ["Age Group", "Gender", "Race", "Ethnicity", "Length of Stay", "Type of Admission", "CCS Diagnosis Code", "CCS Procedure Code", "APR DRG Code", "APR MDC Code", "APR Medical Surgical Description", "Payment Typology 1", "Payment Typology 2", "Payment Typology 3", "Abortion Edit Indicator", "Emergency Department Indicator", "Zip Code - 3 digits", "Hospital Service Area", "Hospital County", "Facility Name"], "features": {"0": {"effect": 0.1110337474020616, "value": "30 to 49"}, "1": {"effect": -0.011512395149103299, "value": "M"}, "2": {"effect": 0.0014598810609946224, "value": "White"}, "3": {"effect": 3.771666553700709e-05, "value": "Not Span/Hispanic"}, "4": {"effect": 0.12481143519484056, "value": "1"}, "5": {"effect": 0.06718969188749144, "value": "Elective"}, "6": {"effect": -0.057493526245382995, "value": 58}, "7": {"effect": -0.005382430045415334, "value": 74}, "8": {"effect": 0.021321378330820866, "value": 403}, "9": {"effect": 0.013753652017115486, "value": 10}, "10": {"effect": 0.029177942141391393, "value": "Surgical"}, "11": {"effect": 0.01996683263691081, "value": "Blue Cross/Blue Shield"}, "12": {"effect": 0.007112294242324643, "value": "None"}, "13": {"effect": 0.004811413966666447, "value": "None"}, "15": {"effect": 0.04779419998457752, "value": "N"}, "16": {"effect": -0.007635829769153247, "value": "110"}, "17": {"effect": 0.003760314016862051, "value": "Long Island"}, "18": {"effect": 0.0027911261239587496, "value": "Nassau"}, "19": {"effect": -0.0021671481265274272, "value": "North Shore University Hospital"}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iV0CLLKUSRQ6MIRLS6XFC')
#   );
# </script>

# %%
explainer = shap.TreeExplainer(model)
row_processed = processor.transform(row)
shap_values = explainer.shap_values(row_processed)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value[1], 
    shap_values=shap_values[1], 
    features=row, 
    link='logit' # For classification, this shows predicted probabilities (Sigmound curve)
)

# Changing to logit type for classification
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i4F380NAHXN45WFZQZN63'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": 0.21695917908258963, "outValue": 0.057816015995358266, "link": "logit", "featureNames": ["Age Group", "Gender", "Race", "Ethnicity", "Length of Stay", "Type of Admission", "CCS Diagnosis Code", "CCS Procedure Code", "APR DRG Code", "APR MDC Code", "APR Medical Surgical Description", "Payment Typology 1", "Payment Typology 2", "Payment Typology 3", "Abortion Edit Indicator", "Emergency Department Indicator", "Zip Code - 3 digits", "Hospital Service Area", "Hospital County", "Facility Name"], "features": {"0": {"effect": -0.05492951418481394, "value": "30 to 49"}, "1": {"effect": 0.0064802084035307595, "value": "M"}, "2": {"effect": -0.001838269106511132, "value": "White"}, "3": {"effect": -0.0004162811688025288, "value": "Not Span/Hispanic"}, "4": {"effect": -0.04518481729263833, "value": "1"}, "5": {"effect": -0.034513088559518595, "value": "Elective"}, "6": {"effect": 0.035273272057002515, "value": 58}, "7": {"effect": 0.00010437206287714809, "value": 74}, "8": {"effect": -0.00638281329451229, "value": 403}, "9": {"effect": -0.0028055058425072122, "value": 10}, "10": {"effect": -0.021428833953404978, "value": "Surgical"}, "11": {"effect": -0.007771554274466637, "value": "Blue Cross/Blue Shield"}, "12": {"effect": -0.004786675455807221, "value": "None"}, "13": {"effect": -0.002733965214917828, "value": "None"}, "15": {"effect": -0.020422522558766695, "value": "N"}, "16": {"effect": 0.005474446182671216, "value": "110"}, "17": {"effect": -0.00295950662110625, "value": "Long Island"}, "18": {"effect": -0.0019653213685537733, "value": "Nassau"}, "19": {"effect": 0.0016632071030143784, "value": "North Shore University Hospital"}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i4F380NAHXN45WFZQZN63')
#   );
# </script>

# %%
explainer = shap.TreeExplainer(model)
row_processed = processor.transform(row)
shap_values = explainer.shap_values(row_processed)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value[2], 
    shap_values=shap_values[2], 
    features=row, 
    link='logit' # For classification, this shows predicted probabilities (Sigmound curve)
)

# Changing to logit type for classification
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i6WUJEF0UW7CG7DQE4572'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": 0.161672477081723, "outValue": 0.0007318296482645981, "link": "logit", "featureNames": ["Age Group", "Gender", "Race", "Ethnicity", "Length of Stay", "Type of Admission", "CCS Diagnosis Code", "CCS Procedure Code", "APR DRG Code", "APR MDC Code", "APR Medical Surgical Description", "Payment Typology 1", "Payment Typology 2", "Payment Typology 3", "Abortion Edit Indicator", "Emergency Department Indicator", "Zip Code - 3 digits", "Hospital Service Area", "Hospital County", "Facility Name"], "features": {"0": {"effect": -0.0456514584964962, "value": "30 to 49"}, "1": {"effect": 0.003764871585057595, "value": "M"}, "2": {"effect": 0.0002393208555251135, "value": "White"}, "3": {"effect": 0.00023687819162513944, "value": "Not Span/Hispanic"}, "4": {"effect": -0.06343418046736053, "value": "1"}, "5": {"effect": -0.024224330522169386, "value": "Elective"}, "6": {"effect": 0.02147237090731349, "value": 58}, "7": {"effect": 0.004076155025048084, "value": 74}, "8": {"effect": -0.006808526917133115, "value": 403}, "9": {"effect": -0.005411409990657238, "value": 10}, "10": {"effect": -0.012499947196217458, "value": "Surgical"}, "11": {"effect": -0.010183716716834313, "value": "Blue Cross/Blue Shield"}, "12": {"effect": -0.0020545044096438704, "value": "None"}, "13": {"effect": -0.001755627526216622, "value": "None"}, "15": {"effect": -0.018400075520850788, "value": "N"}, "16": {"effect": 0.0015821770151726365, "value": "110"}, "17": {"effect": -0.0005870927550118129, "value": "Long Island"}, "18": {"effect": -0.0012611941077769412, "value": "Nassau"}, "19": {"effect": -4.035638683214727e-05, "value": "North Shore University Hospital"}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i6WUJEF0UW7CG7DQE4572')
#   );
# </script>

# %%
explainer = shap.TreeExplainer(model)
row_processed = processor.transform(row)
shap_values = explainer.shap_values(row_processed)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value[3], 
    shap_values=shap_values[3], 
    features=row, 
    link='logit' # For classification, this shows predicted probabilities (Sigmound curve)
)

# Changing to logit type for classification
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iTAHKH9A6MO90IHEDZOBZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": 0.050746485815270526, "outValue": -2.0816681711721685e-17, "link": "logit", "featureNames": ["Age Group", "Gender", "Race", "Ethnicity", "Length of Stay", "Type of Admission", "CCS Diagnosis Code", "CCS Procedure Code", "APR DRG Code", "APR MDC Code", "APR Medical Surgical Description", "Payment Typology 1", "Payment Typology 2", "Payment Typology 3", "Abortion Edit Indicator", "Emergency Department Indicator", "Zip Code - 3 digits", "Hospital Service Area", "Hospital County", "Facility Name"], "features": {"0": {"effect": -0.010452774720749802, "value": "30 to 49"}, "1": {"effect": 0.0012673151605146636, "value": "M"}, "2": {"effect": 0.0001390671899914646, "value": "White"}, "3": {"effect": 0.00014168631164034404, "value": "Not Span/Hispanic"}, "4": {"effect": -0.01619243743483588, "value": "1"}, "5": {"effect": -0.0084522728058018, "value": "Elective"}, "6": {"effect": 0.0007478832810676699, "value": 58}, "7": {"effect": 0.0012019029574903428, "value": 74}, "8": {"effect": -0.00813003811917524, "value": 403}, "9": {"effect": -0.005536736183950171, "value": 10}, "10": {"effect": 0.004750839008231634, "value": "Surgical"}, "11": {"effect": -0.0020115616456101554, "value": "Blue Cross/Blue Shield"}, "12": {"effect": -0.00027111437687380927, "value": "None"}, "13": {"effect": -0.00032182122553219017, "value": "None"}, "15": {"effect": -0.008971601904960404, "value": "N"}, "16": {"effect": 0.0005792065713097291, "value": "110"}, "17": {"effect": -0.00021371464074397502, "value": "Long Island"}, "18": {"effect": 0.0004353893523718808, "value": "Nassau"}, "19": {"effect": 0.0005442974103451527, "value": "North Shore University Hospital"}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iTAHKH9A6MO90IHEDZOBZ')
#   );
# </script>
