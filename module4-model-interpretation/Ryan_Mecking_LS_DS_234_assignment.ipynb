# %% [markdown]
# <a href="https://colab.research.google.com/github/rsmecking/DS-Unit-2-Applied-Modeling/blob/master/module4-model-interpretation/Ryan_Mecking_LS_DS_234_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv (r'C:\Users\Ryan\Desktop\Coding Stuffs\Project 2 stuff/Datafiniti_Womens_Shoes_Jun19.csv')
print (df.shape)
df.head(3)
# Out:
# (10000, 32)
#                      id             dateAdded           dateUpdated asins  \
# 0  AWpyySsJAGTnQPR7wNt4  2019-05-01T09:27:22Z  2019-05-01T09:27:22Z   NaN
# 1  AWpyyyb3AGTnQPR7wN-u  2019-05-01T09:27:19Z  2019-05-01T09:27:19Z   NaN
# 2  AWpyzlajAGTnQPR7wOX8  2019-05-01T09:26:59Z  2019-05-01T09:26:59Z   NaN
#
#              brand                                    categories  \
# 0  City Classified  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 1         Skechers  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 2           Floral  Clothing,Shoes,Womens Shoes,All Womens Shoes
#
#   primaryCategories colors dimension     ean / upc  ...  \
# 0             Shoes  Black       NaN  656000000000  ...
# 1             Shoes  Taupe       NaN  192000000000  ...
# 2             Shoes  Black       NaN  709000000000  ...
#
#             prices.dateSeen prices.isSale prices.merchant prices.offer  \
# 0      2019-04-19T07:09:29Z           NaN             NaN  Online only
# 1      2019-04-24T09:14:11Z           NaN             NaN  Online only
# 2  2019-04-25T12:35:00.000Z           NaN             NaN  Online only
#
#   prices.returnPolicy  prices.shipping  prices.size  \
# 0                 NaN              NaN            8
# 1                 NaN              NaN       6 M US
# 2                 NaN              NaN            5
#
#                                    prices.sourceURLs   sizes  \
# 0  https://www.walmart.com/ip/City-Classified-Sty...       8
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...  6 M US
# 2  https://www.walmart.com/ip/FLORAL-Pearl-Women-...       5
#
#                                           sourceURLs
# 0  https://www.walmart.com/ip/City-Classified-Sty...
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...
# 2  https://www.walmart.com/ip/FLORAL-Pearl-Women-...
#
# [3 rows x 32 columns]

# %%
#Averaging out price of shoe. Most values were the same so it was basically a duplicate column
df['price'] = (df['prices.amountMin'] + df['prices.amountMax'])/2
df.shape
# Out:
# (10000, 33)

# %%
# Dropping now useless columns.
df = df.drop(['prices.amountMin', 'prices.amountMax'], axis=1)
df.shape
# Out:
# (10000, 31)

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AWpyySsJAGTnQPR7wNt4  2019-05-01T09:27:22Z  2019-05-01T09:27:22Z   NaN
# 1  AWpyyyb3AGTnQPR7wN-u  2019-05-01T09:27:19Z  2019-05-01T09:27:19Z   NaN
# 2  AWpyzlajAGTnQPR7wOX8  2019-05-01T09:26:59Z  2019-05-01T09:26:59Z   NaN
# 3  AWpyxomE0U_gzG0hkA1q  2019-05-01T09:26:56Z  2019-05-01T09:26:56Z   NaN
# 4  AWpyxChWJbEilcB6RhWx  2019-05-01T09:26:56Z  2019-05-01T09:26:56Z   NaN
#
#              brand                                    categories  \
# 0  City Classified  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 1         Skechers  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 2           Floral  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 3            Jambu  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 4         Trotters  Clothing,Shoes,Womens Shoes,All Womens Shoes
#
#   primaryCategories       colors dimension     ean / upc  ... prices.isSale  \
# 0             Shoes        Black       NaN  656000000000  ...           NaN
# 1             Shoes        Taupe       NaN  192000000000  ...           NaN
# 2             Shoes        Black       NaN  709000000000  ...           NaN
# 3             Shoes  Black/Multi       NaN  884000000000  ...           NaN
# 4             Shoes        White       NaN  887000000000  ...           NaN
#
#   prices.merchant          prices.offer prices.returnPolicy prices.shipping  \
# 0             NaN           Online only                 NaN             NaN
# 1             NaN           Online only                 NaN             NaN
# 2             NaN           Online only                 NaN             NaN
# 3             NaN  Online only: 20% off                 NaN             NaN
# 4             NaN  Online only: 50% off                 NaN             NaN
#
#    prices.size                                  prices.sourceURLs      sizes  \
# 0            8  https://www.walmart.com/ip/City-Classified-Sty...          8
# 1       6 M US  https://www.walmart.com/ip/Skechers-Women-S-Yo...     6 M US
# 2            5  https://www.walmart.com/ip/FLORAL-Pearl-Women-...          5
# 3    9.5 BM US  https://www.walmart.com/ip/Jambu-Women-s-AMAL-...  9.5 BM US
# 4           11  https://www.walmart.com/ip/Women-s-Trotters-Bl...         11
#
#                                           sourceURLs   price
# 0  https://www.walmart.com/ip/City-Classified-Sty...   29.95
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...   84.00
# 2  https://www.walmart.com/ip/FLORAL-Pearl-Women-...   49.95
# 3  https://www.walmart.com/ip/Jambu-Women-s-AMAL-...  127.20
# 4  https://www.walmart.com/ip/Women-s-Trotters-Bl...   47.66
#
# [5 rows x 31 columns]

# %%
# df['prices.size'].value_counts()

# %%
df['price'].describe()
# Out:
# count    10000.000000
# mean        72.202721
# std        172.400446
# min          5.500000
# 25%         34.990000
# 50%         52.485000
# 75%         83.962500
# max       5000.000000
# Name: price, dtype: float64

# %%
#Removing outliers 
df = df[(df['price'] <= np.percentile(df['price'], 99.5))]
df.shape
# Out:
# (9950, 31)

# %%
df['price'].describe()
# Out:
# count    9950.000000
# mean       65.168357
# std        40.993896
# min         5.500000
# 25%        34.990000
# 50%        52.200000
# 75%        83.682500
# max       260.590000
# Name: price, dtype: float64

# %%
# df['price'].value_counts().head(50)

# %%
#Filling in missing values with word "missing" for imputing reason
df = df.fillna("Missing")

# %%
#Making all upper casing to lower casing in name/color columns
df['name'] = df['name'].str.lower()
df['prices.color'] = df['prices.color'].str.lower()

# %%
# Looking for most common used words in 'name' column.
df1 = (df['name'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))
# df1.head(10)

# %%
df1 = df1.replace(["women's", 'womens', "/", "-", 'on', 'co.', 'by',
                   'and'], "Missing")
# df1['vals'].values[:200]

# %%
# Looking for most common used words in 'color' column.
df2 = (df['colors'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))
# df2.head(50)

# %%
df2 = df2.replace(["/"], "Multi")
# df2['vals'].values[:200]

# %%
#categories size
df3 = (df['categories'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))
# df3.head(60)

# %%
# df3 = df3.replace(["Standard", 'Women', "/", "-", 'Size', 'US', 'BM'], "Multi")
# # df3['vals'].values[:58]

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, train_size=0.80, test_size=0.20, 
                               random_state=42)
train.shape, test.shape
# Out:
# ((7960, 31), (1990, 31))

# %%
train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              random_state=42)
train.shape, val.shape
# Out:
# ((6368, 31), (1592, 31))

# %%
#imports
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor 
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import mean_absolute_error
import plotly.express as px
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from pdpbox import pdp

# %%
#Features

def wrangle(X):
    
    # Prevent SettingWithCopyWarning
    X = X.copy()
    
    #Top descriptive words from 'name' column  
    mylist = df1['vals'].values[:150]
    
    for i in mylist:
        X[i] = X['name'].str.contains(i) 
    
    #Top descriptive words from 'prices.color' column  
    color_list = df2['vals'].values[:200]
    
    for j in color_list:
        X[j] = X['prices.color'].str.contains(j)
    
#     #Top descriptive words from 'Size' column  
#     size_list = df3['vals'].values[:58]
    
#     for k in size_list:
#         X[k] = X['prices.size'].str.contains(k) 
        
    # Does the shoe have a description?
    X['name'] = X['name'].str.strip().fillna('')
    X['has_description'] = X['name'] != ''

    # How long is the description?
    X['name_length'] = X['name'].str.len()
  
    #Dropping all columns with over 99% NaNs or repeated column.
    lon = ['dateAdded','dateUpdated', 'asins', 'primaryCategories','colors','dimension', 
           'imageURLs', 'keys', 'prices.dateAdded','prices.condition', 'prices.merchant', 
           'prices.dateSeen', 'prices.returnPolicy', 'prices.sourceURLs', 'sizes',                
           'prices.sourceURLs', 'prices.condition', 'sourceURLs', 'prices.size']
           
    X = X.drop(columns=lon, axis=1)
    
    #Removing seeding columns from above for loops.
    seeds= ['name', 'prices.color']
    X = X.drop(columns=seeds, axis=1)
    
    # return the wrangled dataframe
    return X

train = wrangle(train)
val = wrangle(val)
test = wrangle(test)
# Out:
# E:\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.

# %%
# The status_group column is the target
target = 'price'

# Get a dataframe with all train columns except the target
train_features = train.drop(columns=[target])

# Get a list of the numeric features
numeric_features = train_features.select_dtypes(include='number').columns.tolist()

# Get a series with the cardinality of the nonnumeric features
cardinality = train_features.select_dtypes(exclude='number').nunique()

# Get a list of all categorical features with cardinality 
categorical_features = cardinality[cardinality <= 550].index.tolist()

# Combine the lists 
features = numeric_features + categorical_features

# %%
#Target/Val assignment

X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((6368, 354), (1592, 354), (1990, 354))

# %%
X_train.head(50)
# Out:
#          ean / upc  name_length                       brand  \
# 7742  728816000000           28                         SAS
# 6628  812000000000           45                Genuine Grip
# 306   728000000000           60                      Carlos
# 5258  825000000000           43                   Aerosoles
# 9638  870000000000           66                 Brinley Co.
# 3775  885308000000           52                  David Tate
# 6823  756000000000           47                      Propet
# 4412  800000000000           60                     OwnShoe
# 5100  706000000000           64                      Alfani
# 9119  886000000000           25                      Propet
# 7919  706000000000           76  INC International Concepts
# 7280  886000000000           47                   Aerosoles
# 6336  191000000000           28              white-mountain
# 4505  666000000000           49                        Soda
# 8496  888000000000           73               Ros Hommerson
# 8070  848231000000           50                   Touch Ups
# 5515  887000000000           59                    Trotters
# 8346  885000000000           31                  David Tate
# 9229  886000000000           30                      Propet
# 356   884000000000           26                    Luichiny
# 9522  870000000000           53                 Brinley Co.
# 4729  729000000000           31                         SAS
# 5842  890000000000           55    L'Artiste by Spring Step
# 4593  885488000000           40          Pleaser Pink Label
# 1652  708750000000           88                      Floral
# 8016  729000000000           41                         SAS
# 9061  886000000000           25                      Propet
# 4530  885000000000           50          Pleaser Pink Label
# 8436  767000000000           70          Karyn's Collection
# 4431  810000000000           82             Exotic Identity
# 4402  191000000000           56                     Rampage
# 65    796000000000           41                    Callisto
# 3242  888000000000           22                     Bellini
# 1985  729000000000           35                         SAS
# 2726  884000000000           36                       Jambu
# 7199  846137000000           33            The Highest Heel
# 9825  756000000000           28                      Propet
# 6849  886000000000           47                      Propet
# 2207  791000000000           84                        Soda
# 7320  791000000000           67                        Soda
# 4143  888000000000           16                        Drew
# 3777  885308000000           52                  David Tate
# 1075  689355000000           52                    Shoelala
# 9880  756000000000           28                      Propet
# 7447  729000000000           34                         SAS
# 210   887278000000           62                        Mozo
# 4329  825000000000           45                   Aerosoles
# 4651  791117000000           73                        Soda
# 7338  689000000000           71                  Soda Shoes
# 5721  887000000000           50                    Trotters
#
#                                              categories manufacturer  \
# 7742       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 6628       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
# 306        Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 5258       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 9638  Womens Flats D*Orsay,Womens Shoes,Women's Shoe...  Brinley Co.
# 3775       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 6823       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4412       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 5100       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
# 9119  Womens Shoes,Clothing,All Womens Comfort,Dress...       Propet
# 7919       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 7280       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 6336       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4505       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 8496       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
# 8070       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 5515       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 8346       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 9229  Women,Womens Shoes,Clothing,Women's Shoes,All ...       Propet
# 356        Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 9522  All Womens Flats,Womens Shoes,Women's Shoes,Cl...  Brinley Co.
# 4729       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 5842       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4593       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 1652       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 8016       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
# 9061  Womens Shoes,Clothing,All Womens Comfort,Dress...       Propet
# 4530       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 8436       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4431       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4402       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 65         Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 3242       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 1985       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 2726       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 7199       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 9825  Womens Shoes,Clothing,Women's Shoes,All Womens...       Propet
# 6849       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 2207       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 7320       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
# 4143       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
# 3777       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 1075       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 9880  Womens Shoes,Clothing,Women's Shoes,All Womens...       Propet
# 7447       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 210        Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4329       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 4651       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 7338       Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 5721       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
#
#      manufacturerNumber  prices.availability prices.currency prices.isSale  \
# 7742            Missing                False             USD       Missing
# 6628            Missing                 True             USD       Missing
# 306             Missing                 True             USD       Missing
# 5258            Missing                 True             USD       Missing
# 9638      ELLIE-BLU-060                 True             USD         False
# 3775            Missing                False             USD       Missing
# 6823            Missing                False             USD       Missing
# 4412            Missing                 True             USD       Missing
# 5100            Missing                 True             USD       Missing
# 9119          W3247-BLU                False             USD         False
# 7919            Missing                 True             USD       Missing
# 7280            Missing                 True             USD       Missing
# 6336            Missing                 True             USD       Missing
# 4505            Missing                False             USD       Missing
# 8496            Missing                False             USD       Missing
# 8070            Missing                 True             USD       Missing
# 5515            Missing                False             USD       Missing
# 8346            Missing                False             USD       Missing
# 9229             W4412N                 True             USD         False
# 356             Missing                 True             USD       Missing
# 9522       EDIE-RGD-060                 True             USD         False
# 4729            Missing                False             USD       Missing
# 5842            Missing                False             USD       Missing
# 4593            Missing                 True             USD       Missing
# 1652            Missing                 True             USD       Missing
# 8016        BLISS BLACK                 True             USD       Missing
# 9061          W3247-BLU                False             USD         False
# 4530            Missing                 True             USD       Missing
# 8436            Missing                False             USD       Missing
# 4431            Missing                 True             USD       Missing
# 4402            Missing                 True             USD       Missing
# 65              Missing                 True             USD       Missing
# 3242            Missing                 True             USD       Missing
# 1985            Missing                False             USD       Missing
# 2726            Missing                False             USD       Missing
# 7199            Missing                 True             USD       Missing
# 9825         W0001BLBLU                 True             USD         False
# 6849            Missing                False             USD       Missing
# 2207            Missing                False             USD       Missing
# 7320            Missing                False             USD       Missing
# 4143            Missing                 True             USD       Missing
# 3777            Missing                False             USD       Missing
# 1075            Missing                False             USD       Missing
# 9880         W0001BLBLU                 True             USD         False
# 7447            Missing                 True             USD       Missing
# 210             Missing                 True             USD       Missing
# 4329            Missing                 True             USD       Missing
# 4651            Missing                False             USD       Missing
# 7338            Missing                False             USD       Missing
# 5721            Missing                False             USD       Missing
#
#               prices.offer  ...    Doe    Off  Lizard  Brushed   GREY  Indigo  \
# 7742           Online only  ...  False  False   False    False  False   False
# 6628  Online only: 24% off  ...  False  False   False    False  False   False
# 306   Online only: 52% off  ...  False  False   False    False  False   False
# 5258  Online only: 20% off  ...  False  False   False    False  False   False
# 9638  Online only: 64% off  ...  False  False   False    False  False   False
# 3775           Online only  ...  False  False   False    False  False   False
# 6823           Online only  ...  False  False   False    False  False   False
# 4412           Online only  ...  False  False   False    False  False   False
# 5100  Online only: 61% off  ...  False  False   False    False  False   False
# 9119           Online only  ...  False  False   False    False  False   False
# 7919  Online only: 28% off  ...  False  False   False    False  False   False
# 7280           Online only  ...  False  False   False    False  False   False
# 6336           Online only  ...  False  False   False    False  False   False
# 4505           Online only  ...  False  False   False    False  False   False
# 8496           Online only  ...  False  False   False    False  False   False
# 8070           Online only  ...  False  False   False    False  False   False
# 5515           Online only  ...  False  False   False    False  False   False
# 8346           Online only  ...  False  False   False    False  False   False
# 9229           Online only  ...  False  False   False    False  False   False
# 356   Online only: 69% off  ...  False  False   False    False  False   False
# 9522  Online only: 55% off  ...  False  False   False    False  False   False
# 4729           Online only  ...  False  False   False    False  False   False
# 5842           Online only  ...  False  False   False    False  False   False
# 4593           Online only  ...  False  False   False    False  False   False
# 1652           Online only  ...  False  False   False    False  False   False
# 8016           Online only  ...  False  False   False    False  False   False
# 9061           Online only  ...  False  False   False    False  False   False
# 4530           Online only  ...  False  False   False    False  False   False
# 8436           Online only  ...  False  False   False    False  False   False
# 4431  Online only: 78% off  ...  False  False   False    False  False   False
# 4402  Online only: 66% off  ...  False  False   False    False  False   False
# 65    Online only: 37% off  ...  False  False   False    False  False   False
# 3242           Online only  ...  False  False   False    False  False   False
# 1985           Online only  ...  False  False   False    False  False   False
# 2726           Online only  ...  False  False   False    False  False   False
# 7199           Online only  ...  False  False   False    False  False   False
# 9825           Online only  ...  False  False   False    False  False   False
# 6849           Online only  ...  False  False   False    False  False   False
# 2207           Online only  ...  False  False   False    False  False   False
# 7320           Online only  ...  False  False   False    False  False   False
# 4143           Online only  ...  False  False   False    False  False   False
# 3777           Online only  ...  False  False   False    False  False   False
# 1075           Online only  ...  False  False   False    False  False   False
# 9880           Online only  ...  False  False   False    False  False   False
# 7447           Online only  ...  False  False   False    False  False   False
# 210            Online only  ...  False  False   False    False  False   False
# 4329  Online only: 31% off  ...  False  False   False    False  False   False
# 4651           Online only  ...  False  False   False    False  False   False
# 7338           Online only  ...  False  False   False    False  False   False
# 5721           Online only  ...  False  False   False    False  False   False
#
#       Lambskin   Teal  Coral  has_description
# 7742     False  False  False             True
# 6628     False  False  False             True
# 306      False  False  False             True
# 5258     False  False  False             True
# 9638     False  False  False             True
# 3775     False  False  False             True
# 6823     False  False  False             True
# 4412     False  False  False             True
# 5100     False  False  False             True
# 9119     False  False  False             True
# 7919     False  False  False             True
# 7280     False  False  False             True
# 6336     False  False  False             True
# 4505     False  False  False             True
# 8496     False  False  False             True
# 8070     False  False  False             True
# 5515     False  False  False             True
# 8346     False  False  False             True
# 9229     False  False  False             True
# 356      False  False  False             True
# 9522     False  False  False             True
# 4729     False  False  False             True
# 5842     False  False  False             True
# 4593     False  False  False             True
# 1652     False  False  False             True
# 8016     False  False  False             True
# 9061     False  False  False             True
# 4530     False  False  False             True
# 8436     False  False  False             True
# 4431     False  False  False             True
# 4402     False  False  False             True
# 65       False  False  False             True
# 3242     False  False  False             True
# 1985     False  False  False             True
# 2726     False  False  False             True
# 7199     False  False  False             True
# 9825     False  False  False             True
# 6849     False  False  False             True
# 2207     False  False  False             True
# 7320     False  False  False             True
# 4143     False  False  False             True
# 3777     False  False  False             True
# 1075     False  False  False             True
# 9880     False  False  False             True
# 7447     False  False  False             True
# 210      False  False  False             True
# 4329     False  False  False             True
# 4651     False  False  False             True
# 7338     False  False  False             True
# 5721     False  False  False             True
#
# [50 rows x 354 columns]

# %%
X_train.dtypes
# Out:
# ean / upc           int64
# name_length         int64
# brand              object
# categories         object
# manufacturer       object
#                     ...
# Indigo               bool
# Lambskin             bool
# Teal                 bool
# Coral                bool
# has_description      bool
# Length: 354, dtype: object

# %%
y = df['price']
sns.distplot(y);

# %%
y_log = np.log1p(y)
sns.distplot(y_log)
plt.title('Log-transformed target, in log-dollars');

# %%
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='numpy')
warnings.filterwarnings(action='ignore', category=RuntimeWarning, module='sklearn')
warnings.filterwarnings(action='ignore', category=RuntimeWarning, module='scipy')

# %%
X_val = X_val[features]

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
print('R^2 Score=', pipeline.score(X_val, y_val))
# Out:
# R^2 Score= 0.645579375853303

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred_train = [y_train.mean()] * len(y_train)
y_pred_val  = [y_train.mean()] * len(y_val)

print('Mean Baseline:')
print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train, y_pred_train)))
print('val Root Mean Square Error:', np.sqrt(mean_squared_error(y_val, y_pred_val)))
print('Train Mean Absolute Error:', mean_absolute_error(y_train, y_pred_train))
print('val Mean Absolute Error:', mean_absolute_error(y_val, y_pred_val))
print('Train R^2 Score:', r2_score(y_train, y_pred_train))
print('val R^2 Score:', r2_score(y_val, y_pred_val))
# Out:
# Mean Baseline:
# Train Root Mean Squared Error: 41.40722877922959
# val Root Mean Square Error: 40.343225227898635
# Train Mean Absolute Error: 32.34957952154805
# val Mean Absolute Error: 32.02194338526833
# Train R^2 Score: -2.220446049250313e-16
# val R^2 Score: -9.672071927324666e-05

# %%
encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_val_scaled = scaler.transform(X_val_encoded)

for k in range(1, len(X_train_encoded.columns)+1):
    print(f'{k} features')
    
    selector = SelectKBest(score_func=f_regression, k=k)
    X_train_selected = selector.fit_transform(X_train_scaled, y_train)
    X_val_selected = selector.transform(X_val_scaled)
    
    model = LinearRegression()
    model.fit(X_train_selected, y_train)
    
    
    y_pred = model.predict(X_val_selected)
    mae = mean_absolute_error(y_val, y_pred)
    print(f'Test MAE: ${mae:,.0f} \n')
# Out:
# 1 features
# Test MAE: $29
#
# 2 features
# Test MAE: $28
#
# 3 features
# Test MAE: $27
#
# 4 features
# Test MAE: $27
#
# 5 features
# Test MAE: $26
#
# 6 features
# Test MAE: $26
#
# 7 features
# Test MAE: $26
#
# 8 features
# Test MAE: $26
#
# 9 features
# Test MAE: $26
#
# 10 features
# Test MAE: $25
#
# 11 features
# Test MAE: $25
#
# 12 features
# Test MAE: $24
#
# 13 features
# Test MAE: $24
#
# 14 features
# Test MAE: $24
#
# 15 features
# Test MAE: $24
#
# 16 features
# Test MAE: $24
#
# 17 features
# Test MAE: $23
#
# 18 features
# Test MAE: $23
#
# 19 features
# Test MAE: $23
#
# 20 features
# Test MAE: $23
#
# 21 features
# Test MAE: $23
#
# 22 features
# Test MAE: $23
#
# 23 features
# Test MAE: $23
#
# 24 features
# Test MAE: $23
#
# 25 features
# Test MAE: $23
#
# 26 features
# Test MAE: $23
#
# 27 features
# Test MAE: $23
#
# 28 features
# Test MAE: $23
#
# 29 features
# Test MAE: $23
#
# 30 features
# Test MAE: $23
#
# 31 features
# Test MAE: $23
#
# 32 features
# Test MAE: $23
#
# 33 features
# Test MAE: $23
#
# 34 features
# Test MAE: $23
#
# 35 features
# Test MAE: $23
#
# 36 features
# Test MAE: $23
#
# 37 features
# Test MAE: $23
#
# 38 features
# Test MAE: $23
#
# 39 features
# Test MAE: $22
#
# 40 features
# Test MAE: $22
#
# 41 features
# Test MAE: $22
#
# 42 features
# Test MAE: $22
#
# 43 features
# Test MAE: $22
#
# 44 features
# Test MAE: $22
#
# 45 features
# Test MAE: $22
#
# 46 features
# Test MAE: $22
#
# 47 features
# Test MAE: $22
#
# 48 features
# Test MAE: $22
#
# 49 features
# Test MAE: $22
#
# 50 features
# Test MAE: $22
#
# 51 features
# Test MAE: $22
#
# 52 features
# Test MAE: $22
#
# 53 features
# Test MAE: $22
#
# 54 features
# Test MAE: $22
#
# 55 features
# Test MAE: $21
#
# 56 features
# Test MAE: $22
#
# 57 features
# Test MAE: $22
#
# 58 features
# Test MAE: $22
#
# 59 features
# Test MAE: $22
#
# 60 features
# Test MAE: $22
#
# 61 features
# Test MAE: $21
#
# 62 features
# Test MAE: $21
#
# 63 features
# Test MAE: $21
#
# 64 features
# Test MAE: $21
#
# 65 features
# Test MAE: $21
#
# 66 features
# Test MAE: $21
#
# 67 features
# Test MAE: $21
#
# 68 features
# Test MAE: $21
#
# 69 features
# Test MAE: $21
#
# 70 features
# Test MAE: $21
#
# 71 features
# Test MAE: $21
#
# 72 features
# Test MAE: $21
#
# 73 features
# Test MAE: $21
#
# 74 features
# Test MAE: $21
#
# 75 features
# Test MAE: $21
#
# 76 features
# Test MAE: $21
#
# 77 features
# Test MAE: $21
#
# 78 features
# Test MAE: $21
#
# 79 features
# Test MAE: $21
#
# 80 features
# Test MAE: $21
#
# 81 features
# Test MAE: $21
#
# 82 features
# Test MAE: $21
#
# 83 features
# Test MAE: $21
#
# 84 features
# Test MAE: $21
#
# 85 features
# Test MAE: $21
#
# 86 features
# Test MAE: $21
#
# 87 features
# Test MAE: $21
#
# 88 features
# Test MAE: $21
#
# 89 features
# Test MAE: $21
#
# 90 features
# Test MAE: $21
#
# 91 features
# Test MAE: $21
#
# 92 features
# Test MAE: $21
#
# 93 features
# Test MAE: $21
#
# 94 features
# Test MAE: $21
#
# 95 features
# Test MAE: $20
#
# 96 features
# Test MAE: $21
#
# 97 features
# Test MAE: $20
#
# 98 features
# Test MAE: $21
#
# 99 features
# Test MAE: $21
#
# 100 features
# Test MAE: $21
#
# 101 features
# Test MAE: $20
#
# 102 features
# Test MAE: $20
#
# 103 features
# Test MAE: $20
#
# 104 features
# Test MAE: $20
#
# 105 features
# Test MAE: $20
#
# 106 features
# Test MAE: $20
#
# 107 features
# Test MAE: $20
#
# 108 features
# Test MAE: $20
#
# 109 features
# Test MAE: $20
#
# 110 features
# Test MAE: $20
#
# 111 features
# Test MAE: $20
#
# 112 features
# Test MAE: $20
#
# 113 features
# Test MAE: $20
#
# 114 features
# Test MAE: $20
#
# 115 features
# Test MAE: $20
#
# 116 features
# Test MAE: $20
#
# 117 features
# Test MAE: $20
#
# 118 features
# Test MAE: $20
#
# 119 features
# Test MAE: $20
#
# 120 features
# Test MAE: $20
#
# 121 features
# Test MAE: $20
#
# 122 features
# Test MAE: $20
#
# 123 features
# Test MAE: $20
#
# 124 features
# Test MAE: $20
#
# 125 features
# Test MAE: $20
#
# 126 features
# Test MAE: $20
#
# 127 features
# Test MAE: $20
#
# 128 features
# Test MAE: $20
#
# 129 features
# Test MAE: $20
#
# 130 features
# Test MAE: $20
#
# 131 features
# Test MAE: $20
#
# 132 features
# Test MAE: $20
#
# 133 features
# Test MAE: $20
#
# 134 features
# Test MAE: $20
#
# 135 features
# Test MAE: $20
#
# 136 features
# Test MAE: $20
#
# 137 features
# Test MAE: $20
#
# 138 features
# Test MAE: $20
#
# 139 features
# Test MAE: $20
#
# 140 features
# Test MAE: $20
#
# 141 features
# Test MAE: $20
#
# 142 features
# Test MAE: $20
#
# 143 features
# Test MAE: $20
#
# 144 features
# Test MAE: $20
#
# 145 features
# Test MAE: $20
#
# 146 features
# Test MAE: $20
#
# 147 features
# Test MAE: $20
#
# 148 features
# Test MAE: $20
#
# 149 features
# Test MAE: $20
#
# 150 features
# Test MAE: $20
#
# 151 features
# Test MAE: $20
#
# 152 features
# Test MAE: $20
#
# 153 features
# Test MAE: $20
#
# 154 features
# Test MAE: $20
#
# 155 features
# Test MAE: $20
#
# 156 features
# Test MAE: $20
#
# 157 features
# Test MAE: $20
#
# 158 features
# Test MAE: $20
#
# 159 features
# Test MAE: $20
#
# 160 features
# Test MAE: $20
#
# 161 features
# Test MAE: $20
#
# 162 features
# Test MAE: $20
#
# 163 features
# Test MAE: $20
#
# 164 features
# Test MAE: $20
#
# 165 features
# Test MAE: $20
#
# 166 features
# Test MAE: $20
#
# 167 features
# Test MAE: $20
#
# 168 features
# Test MAE: $20
#
# 169 features
# Test MAE: $20
#
# 170 features
# Test MAE: $20
#
# 171 features
# Test MAE: $20
#
# 172 features
# Test MAE: $20
#
# 173 features
# Test MAE: $20
#
# 174 features
# Test MAE: $20
#
# 175 features
# Test MAE: $20
#
# 176 features
# Test MAE: $20
#
# 177 features
# Test MAE: $20
#
# 178 features
# Test MAE: $20
#
# 179 features
# Test MAE: $20
#
# 180 features
# Test MAE: $20
#
# 181 features
# Test MAE: $20
#
# 182 features
# Test MAE: $20
#
# 183 features
# Test MAE: $20
#
# 184 features
# Test MAE: $20
#
# 185 features
# Test MAE: $20
#
# 186 features
# Test MAE: $20
#
# 187 features
# Test MAE: $20
#
# 188 features
# Test MAE: $20
#
# 189 features
# Test MAE: $20
#
# 190 features
# Test MAE: $20
#
# 191 features
# Test MAE: $20
#
# 192 features
# Test MAE: $20
#
# 193 features
# Test MAE: $20
#
# 194 features
# Test MAE: $20
#
# 195 features
# Test MAE: $20
#
# 196 features
# Test MAE: $20
#
# 197 features
# Test MAE: $20
#
# 198 features
# Test MAE: $20
#
# 199 features
# Test MAE: $20
#
# 200 features
# Test MAE: $20
#
# 201 features
# Test MAE: $20
#
# 202 features
# Test MAE: $20
#
# 203 features
# Test MAE: $20
#
# 204 features
# Test MAE: $20
#
# 205 features
# Test MAE: $20
#
# 206 features
# Test MAE: $20
#
# 207 features
# Test MAE: $20
#
# 208 features
# Test MAE: $20
#
# 209 features
# Test MAE: $20
#
# 210 features
# Test MAE: $20
#
# 211 features
# Test MAE: $20
#
# 212 features
# Test MAE: $20
#
# 213 features
# Test MAE: $20
#
# 214 features
# Test MAE: $20
#
# 215 features
# Test MAE: $20
#
# 216 features
# Test MAE: $20
#
# 217 features
# Test MAE: $20
#
# 218 features
# Test MAE: $20
#
# 219 features
# Test MAE: $20
#
# 220 features
# Test MAE: $20
#
# 221 features
# Test MAE: $20
#
# 222 features
# Test MAE: $20
#
# 223 features
# Test MAE: $20
#
# 224 features
# Test MAE: $20
#
# 225 features
# Test MAE: $20
#
# 226 features
# Test MAE: $20
#
# 227 features
# Test MAE: $20
#
# 228 features
# Test MAE: $20
#
# 229 features
# Test MAE: $20
#
# 230 features
# Test MAE: $20
#
# 231 features
# Test MAE: $20
#
# 232 features
# Test MAE: $20
#
# 233 features
# Test MAE: $20
#
# 234 features
# Test MAE: $20
#
# 235 features
# Test MAE: $20
#
# 236 features
# Test MAE: $20
#
# 237 features
# Test MAE: $20
#
# 238 features
# Test MAE: $20
#
# 239 features
# Test MAE: $20
#
# 240 features
# Test MAE: $20
#
# 241 features
# Test MAE: $20
#
# 242 features
# Test MAE: $20
#
# 243 features
# Test MAE: $20
#
# 244 features
# Test MAE: $20
#
# 245 features
# Test MAE: $20
#
# 246 features
# Test MAE: $20
#
# 247 features
# Test MAE: $20
#
# 248 features
# Test MAE: $20
#
# 249 features
# Test MAE: $20
#
# 250 features
# Test MAE: $20
#
# 251 features
# Test MAE: $20
#
# 252 features
# Test MAE: $20
#
# 253 features
# Test MAE: $20
#
# 254 features
# Test MAE: $20
#
# 255 features
# Test MAE: $20
#
# 256 features
# Test MAE: $20
#
# 257 features
# Test MAE: $20
#
# 258 features
# Test MAE: $20
#
# 259 features
# Test MAE: $20
#
# 260 features
# Test MAE: $20
#
# 261 features
# Test MAE: $20
#
# 262 features
# Test MAE: $20
#
# 263 features
# Test MAE: $20
#
# 264 features
# Test MAE: $20
#
# 265 features
# Test MAE: $20
#
# 266 features
# Test MAE: $20
#
# 267 features
# Test MAE: $20
#
# 268 features
# Test MAE: $20
#
# 269 features
# Test MAE: $20
#
# 270 features
# Test MAE: $20
#
# 271 features
# Test MAE: $20
#
# 272 features
# Test MAE: $20
#
# 273 features
# Test MAE: $20
#
# 274 features
# Test MAE: $20
#
# 275 features
# Test MAE: $20
#
# 276 features
# Test MAE: $20
#
# 277 features
# Test MAE: $20
#
# 278 features
# Test MAE: $20
#
# 279 features
# Test MAE: $20
#
# 280 features
# Test MAE: $20
#
# 281 features
# Test MAE: $20
#
# 282 features
# Test MAE: $20
#
# 283 features
# Test MAE: $20
#
# 284 features
# Test MAE: $20
#
# 285 features
# Test MAE: $20
#
# 286 features
# Test MAE: $20
#
# 287 features
# Test MAE: $20
#
# 288 features
# Test MAE: $20
#
# 289 features
# Test MAE: $20
#
# 290 features
# Test MAE: $20
#
# 291 features
# Test MAE: $20
#
# 292 features
# Test MAE: $20
#
# 293 features
# Test MAE: $20
#
# 294 features
# Test MAE: $20
#
# 295 features
# Test MAE: $20
#
# 296 features
# Test MAE: $20
#
# 297 features
# Test MAE: $20
#
# 298 features
# Test MAE: $20
#
# 299 features
# Test MAE: $20
#
# 300 features
# Test MAE: $20
#
# 301 features
# Test MAE: $20
#
# 302 features
# Test MAE: $20
#
# 303 features
# Test MAE: $20
#
# 304 features
# Test MAE: $20
#
# 305 features
# Test MAE: $20
#
# 306 features
# Test MAE: $20
#
# 307 features
# Test MAE: $20
#
# 308 features
# Test MAE: $20
#
# 309 features
# Test MAE: $20
#
# 310 features
# Test MAE: $20
#
# 311 features
# Test MAE: $20
#
# 312 features
# Test MAE: $20
#
# 313 features
# Test MAE: $20
#
# 314 features
# Test MAE: $20
#
# 315 features
# Test MAE: $20
#
# 316 features
# Test MAE: $20
#
# 317 features
# Test MAE: $20
#
# 318 features
# Test MAE: $20
#
# 319 features
# Test MAE: $20
#
# 320 features
# Test MAE: $20
#
# 321 features
# Test MAE: $20
#
# 322 features
# Test MAE: $20
#
# 323 features
# Test MAE: $20
#
# 324 features
# Test MAE: $20
#
# 325 features
# Test MAE: $20
#
# 326 features
# Test MAE: $20
#
# 327 features
# Test MAE: $20
#
# 328 features
# Test MAE: $20
#
# 329 features
# Test MAE: $20
#
# 330 features
# Test MAE: $20
#
# 331 features
# Test MAE: $20
#
# 332 features
# Test MAE: $20
#
# 333 features
# Test MAE: $20
#
# 334 features
# Test MAE: $20
#
# 335 features
# Test MAE: $20
#
# 336 features
# Test MAE: $20
#
# 337 features
# Test MAE: $20
#
# 338 features
# Test MAE: $20
#
# 339 features
# Test MAE: $20
#
# 340 features
# Test MAE: $20
#
# 341 features
# Test MAE: $20
#
# 342 features
# Test MAE: $20
#
# 343 features
# Test MAE: $20
#
# 344 features
# Test MAE: $20
#
# 345 features
# Test MAE: $20
#
# 346 features
# Test MAE: $20
#
# 347 features
# Test MAE: $20
#
# 348 features
# Test MAE: $20
#
# 349 features
# Test MAE: $20
#
# 350 features
# Test MAE: $20
#
# 351 features
# Test MAE: $20
#
# 352 features
# Test MAE: $20
#
# 353 features
# Test MAE: $20
#
# 354 features
# Test MAE: $20

# %%
from sklearn.linear_model import LinearRegression

def lr(X_train, X_val, features, target):

    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_val = model.predict(X_val)
    
#     print(f'Linear Regression with {len(features)} features')
#     print('Intercept', model.intercept_)
#     coefficients = pd.Series(model.coef_, features)
#     print(coefficients.to_string())
    
    print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train, y_pred_train)))
    print('Val Root Mean Square Error:', np.sqrt(mean_squared_error(y_val, y_pred_val)))
    print('Train Mean Absolute Error:', mean_absolute_error(y_train, y_pred_train))
    print('Val Mean Absolute Error:', mean_absolute_error(y_val, y_pred_val))
    print('Train R^2 Score:', r2_score(y_train, y_pred_train))
    print('Val R^2 Score:', r2_score(y_val, y_pred_val))
    return True

# %%
lr(X_train_encoded, X_val_encoded, features, target)
# Out:
# Train Root Mean Squared Error: 28.24849080118517
# Val Root Mean Square Error: 28.120079407061557
# Train Mean Absolute Error: 19.503976557122073
# Val Mean Absolute Error: 19.54937049816826
# Train R^2 Score: 0.5345873656403197
# Val R^2 Score: 0.514114589253309
# True

# %%
#setting up transformer to implement eli5
transformers = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_transformed = transformers.fit_transform(X_train)
X_val_transformed = transformers.transform(X_val)

model = LinearRegression()
model.fit(X_train_transformed, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#setting up transformer to implement eli5
import eli5
from eli5.sklearn import PermutationImportance

permuter = PermutationImportance(
    model, 
    scoring=None, 
    n_iter=5, 
    random_state=42
)

permuter.fit(X_val_transformed, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=LinearRegression(copy_X=True,
#                                                  fit_intercept=True,
#                                                  n_jobs=None, normalize=False),
#                       n_iter=5, random_state=42, refit=True, scoring=None)

# %%
feature_names = X_val.columns.tolist()
pd.Series(permuter.feature_importances_, feature_names).sort_values()
# Out:
# ean / upc       -0.001854
# skimmers        -0.000941
# sunny           -0.000818
# synthetic       -0.000779
# street          -0.000777
#                    ...
# prices.isSale    0.060154
# boot             0.088322
# classified       0.090893
# drew             0.100114
# sas,             0.411943
# Length: 354, dtype: float64

# %%
eli5.show_weights(
    permuter,
    top=None,
    feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4119
#
#                     &plusmn; 0.0170
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sas,
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1001
#
#                     &plusmn; 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 drew
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0909
#
#                     &plusmn; 0.0274
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 classified
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0883
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 boot
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0602
#
#                     &plusmn; 0.0143
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 prices.isSale
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0493
#
#                     &plusmn; 0.0094
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 spring
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0433
#
#                     &plusmn; 0.0100
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 prices.offer
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0410
#
#                     &plusmn; 0.0112
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0349
#
#                     &plusmn; 0.0119
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0242
#
#                     &plusmn; 0.0076
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 soda
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0233
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ww
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0222
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 inch
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0204
#
#                     &plusmn; 0.0119
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 women
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0187
#
#                     &plusmn; 0.0058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 softwalk
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0175
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 trotters
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0165
#
#                     &plusmn; 0.0048
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 prices.availability
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 medium
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0146
#
#                     &plusmn; 0.0056
#
#             </td>
#             <td style="paddi

# %%
#Removing features that don't contribute
minimum_importance = 0
mask = permuter.feature_importances_ > minimum_importance
features = X_train.columns[mask]
X_train = X_train[features]
X_val = X_val[features]

# %%
X_val = X_val[features]

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
print('Val R^2 Score=', pipeline.score(X_val, y_val))
# Out:
# Val R^2 Score= 0.5813893008657656

# %%
from xgboost import XGBRegressor
encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

model = XGBRegressor(
    booster='dart',
    n_estimators=1000, 
    max_depth=7,      
    learning_rate=0.5, 
    n_jobs=-1
)

eval_set = [(X_train_encoded, y_train), 
            (X_val_encoded, y_val)]

model.fit(X_train_encoded, y_train, 
          eval_set=eval_set,  
          early_stopping_rounds=50)
# Out:
# [17:25:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:47.2122	validation_1-rmse:46.1164
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:35.304	validation_1-rmse:35.5325
# [2]	validation_0-rmse:28.9538	validation_1-rmse:31.1199
# [3]	validation_0-rmse:26.0927	validation_1-rmse:29.0398
# [4]	validation_0-rmse:24.8779	validation_1-rmse:28.4848
# [5]	validation_0-rmse:23.4447	validation_1-rmse:27.9931
# E:\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# E:\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
# [6]	validation_0-rmse:22.9507	validation_1-rmse:27.6777
# [7]	validation_0-rmse:21.9913	validation_1-rmse:26.8627
# [8]	validation_0-rmse:21.0151	validation_1-rmse:26.5474
# [9]	validation_0-rmse:20.6181	validation_1-rmse:26.33
# [10]	validation_0-rmse:20.4159	validation_1-rmse:26.2128
# [11]	validation_0-rmse:20.2258	validation_1-rmse:26.1693
# [12]	validation_0-rmse:19.0697	validation_1-rmse:25.5208
# [13]	validation_0-rmse:18.6019	validation_1-rmse:25.4013
# [14]	validation_0-rmse:18.3101	validation_1-rmse:25.5142
# [15]	validation_0-rmse:17.8803	validation_1-rmse:25.3227
# [16]	validation_0-rmse:17.6195	validation_1-rmse:25.2234
# [17]	validation_0-rmse:17.1184	validation_1-rmse:24.9592
# [18]	validation_0-rmse:16.9403	validation_1-rmse:24.9561
# [19]	validation_0-rmse:16.7469	validation_1-rmse:24.9222
# [20]	validation_0-rmse:16.6462	validation_1-rmse:24.8668
# [21]	validation_0-rmse:16.249	validation_1-rmse:24.7762
# [22]	validation_0-rmse:15.9744	validation_1-rmse:24.6392
# [23]	validation_0-rmse:15.8197	validation_1-rmse:24.5583
# [24]	validation_0-rmse:15.6096	validation_1-rmse:24.4838
# [25]	validation_0-rmse:15.4729	validation_1-rmse:24.4457
# [26]	validation_0-rmse:15.2162	validation_1-rmse:24.3346
# [27]	validation_0-rmse:15.0937	validation_1-rmse:24.3466
# [28]	validation_0-rmse:14.7993	validation_1-rmse:24.2605
# [29]	validation_0-rmse:14.7084	validation_1-rmse:24.2496
# [30]	validation_0-rmse:14.6294	validation_1-rmse:24.2401
# [31]	validation_0-rmse:14.3679	validation_1-rmse:24.1932
# [32]	validation_0-rmse:14.2202	validation_1-rmse:24.1688
# [33]	validation_0-rmse:14.0778	validation_1-rmse:24.0667
# [34]	validation_0-rmse:14.0164	validation_1-rmse:24.0588
# [35]	validation_0-rmse:13.9059	validation_1-rmse:23.9961
# [36]	validation_0-rmse:13.8186	validation_1-rmse:24.0002
# [37]	validation_0-rmse:13.6809	validation_1-rmse:23.9248
# [38]	validation_0-rmse:13.5771	validation_1-rmse:23.9321
# [39]	validation_0-rmse:13.4278	validation_1-rmse:23.9352
# [40]	validation_0-rmse:13.3342	validation_1-rmse:23.9368
# [41]	validation_0-rmse:13.1573	validation_1-rmse:23.9437
# [42]	validation_0-rmse:13.0746	validation_1-rmse:24.0506
# [43]	validation_0-rmse:13.0478	validation_1-rmse:24.0514
# [44]	validation_0-rmse:12.9932	validation_1-rmse:24.0175
# [45]	validation_0-rmse:12.9173	validation_1-rmse:24.0358
# [46]	validation_0-rmse:12.8294	validation_1-rmse:24.0509
# [47]	validation_0-rmse:12.7622	validation_1-rmse:24.0298
# [48]	validation_0-rmse:12.6948	validation_1-rmse:24.0453
# [49]	validation_0-rmse:12.5387	validation_1-rmse:24.0812
# [50]	validation_0-rmse:12.4798	validation_1-rmse:24.0366
# [51]	validation_0-rmse:12.3801	validation_1-rmse:24.0314
# [52]	validation_0-rmse:12.2684	validation_1-rmse:24.0708
# [53]	validation_0-rmse:12.1587	validation_1-rmse:24.148
# [54]	validation_0-rmse:12.0877	validation_1-rmse:24.2086
# [55]	validation_0-rmse:12.0559	validation_1-rmse:24.2068
# [56]	validation_0-rmse:12.019	validation_1-rmse:24.2339
# [57]	validation_0-rmse:11.9466	validation_1-rmse:24.2489
# [58]	validation_0-rmse:11.802	validation_1-rmse:24.2269
# [59]	validation_0-rmse:11.7494	validation_1-rmse:24.2475
# [60]	validation_0-rmse:11.6044	validation_1-rmse:24.2083
# [61]	validation_0-rmse:11.5519	validation_1-rmse:24.2329
# [62]	validation_0-rmse:11.5154	validation_1-rmse:24.2296
# [63]	validation_0-rmse:11.4674	validation_1-rmse:24.2525
# [64]	validation_0-rmse:11.4118	validation_1-rmse:24.2489
# [65]	validation_0-rmse:11.3513	validation_1-rmse:24.2584
# [66]	validation_0-rmse:11.3069	validation_1-rmse:24.299
# [67]	validation_0-rmse:11.2516	validation_1-rmse:24.3018
# [68]	validation_0-rmse:11.2143	validation_1-rmse:24.3118
# [69]	validation_0-rmse:11.1924	validation_1-rmse:24.3204
# [70]	validation_0-rmse:11.1655	validation_1-rmse:24.3071
# [71]	validation_0-rmse:11.068	validation_1-rmse:24.2909
# [72]	validation_0-rmse:11.0495	validation_1-rmse:24.2762
# [73]	validation_0-rmse:11.0045	validation_1-rmse:24.2692
# [74]	validation_0-rmse:10.9874	validation_1-rmse:24.27
# [75]	validation_0-rmse:10.9177	validation_1-rmse:24.2888
# [76]	validation_0-rmse:10.8741	validation_1-rmse:24.2717
# [77]	validation_0-rmse:10.8464	validation_1-rmse:24.2644
# [78]	validation_0-rmse:10.816	validation_1-rmse:24.2627
# [79]	validation_0-rmse:10.8	validation_1-rmse:24.2854
# [80]	validation_0-rmse:10.7659	validation_1-rmse:24.2716
# [81]	validation_0-rmse:10.7527	validation_1-rmse:24.2524
# [82]	validation_0-rmse:10.7476	validation_1-rmse:24.2495
# [83]	validation_0-rmse:10.73	validation_1-rmse:24.2172
# [84]	validation_0-rmse:10.7096	validation_1-rmse:24.1827
# [85]	validation_0-rmse:10.6883	validation_1-rmse:24.2037
# [86]	validation_0-rmse:10.6619	validation_1-rmse:24.2067
# [87]	validation_0-rmse:10.6328	validation_1-rmse:24.182
# Stopping. Best iteration:
# [37]	validation_0-rmse:13.6809	validation_1-rmse:23.9248
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.5, max_delta_step=0,
#              max_depth=7, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
#Graphing the above
results = model.evals_result()
train_error = results['validation_0']['rmse']
val_error = results['validation_1']['rmse']
epoch = list(range(1, len(train_error)+1))
plt.plot(epoch, train_error, label='Train')
plt.plot(epoch, val_error, label='Validation')
plt.ylabel('Classification Error')
plt.xlabel('Model Complexity (n_estimators)')
plt.title('Validation Curve for this XGBoost model')

plt.legend();

# %%
from sklearn.metrics import r2_score
from xgboost import XGBRegressor

gb = make_pipeline(
    ce.OrdinalEncoder(), 
    XGBRegressor(n_estimators=3000, objective='reg:squarederror', n_jobs=-1)
)

gb.fit(X_train, y_train)
y_pred = gb.predict(X_val)
print('Gradient Boosting R^2', r2_score(y_val, y_pred))
# Out:
# Gradient Boosting R^2 0.644372276448373

# %%
#PDP graphs
import matplotlib.pyplot as plt
from pdpbox.pdp import pdp_interact, pdp_interact_plot
from pdpbox.pdp import pdp_isolate, pdp_plot

# %%
plt.rcParams['figure.dpi'] = 72

feature = 'sas,'

isolated = pdp_isolate(
    model=gb, 
    dataset=X_val, 
    model_features=X_val.columns, 
    feature=feature
)

# %%
pdp_plot(isolated, feature_name=feature);

# %%
#shap
import shap
X_val_encoded = encoder.transform(X_val)
row = X_val_encoded.iloc[[0]]
print (y_val.iloc[[0]])
model.predict(row)
# Out:
# 4726    152.95
# Name: price, dtype: float64
# array([145.38411168])

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(row)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value, 
    shap_values=shap_values, 
    features=row
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='iOBASKOB23GNNZLH9MIKE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 65.62092993090452, "outValue": 145.38411165881246, "link": "identity", "featureNames": ["name_length", "brand", "manufacturer", "manufacturerNumber", "prices.availability", "prices.isSale", "prices.offer", "prices.shipping", "toe", "ankle", "heel", "boot", "sandal", "shoes", "bootie", "strap", "leather", "propet", "flats", "black", "fashion", "women", "open", "pump", "suede", "sandals", "wide", "lace", "pleaser", "up", "sas,", "trotters", "brinley", "faux", "slip", "mary", "ankle-high", "flat", "jane", "pointed", "casual", "closed", "dress", "breeze", "spring", "sneaker", "riding", "step", "comfort", "blue", "booties", "round", "running", "knee", "side", "size", "m", "us", "block", "aerosoles", "d'orsay", "softwalk", "width", "mid", "new", "stacked", "l'artiste", "walker", "easy", "pumps", "inch", "soda", "strappy", "slip-on", "drew", "buckle", "chunky", "medium", "10", "6", "low", "w", "ballet", "4", "6.5", "patent", "city", "madden", "pink", "open-toe", "t-strap", "wear", "peep", "soda,", "combat", "waterproof", "heels", "david", "cowboy", "tall", "gladiator", "leatherette", "5", "classified", "joy", "n", "western", "steve", "tate", "ww", "cutout", "sexy", "gold", "hampshire", "ellie", "wood", "floral", "wash", "a2", "bow", "stiletto", "b(m)", "7", "athletic", "label", "madison", "and"], "features": {"0": {"effect": 5.038222725186898, "value": 31}, "1": {"effect": 78.1200956239039, "value": 1.0}, "2": {"effect": 0.0848519630671591, "value": 1.0}, "3": {"effect": 0.6619199830518527, "value": 1.0}, "4": {"effect": -3.3126247905061907, "value": false}, "5": {"effect": 0.042040420864549594, "value": 1}, "6": {"effect": 2.759615352997227, "value": 1.0}, "7": {"effect": 0.004995037917570968, "value": 1}, "8": {"effect": 0.054319718307855, "value": false}, "9": {"effect": 0.014799030244123077, "value": false}, "10": {"effect": 1.194090620058264, "value": false}, "11": {"effect": -1.149153273679318, "value": false}, "12": {"effect": 0.10893046620076066, "value": false}, "13": {"effect": 0.0955949401985664, "value": false}, "14": {"effect": -0.039927278406985484, "value": false}, "15": {"effect": -0.03145340305785515, "value": false}, "16": {"effect": -0.08145558214760512, "value": false}, "17": {"effect": 0.058760794778486926, "value": false}, "18": {"effect": 0.3374157571801711, "value": true}, "19": {"effect": -0.02202560950020604, "value": false}, "20": {"effect": 0.019325042162150023, "value": false}, "21": {"effect": 0.05073443780036285, "value": true}, "22": {"effect": 0.00252084183076823, "value": false}, "23": {"effect": -0.06904891986893551, "value": false}, "24": {"effect": -0.005466299146166443, "value": false}, "25": {"effect": -0.5638064035215818, "value": false}, "26": {"effect": -0.009824041187149088, "value": false}, "27": {"effect": 0.12744712455430074, "value": false}, "28": {"effect": -0.07563164729646156, "value": false}, "29": {"effect": 0.23229941749879676, "value": false}, "30": {"effect": 0.1038513882384494, "value": true}, "31": {"effect": -0.49696734593581354, "value": false}, "32": {"effect": 0.0008535406613230491, "value": false}, "33": {"effect": 0.028262637220256813, "value": false}, "34": {"effect": 2.4512793999020297, "value": true}, "35": {"effect": -0.019676265198121063, "value": false}, "36": {"effect": -0.032313505513448866, "value": false}, "37": {"effect": -2.043122239043457, "value": true}, "38": {"effect": -0.0293604177142775, "value": false}, "39": {"effect": 0.008886072497019337, "value": false}, "40": {"effect": -0.015578900604152995, "value": false}, "41": {"effect": -0.11930011558346172, "value": false}, "42": {"effect": 0.010894017165518143, "value": false}, "43": {"effect": 0.04681072724347449, "value": false}, "44": {"effect": -0.5717763094180108, "value": false}, "45": {"effect": -0.08646419346783552, "value": false}, "46": {"effect": -0.0366900178105429, "value": false}, "47": {"eff ...
