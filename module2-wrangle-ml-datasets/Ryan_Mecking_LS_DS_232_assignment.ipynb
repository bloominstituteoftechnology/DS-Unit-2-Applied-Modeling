# %% [markdown]
# <a href="https://colab.research.google.com/github/rsmecking/DS-Unit-2-Applied-Modeling/blob/master/module2-wrangle-ml-datasets/Ryan_Mecking_LS_DS_232_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv (r'C:\Users\Ryan\Desktop\Coding Stuffs\Project 2 stuff/Datafiniti_Womens_Shoes_Jun19.csv')
print (df.shape)
df.head(3)
# Out:
# (10000, 32)
#                      id             dateAdded           dateUpdated asins  \
# 0  AWpyySsJAGTnQPR7wNt4  2019-05-01T09:27:22Z  2019-05-01T09:27:22Z   NaN
# 1  AWpyyyb3AGTnQPR7wN-u  2019-05-01T09:27:19Z  2019-05-01T09:27:19Z   NaN
# 2  AWpyzlajAGTnQPR7wOX8  2019-05-01T09:26:59Z  2019-05-01T09:26:59Z   NaN
#
#              brand                                    categories  \
# 0  City Classified  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 1         Skechers  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 2           Floral  Clothing,Shoes,Womens Shoes,All Womens Shoes
#
#   primaryCategories colors dimension     ean / upc  ...  \
# 0             Shoes  Black       NaN  656000000000  ...
# 1             Shoes  Taupe       NaN  192000000000  ...
# 2             Shoes  Black       NaN  709000000000  ...
#
#             prices.dateSeen prices.isSale prices.merchant prices.offer  \
# 0      2019-04-19T07:09:29Z           NaN             NaN  Online only
# 1      2019-04-24T09:14:11Z           NaN             NaN  Online only
# 2  2019-04-25T12:35:00.000Z           NaN             NaN  Online only
#
#   prices.returnPolicy  prices.shipping  prices.size  \
# 0                 NaN              NaN            8
# 1                 NaN              NaN       6 M US
# 2                 NaN              NaN            5
#
#                                    prices.sourceURLs   sizes  \
# 0  https://www.walmart.com/ip/City-Classified-Sty...       8
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...  6 M US
# 2  https://www.walmart.com/ip/FLORAL-Pearl-Women-...       5
#
#                                           sourceURLs
# 0  https://www.walmart.com/ip/City-Classified-Sty...
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...
# 2  https://www.walmart.com/ip/FLORAL-Pearl-Women-...
#
# [3 rows x 32 columns]

# %%
#Averaging out price of shoe. Most values were the same so it was basically a duplicate column
df['price'] = (df['prices.amountMin'] + df['prices.amountMax'])/2
df.shape
# Out:
# (10000, 33)

# %%
# Dropping now useless columns.
df = df.drop(['prices.amountMin', 'prices.amountMax'], axis=1)
df.shape
# Out:
# (10000, 31)

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AWpyySsJAGTnQPR7wNt4  2019-05-01T09:27:22Z  2019-05-01T09:27:22Z   NaN
# 1  AWpyyyb3AGTnQPR7wN-u  2019-05-01T09:27:19Z  2019-05-01T09:27:19Z   NaN
# 2  AWpyzlajAGTnQPR7wOX8  2019-05-01T09:26:59Z  2019-05-01T09:26:59Z   NaN
# 3  AWpyxomE0U_gzG0hkA1q  2019-05-01T09:26:56Z  2019-05-01T09:26:56Z   NaN
# 4  AWpyxChWJbEilcB6RhWx  2019-05-01T09:26:56Z  2019-05-01T09:26:56Z   NaN
#
#              brand                                    categories  \
# 0  City Classified  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 1         Skechers  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 2           Floral  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 3            Jambu  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 4         Trotters  Clothing,Shoes,Womens Shoes,All Womens Shoes
#
#   primaryCategories       colors dimension     ean / upc  ... prices.isSale  \
# 0             Shoes        Black       NaN  656000000000  ...           NaN
# 1             Shoes        Taupe       NaN  192000000000  ...           NaN
# 2             Shoes        Black       NaN  709000000000  ...           NaN
# 3             Shoes  Black/Multi       NaN  884000000000  ...           NaN
# 4             Shoes        White       NaN  887000000000  ...           NaN
#
#   prices.merchant          prices.offer prices.returnPolicy prices.shipping  \
# 0             NaN           Online only                 NaN             NaN
# 1             NaN           Online only                 NaN             NaN
# 2             NaN           Online only                 NaN             NaN
# 3             NaN  Online only: 20% off                 NaN             NaN
# 4             NaN  Online only: 50% off                 NaN             NaN
#
#    prices.size                                  prices.sourceURLs      sizes  \
# 0            8  https://www.walmart.com/ip/City-Classified-Sty...          8
# 1       6 M US  https://www.walmart.com/ip/Skechers-Women-S-Yo...     6 M US
# 2            5  https://www.walmart.com/ip/FLORAL-Pearl-Women-...          5
# 3    9.5 BM US  https://www.walmart.com/ip/Jambu-Women-s-AMAL-...  9.5 BM US
# 4           11  https://www.walmart.com/ip/Women-s-Trotters-Bl...         11
#
#                                           sourceURLs   price
# 0  https://www.walmart.com/ip/City-Classified-Sty...   29.95
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...   84.00
# 2  https://www.walmart.com/ip/FLORAL-Pearl-Women-...   49.95
# 3  https://www.walmart.com/ip/Jambu-Women-s-AMAL-...  127.20
# 4  https://www.walmart.com/ip/Women-s-Trotters-Bl...   47.66
#
# [5 rows x 31 columns]

# %%
# df['prices.size'].value_counts()

# %%
# df['sizes'].value_counts()

# %%
df['price'].describe()
# Out:
# count    10000.000000
# mean        72.202721
# std        172.400446
# min          5.500000
# 25%         34.990000
# 50%         52.485000
# 75%         83.962500
# max       5000.000000
# Name: price, dtype: float64

# %%
#Removing outliers 
df = df[(df['price'] <= np.percentile(df['price'], 99.5))]
df.shape
# Out:
# (9950, 31)

# %%
df['price'].describe()
# Out:
# count    9950.000000
# mean       65.168357
# std        40.993896
# min         5.500000
# 25%        34.990000
# 50%        52.200000
# 75%        83.682500
# max       260.590000
# Name: price, dtype: float64

# %%
#Filling in missing values with word "missing" for imputing reason
df = df.fillna("Missing")

# %%
#Making all upper casing to lower casing in name/color columns
df['name'] = df['name'].str.lower()
df['prices.color'] = df['prices.color'].str.lower()

# %%
# Looking for most common used words in 'name' column.
df1 = (df['name'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))
# df1.head(10)

# %%
df1 = df1.replace(["women's", 'womens', "/", "-", 'on', 'co.', 'by',
                   'and', 'm'], "Missing")
# df1['vals'].values[:200]

# %%
# Looking for most common used words in 'color' column.
df2 = (df['prices.color'].str.split(expand=True)
              .stack()
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))
# df2.head(10)

# %%
df2 = df2.replace(["women's", 'womens', "/", "-", 'on', 'co.', 'by',
                   'and', 'm'], "Missing")
# df2['vals'].values[:200]

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, train_size=0.80, test_size=0.20, 
                               random_state=42)
train.shape, test.shape
# Out:
# ((7960, 31), (1990, 31))

# %%
train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              random_state=42)
train.shape, val.shape
# Out:
# ((6368, 31), (1592, 31))

# %%
#imports
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeRegressor 
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import mean_absolute_error
import plotly.express as px
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# %%
#Features

def wrangle(X):
   # Prevent SettingWithCopyWarning
    X = X.copy()
    
  #Top descriptive words from 'name' column  
    mylist = df1['vals'].values[:150]
    
    for i in mylist:
        X[i] = X['name'].str.contains(i) 
    
    #Top descriptive words from 'name' column  
    color_list = df2['vals'].values[:200]
    
    for j in color_list:
        X[j] = X['prices.color'].str.contains(j) 

      # Does the shoe have a description?
    X['name'] = X['name'].str.strip().fillna('')
    X['has_description'] = X['name'] != ''

    # How long is the description?
    X['name_length'] = X['name'].str.len()
  
  #Dropping all columns with over 95% NaNs or repeated column.
    lon = ['id', 'asins', 'dateUpdated', 'prices.condition', 'dimension', 'prices.condition',
           'prices.dateAdded', 'prices.merchant', 'prices.returnPolicy','prices.shipping', 
           'dateAdded', 'primaryCategories', 'imageURLs', 'keys', 'colors', 'prices.isSale',
           'prices.sourceURLs', 'sizes', 'prices.isSale', 'manufacturerNumber', 'prices.sourceURLs', 
           'sourceURLs', 'prices.dateSeen', 'prices.color']
    X = X.drop(columns=lon, axis=1)
    
   # return the wrangled dataframe
    return X

train = wrangle(train)
val = wrangle(val)
test = wrangle(test)
# Out:
# E:\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.

# %%
# The status_group column is the target
target = 'price'

# Get a dataframe with all train columns except the target
train_features = train.drop(columns=[target])

# Get a list of the numeric features
numeric_features = train_features.select_dtypes(include='number').columns.tolist()

# Get a series with the cardinality of the nonnumeric features
cardinality = train_features.select_dtypes(exclude='number').nunique()

# Get a list of all categorical features with cardinality 
categorical_features = cardinality[cardinality <= 550].index.tolist()

# Combine the lists 
features = numeric_features + categorical_features

# %%
#Target/Val assignment

X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((6368, 333), (1592, 333), (1990, 333))

# %%
X_train.head(50)
# Out:
#          ean / upc  name_length                       brand  \
# 7742  728816000000           28                         SAS
# 6628  812000000000           45                Genuine Grip
# 306   728000000000           60                      Carlos
# 5258  825000000000           43                   Aerosoles
# 9638  870000000000           66                 Brinley Co.
# 3775  885308000000           52                  David Tate
# 6823  756000000000           47                      Propet
# 4412  800000000000           60                     OwnShoe
# 5100  706000000000           64                      Alfani
# 9119  886000000000           25                      Propet
# 7919  706000000000           76  INC International Concepts
# 7280  886000000000           47                   Aerosoles
Clothing,Shoes,Womens Shoes,All Womens Shoes      Missing
# 5721       Womens Shoes,Clothing,All Womens Shoes,Shoes      Missing
#
#       prices.availability prices.currency          prices.offer prices.size  \
# 7742                False             USD           Online only         7 M
# 6628                 True             USD  Online only: 24% off         8.5
# 306                  True             USD  Online only: 52% off         7.5
# 5258                 True             USD  Online only: 20% off           5
# 9638                 True             USD  Online only: 64% off           8
# 3775                False             USD           Online only          11
# 6823                False             USD           Online only         7.5
# 4412                 True             USD           Online only          11
# 5100                 True             USD  Online only: 61% off          10
# 9119                False             USD           Online only           7
# 7919                 True             USD  Online only: 28% off           8
# 7280                 True             USD           Online only          12
# 6336                 True             USD           Online only         8.5
# 4505                False             USD           Online only     7 BM US
# 8496                False             USD           Online only       7.5 M
# 8070                 True             USD           Online only           7
# 5515                False             USD           Online only          12
# 8346                False             USD           Online only         9 W
# 9229                 True             USD           Online only          10
# 356                  True             USD  Online only: 69% off           6
# 9522                 True             USD  Online only: 55% off         7.5
# 4729                False             USD           Online only       6.5 W
# 5842                False             USD           Online only          42
# 4593                 True             USD           Online only          10
# 1652                 True             USD           Online only          10
# 8016                 True             USD           Online only       7.5 M
# 9061                False             USD           Online only           9
# 4530                 True             USD           Online only          13
# 8436                False             USD           Online only         8.5
# 4431                 True             USD  Online only: 78% off          8M
# 4402                 True             USD  Online only: 66% off         6.5
# 65                   True             USD  Online only: 37% off           8
# 3242                 True             USD           Online only          10
# 1985                False             USD           Online only      11.5 S
# 2726                False             USD           Online only   7.5 BM US
# 7199                 True             USD           Online only     Size 11
# 9825                 True             USD           Online only         7.5
# 6849                False             USD           Online only         8.5
# 2207                False             USD           Online only      US 5.5
# 7320                False             USD           Online only        US 9
# 4143                 True             USD           Online only           7
# 3777                False             USD           Online only        10.5
# 1075                False             USD           Online only         8.5
# 9880                 True             USD           Online only          10
# 7447                 True             USD           Online only       7.5 M
# 210                  True             USD           Online only         9.5
# 4329                 True             USD  Online only: 31% off         7.5
# 4651                False             USD           Online only      US 7.5
# 7338                False             USD           Online only         9 M
# 5721                False             USD           Online only          10
#
#       Missing  ...  blue/silver    wb2  royal   knit  suedette    bm2  \
# 7742    False  ...        False  False  False  False     False  False
# 6628    False  ...        False  False  False  False     False  False
# 306     False  ...        False  False  False  False     False  False
# 5258    False  ...        False  False  False  False     False  False
# 9638    False  ...        False  False  False  False     False  False
# 3775    False  ...        False  False  False  False     False  False
# 6823    False  ...        False  False  False  False     False  False
# 4412    False  ...        False  False  False  False     False  False
# 5100    False  ...        False  False  False  False     False  False
# 9119    False  ...        False  False  False  False     False  False
# 7919    False  ...        False  False  False  False     False  False
# 7280    False  ...        False  False  False  False     False  False
# 6336    False  ...        False  False  False  False     False  False
# 4505    False  ...        False  False  False  False     False  False
# 8496    False  ...        False  False  False  False     False  False
# 8070    False  ...        False  False  False  False     False  False
# 5515    False  ...        False  False  False  False     False  False
# 8346    False  ...        False  False  False  False     False  False
# 9229    False  ...        False  False  False  False     False  False
# 356     False  ...        False  False  False  False     False  False
# 9522    False  ...        False  False  False  False     False  False
# 4729    False  ...        False  False  False  False     False  False
# 5842    False  ...        False  False  False  False     False  False
# 4593    False  ...        False  False  False  False     False  False
# 1652    False  ...        False  False  False  False     False  False
# 8016    False  ...        False  False  False  False     False  False
# 9061    False  ...        False  False  False  False     False  False
# 4530    False  ...        False  False  False  False     False  False
# 8436    False  ...        False  False  False  False     False  False
# 4431    False  ...        False  False  False  False     False  False
# 4402    False  ...        False  False  False  False     False  False
# 65      False  ...        False  False  False  False     False  False
# 3242    False  ...        False  False  False  False     False  False
# 1985    False  ...        False  False  False  False     False  False
# 2726    False  ...        False  False  False  False     False  False
# 7199    False  ...        False  False  False  False     False  False
# 9825    False  ...        False  False  False  False     False  False
# 6849    False  ...        False  False  False  False     False  False
# 2207    False  ...        False  False  False  False     False  False
# 7320    False  ...        False  False  False  False     False  False
# 4143    False  ...        False  False  False  False     False  False
# 3777    False  ...        False  False  False  False     False  False
# 1075    False  ...        False  False  False  False     False  False
# 9880    False  ...        False  False  False  False     False  False
# 7447    False  ...        False  False  False  False     False  False
# 210     False  ...        False  False  False  False     False  False
# 4329    False  ...        False  False  False  False     False  False
# 4651    False  ...        False  False  False  False     False  False
# 7338    False  ...        False  False  False  False     False  False
# 5721    False  ...        False  False  False  False     False  False
#
#       patent/black  oyster/gold  theatrical  has_description
# 7742         False        False       False             True
# 6628         False        False       False             True
# 306          False        False       False             True
# 5258         False        False       False             True
# 9638         False        False       False             True
# 3775         False        False       False             True
# 6823         False        False       False             True
# 4412         False        False       False             True
# 5100         False        False       False             True
# 9119         False        False       False             True
# 7919         False        False       False             True
# 7280         False        False       False             True
# 6336         False        False       False             True
# 4505         False        False       False             True
# 8496         False        False       False             True
# 8070         False        False       False             True
# 5515         False        False       False             True
# 8346         False        False       False             True
# 9229         False        False       False             True
# 356          False        False       False             True
# 9522         False        False       False             True
# 4729         False        False       False             True
# 5842         False        False       False             True
# 4593         False        False       False             True
# 1652         False        False       False             True
# 8016         False        False       False             True
# 9061         False        False       False             True
# 4530         False        False       False             True
# 8436         False        False       False             True
# 4431         False        False       False             True
# 4402         False        False       False             True
# 65           False        False       False             True
# 3242         False        False       False             True
# 1985         False        False       False             True
# 2726         False        False       False             True
# 7199         False        False       False             True
# 9825         False        False       False             True
# 6849         False        False       False             True
# 2207         False        False       False             True
# 7320         False        False       False             True
# 4143         False        False       False             True
# 3777         False        False       False             True
# 1075         False        False       False             True
# 9880         False        False       False             True
# 7447         False        False       False             True
# 210          False        False       False             True
# 4329         False        False       False             True
# 4651         False        False       False             True
# 7338         False        False       False             True
# 5721         False        False       False             True
#
# [50 rows x 333 columns]

# %%
X_train.dtypes
# Out:
# ean / upc           int64
# name_length         int64
# brand              object
# categories         object
# manufacturer       object
#                     ...
# bm2                  bool
# patent/black         bool
# oyster/gold          bool
# theatrical           bool
# has_description      bool
# Length: 333, dtype: object

# %%
y = df['price']
sns.distplot(y);

# %%
y_log = np.log1p(y)
sns.distplot(y_log)
plt.title('Log-transformed target, in log-dollars');

# %%
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='numpy')
warnings.filterwarnings(action='ignore', category=RuntimeWarning, module='sklearn')
warnings.filterwarnings(action='ignore', category=RuntimeWarning, module='scipy')

# %%
encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_val_scaled = scaler.transform(X_val_encoded)

for k in range(1, len(X_train_encoded.columns)+1):
    print(f'{k} features')
    
    selector = SelectKBest(score_func=f_regression, k=k)
    X_train_selected = selector.fit_transform(X_train_scaled, y_train)
    X_val_selected = selector.transform(X_val_scaled)
    
    model = LinearRegression()
    model.fit(X_train_selected, y_train)
    
    y_pred = model.predict(X_val_selected)
    mae = mean_absolute_error(y_val, y_pred)
    print(f'Test MAE: ${mae:,.0f} \n')
# Out:
# 1 features
# Test MAE: $29
#
# 2 features
# Test MAE: $28
#
# 3 features
# Test MAE: $26
#
# 4 features
# Test MAE: $25
#
# 5 features
# Test MAE: $25
#
# 6 features
# Test MAE: $25
#
# 7 features
# Test MAE: $25
#
# 8 features
# Test MAE: $25
#
# 9 features
# Test MAE: $25
#
# 10 features
# Test MAE: $25
#
# 11 features
# Test MAE: $25
#
# 12 features
# Test MAE: $25
#
# 13 features
# Test MAE: $24
#
# 14 features
# Test MAE: $24
#
# 15 features
# Test MAE: $24
#
# 16 features
# Test MAE: $24
#
# 17 features
# Test MAE: $24
#
# 18 features
# Test MAE: $23
#
# 19 features
# Test MAE: $23
#
# 20 features
# Test MAE: $23
#
# 21 features
# Test MAE: $23
#
# 22 features
# Test MAE: $23
#
# 23 features
# Test MAE: $23
#
# 24 features
# Test MAE: $23
#
# 25 features
# Test MAE: $23
#
# 26 features
# Test MAE: $23
#
# 27 features
# Test MAE: $23
#
# 28 features
# Test MAE: $23
#
# 29 features
# Test MAE: $23
#
# 30 features
# Test MAE: $23
#
# 31 features
# Test MAE: $23
#
# 32 features
# Test MAE: $23
#
# 33 features
# Test MAE: $23
#
# 34 features
# Test MAE: $22
#
# 35 features
# Test MAE: $22
#
# 36 features
# Test MAE: $22
#
# 37 features
# Test MAE: $22
#
# 38 features
# Test MAE: $22
#
# 39 features
# Test MAE: $22
#
# 40 features
# Test MAE: $22
#
# 41 features
# Test MAE: $22
#
# 42 features
# Test MAE: $22
#
# 43 features
# Test MAE: $22
#
# 44 features
# Test MAE: $22
#
# 45 features
# Test MAE: $22
#
# 46 features
# Test MAE: $22
#
# 47 features
# Test MAE: $22
#
# 48 features
# Test MAE: $22
#
# 49 features
# Test MAE: $22
#
# 50 features
# Test MAE: $21
#
# 51 features
# Test MAE: $21
#
# 52 features
# Test MAE: $21
#
# 53 features
# Test MAE: $21
#
# 54 features
# Test MAE: $21
#
# 55 features
# Test MAE: $21
#
# 56 features
# Test MAE: $21
#
# 57 features
# Test MAE: $21
#
# 58 features
# Test MAE: $21
#
# 59 features
# Test MAE: $21
#
# 60 features
# Test MAE: $21
#
# 61 features
# Test MAE: $21
#
# 62 features
# Test MAE: $21
#
# 63 features
# Test MAE: $21
#
# 64 features
# Test MAE: $21
#
# 65 features
# Test MAE: $21
#
# 66 features
# Test MAE: $21
#
# 67 features
# Test MAE: $21
#
# 68 features
# Test MAE: $21
#
# 69 features
# Test MAE: $21
#
# 70 features
# Test MAE: $21
#
# 71 features
# Test MAE: $21
#
# 72 features
# Test MAE: $21
#
# 73 features
# Test MAE: $21
#
# 74 features
# Test MAE: $21
#
# 75 features
# Test MAE: $20
#
# 76 features
# Test MAE: $20
#
# 77 features
# Test MAE: $20
#
# 78 features
# Test MAE: $20
#
# 79 features
# Test MAE: $20
#
# 80 features
# Test MAE: $20
#
# 81 features
# Test MAE: $20
#
# 82 features
# Test MAE: $20
#
# 83 features
# Test MAE: $20
#
# 84 features
# Test MAE: $20
#
# 85 features
# Test MAE: $20
#
# 86 features
# Test MAE: $20
#
# 87 features
# Test MAE: $20
#
# 88 features
# Test MAE: $20
#
# 89 features
# Test MAE: $20
#
# 90 features
# Test MAE: $20
#
# 91 features
# Test MAE: $20
#
# 92 features
# Test MAE: $20
#
# 93 features
# Test MAE: $20
#
# 94 features
# Test MAE: $20
#
# 95 features
# Test MAE: $20
#
# 96 features
# Test MAE: $20
#
# 97 features
# Test MAE: $20
#
# 98 features
# Test MAE: $20
#
# 99 features
# Test MAE: $20
#
# 100 features
# Test MAE: $20
#
# 101 features
# Test MAE: $20
#
# 102 features
# Test MAE: $20
#
# 103 features
# Test MAE: $20
#
# 104 features
# Test MAE: $20
#
# 105 features
# Test MAE: $20
#
# 106 features
# Test MAE: $20
#
# 107 features
# Test MAE: $20
#
# 108 features
# Test MAE: $20
#
# 109 features
# Test MAE: $20
#
# 110 features
# Test MAE: $20
#
# 111 features
# Test MAE: $20
#
# 112 features
# Test MAE: $20
#
# 113 features
# Test MAE: $20
#
# 114 features
# Test MAE: $20
#
# 115 features
# Test MAE: $20
#
# 116 features
# Test MAE: $20
#
# 117 features
# Test MAE: $20
#
# 118 features
# Test MAE: $20
#
# 119 features
# Test MAE: $20
#
# 120 features
# Test MAE: $20
#
# 121 features
# Test MAE: $20
#
# 122 features
# Test MAE: $20
#
# 123 features
# Test MAE: $20
#
# 124 features
# Test MAE: $20
#
# 125 features
# Test MAE: $20
#
# 126 features
# Test MAE: $20
#
# 127 features
# Test MAE: $20
#
# 128 features
# Test MAE: $20
#
# 129 features
# Test MAE: $20
#
# 130 features
# Test MAE: $20
#
# 131 features
# Test MAE: $20
#
# 132 features
# Test MAE: $20
#
# 133 features
# Test MAE: $20
#
# 134 features
# Test MAE: $20
#
# 135 features
# Test MAE: $20
#
# 136 features
# Test MAE: $20
#
# 137 features
# Test MAE: $20
#
# 138 features
# Test MAE: $20
#
# 139 features
# Test MAE: $20
#
# 140 features
# Test MAE: $20
#
# 141 features
# Test MAE: $20
#
# 142 features
# Test MAE: $20
#
# 143 features
# Test MAE: $20
#
# 144 features
# Test MAE: $20
#
# 145 features
# Test MAE: $20
#
# 146 features
# Test MAE: $20
#
# 147 features
# Test MAE: $20
#
# 148 features
# Test MAE: $20
#
# 149 features
# Test MAE: $20
#
# 150 features
# Test MAE: $20
#
# 151 features
# Test MAE: $20
#
# 152 features
# Test MAE: $20
#
# 153 features
# Test MAE: $20
#
# 154 features
# Test MAE: $20
#
# 155 features
# Test MAE: $20
#
# 156 features
# Test MAE: $20
#
# 157 features
# Test MAE: $20
#
# 158 features
# Test MAE: $20
#
# 159 features
# Test MAE: $20
#
# 160 features
# Test MAE: $20
#
# 161 features
# Test MAE: $20
#
# 162 features
# Test MAE: $20
#
# 163 features
# Test MAE: $20
#
# 164 features
# Test MAE: $20
#
# 165 features
# Test MAE: $20
#
# 166 features
# Test MAE: $20
#
# 167 features
# Test MAE: $20
#
# 168 features
# Test MAE: $20
#
# 169 features
# Test MAE: $20
#
# 170 features
# Test MAE: $20
#
# 171 features
# Test MAE: $20
#
# 172 features
# Test MAE: $20
#
# 173 features
# Test MAE: $20
#
# 174 features
# Test MAE: $20
#
# 175 features
# Test MAE: $20
#
# 176 features
# Test MAE: $20
#
# 177 features
# Test MAE: $20
#
# 178 features
# Test MAE: $20
#
# 179 features
# Test MAE: $20
#
# 180 features
# Test MAE: $20
#
# 181 features
# Test MAE: $20
#
# 182 features
# Test MAE: $20
#
# 183 features
# Test MAE: $20
#
# 184 features
# Test MAE: $20
#
# 185 features
# Test MAE: $20
#
# 186 features
# Test MAE: $20
#
# 187 features
# Test MAE: $20
#
# 188 features
# Test MAE: $20
#
# 189 features
# Test MAE: $20
#
# 190 features
# Test MAE: $20
#
# 191 features
# Test MAE: $20
#
# 192 features
# Test MAE: $20
#
# 193 features
# Test MAE: $20
#
# 194 features
# Test MAE: $20
#
# 195 features
# Test MAE: $20
#
# 196 features
# Test MAE: $20
#
# 197 features
# Test MAE: $20
#
# 198 features
# Test MAE: $20
#
# 199 features
# Test MAE: $20
#
# 200 features
# Test MAE: $20
#
# 201 features
# Test MAE: $20
#
# 202 features
# Test MAE: $20
#
# 203 features
# Test MAE: $20
#
# 204 features
# Test MAE: $20
#
# 205 features
# Test MAE: $20
#
# 206 features
# Test MAE: $20
#
# 207 features
# Test MAE: $20
#
# 208 features
# Test MAE: $20
#
# 209 features
# Test MAE: $20
#
# 210 features
# Test MAE: $20
#
# 211 features
# Test MAE: $20
#
# 212 features
# Test MAE: $20
#
# 213 features
# Test MAE: $20
#
# 214 features
# Test MAE: $20
#
# 215 features
# Test MAE: $20
#
# 216 features
# Test MAE: $20
#
# 217 features
# Test MAE: $20
#
# 218 features
# Test MAE: $20
#
# 219 features
# Test MAE: $20
#
# 220 features
# Test MAE: $20
#
# 221 features
# Test MAE: $20
#
# 222 features
# Test MAE: $20
#
# 223 features
# Test MAE: $20
#
# 224 features
# Test MAE: $20
#
# 225 features
# Test MAE: $20
#
# 226 features
# Test MAE: $20
#
# 227 features
# Test MAE: $20
#
# 228 features
# Test MAE: $20
#
# 229 features
# Test MAE: $20
#
# 230 features
# Test MAE: $20
#
# 231 features
# Test MAE: $20
#
# 232 features
# Test MAE: $20
#
# 233 features
# Test MAE: $20
#
# 234 features
# Test MAE: $20
#
# 235 features
# Test MAE: $20
#
# 236 features
# Test MAE: $20
#
# 237 features
# Test MAE: $20
#
# 238 features
# Test MAE: $20
#
# 239 features
# Test MAE: $20
#
# 240 features
# Test MAE: $20
#
# 241 features
# Test MAE: $20
#
# 242 features
# Test MAE: $20
#
# 243 features
# Test MAE: $20
#
# 244 features
# Test MAE: $20
#
# 245 features
# Test MAE: $20
#
# 246 features
# Test MAE: $20
#
# 247 features
# Test MAE: $20
#
# 248 features
# Test MAE: $20
#
# 249 features
# Test MAE: $20
#
# 250 features
# Test MAE: $20
#
# 251 features
# Test MAE: $20
#
# 252 features
# Test MAE: $20
#
# 253 features
# Test MAE: $20
#
# 254 features
# Test MAE: $20
#
# 255 features
# Test MAE: $20
#
# 256 features
# Test MAE: $20
#
# 257 features
# Test MAE: $20
#
# 258 features
# Test MAE: $20
#
# 259 features
# Test MAE: $20
#
# 260 features
# Test MAE: $20
#
# 261 features
# Test MAE: $20
#
# 262 features
# Test MAE: $20
#
# 263 features
# Test MAE: $20
#
# 264 features
# Test MAE: $20
#
# 265 features
# Test MAE: $20
#
# 266 features
# Test MAE: $20
#
# 267 features
# Test MAE: $20
#
# 268 features
# Test MAE: $20
#
# 269 features
# Test MAE: $20
#
# 270 features
# Test MAE: $20
#
# 271 features
# Test MAE: $20
#
# 272 features
# Test MAE: $20
#
# 273 features
# Test MAE: $20
#
# 274 features
# Test MAE: $20
#
# 275 features
# Test MAE: $20
#
# 276 features
# Test MAE: $20
#
# 277 features
# Test MAE: $20
#
# 278 features
# Test MAE: $20
#
# 279 features
# Test MAE: $20
#
# 280 features
# Test MAE: $20
#
# 281 features
# Test MAE: $20
#
# 282 features
# Test MAE: $20
#
# 283 features
# Test MAE: $20
#
# 284 features
# Test MAE: $20
#
# 285 features
# Test MAE: $20
#
# 286 features
# Test MAE: $20
#
# 287 features
# Test MAE: $20
#
# 288 features
# Test MAE: $19
#
# 289 features
# Test MAE: $20
#
# 290 features
# Test MAE: $20
#
# 291 features
# Test MAE: $19
#
# 292 features
# Test MAE: $19
#
# 293 features
# Test MAE: $20
#
# 294 features
# Test MAE: $20
#
# 295 features
# Test MAE: $20
#
# 296 features
# Test MAE: $20
#
# 297 features
# Test MAE: $20
#
# 298 features
# Test MAE: $19
#
# 299 features
# Test MAE: $19
#
# 300 features
# Test MAE: $19
#
# 301 features
# Test MAE: $19
#
# 302 features
# Test MAE: $19
#
# 303 features
# Test MAE: $19
#
# 304 features
# Test MAE: $19
#
# 305 features
# Test MAE: $19
#
# 306 features
# Test MAE: $19
#
# 307 features
# Test MAE: $19
#
# 308 features
# Test MAE: $19
#
# 309 features
# Test MAE: $19
#
# 310 features
# Test MAE: $19
#
# 311 features
# Test MAE: $19
#
# 312 features
# Test MAE: $19
#
# 313 features
# Test MAE: $19
#
# 314 features
# Test MAE: $19
#
# 315 features
# Test MAE: $20
#
# 316 features
# Test MAE: $19
#
# 317 features
# Test MAE: $19
#
# 318 features
# Test MAE: $19
#
# 319 features
# Test MAE: $20
#
# 320 features
# Test MAE: $19
#
# 321 features
# Test MAE: $19
#
# 322 features
# Test MAE: $20
#
# 323 features
# Test MAE: $19
#
# 324 features
# Test MAE: $19
#
# 325 features
# Test MAE: $19
#
# 326 features
# Test MAE: $19
#
# 327 features
# Test MAE: $19
#
# 328 features
# Test MAE: $19
#
# 329 features
# Test MAE: $19
#
# 330 features
# Test MAE: $19
#
# 331 features
# Test MAE: $19
#
# 332 features
# Test MAE: $19
#
# 333 features
# Test MAE: $19

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_train = train['price']
y_val = val['price']
y_pred_train = [y_train.mean()] * len(y_train)
y_pred_val  = [y_train.mean()] * len(y_val)

print('Mean Baseline:')
print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train, y_pred_train)))
print('val Root Mean Square Error:', np.sqrt(mean_squared_error(y_val, y_pred_val)))
print('Train Mean Absolute Error:', mean_absolute_error(y_train, y_pred_train))
print('val Mean Absolute Error:', mean_absolute_error(y_val, y_pred_val))
print('Train R^2 Score:', r2_score(y_train, y_pred_train))
print('val R^2 Score:', r2_score(y_val, y_pred_val))
# Out:
# Mean Baseline:
# Train Root Mean Squared Error: 41.40722877922959
# val Root Mean Square Error: 40.343225227898635
# Train Mean Absolute Error: 32.34957952154805
# val Mean Absolute Error: 32.02194338526833
# Train R^2 Score: -2.220446049250313e-16
# val R^2 Score: -9.672071927324666e-05

# %%
from sklearn.linear_model import LinearRegression

def lr(X_train, X_val, features, target):

    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_val = model.predict(X_val)
    
    print(f'Linear Regression with {len(features)} features')
    print('Intercept', model.intercept_)
    coefficients = pd.Series(model.coef_, features)
    print(coefficients.to_string())
    
    print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train, y_pred_train)))
    print('Val Root Mean Square Error:', np.sqrt(mean_squared_error(y_val, y_pred_val)))
    print('Train Mean Absolute Error:', mean_absolute_error(y_train, y_pred_train))
    print('Val Mean Absolute Error:', mean_absolute_error(y_val, y_pred_val))
    print('Train R^2 Score:', r2_score(y_train, y_pred_train))
    print('Val R^2 Score:', r2_score(y_val, y_pred_val))
    return True

# %%
lr(X_train_encoded, X_test_encoded, features, target)
# Out:
# Linear Regression with 333 features
# Intercept 58.84583440302153
# ean / upc              4.283819e-12
# name_length           -8.918609e-02
# brand                  1.197669e-02
# categories            -9.659811e-01
# manufacturer           3.336746e-01
# prices.availability    7.739912e+00
# prices.currency        1.532305e-03
# prices.offer          -3.148010e-01
# prices.size            1.596253e-02
# Missing               -3.646355e-06
# toe                    6.690324e+00
# ankle                 -7.234353e+00
# heel                  -5.570933e+00
# boot                   1.308354e+01
# boots                 -6.978212e+00
# sandal                -7.237215e+00
# shoes                 -5.232833e+00
# bootie                -3.042060e+00
# strap                  7.489839e+00
# leather                1.998877e+01
# propet                -1.328304e+00
# flats                  4.543256e+00
# black                  6.243183e-01
# high                  -1.184035e-01
# fashion               -1.111632e+01
# women                  1.269959e+01
# open                  -1.050769e+01
# shoe                   8.103964e-01
# pump                  -6.094997e-01
# suede                  1.038512e+01
# sandals                6.497347e+00
# wide                  -2.553002e+00
# lace                   8.258021e+00
# pleaser                4.058480e+00
# up                    -9.409374e+00
# sas,                   8.734823e+01
# trotters               1.090933e+00
# brinley               -1.578270e+01
# faux                  -2.124611e+01
# mary                   1.814903e-01
# slip                  -1.136259e+01
# platform               4.844775e+00
# calf                   3.067696e+01
# ankle-high             2.357252e-01
# flat                  -6.888046e+00
# jane                   8.526590e+00
# pointed               -1.053427e+01
# university             1.638315e+00
# midnight              -2.124520e+01
# black/silver           3.749493e+01
# all                   -1.081157e+01
# plum                   2.251029e+01
# mocha                 -2.946883e+00
# cement                -7.958060e+00
# coffee                 1.931073e+01
# aqua                   2.566463e+01
# veg                   -1.398041e+01
# pu/ballistic           3.051590e+00
# nylon/faux             3.051590e+00
# rubberized             3.051591e+00
# baby                  -1.304855e+01
# dot                    1.194398e+01
# tinted                -5.061205e+00
# sequins/silver         3.648900e+01
# inserts               -4.724802e-01
# periwinkle            -8.592842e+00
# mushroom              -1.909306e+01
# ivory                 -1.380354e+01
# washed                -1.009473e+01
# lime                   1.618475e+01
# multicolor             2.785248e+00
# sueded                -1.508400e+01
# imi                   -3.728669e+01
# croco/smooth           5.453091e+01
# dragon                 2.471502e+00
# whiskey                2.713593e+01
# clear/black           -1.697772e+01
# canyon                 3.689168e+00
# bronze,               -2.145311e+01
# peach                 -8.875772e+00
# box                    3.780461e+00
# synthetic/rubber       3.780461e+00
# lt                    -4.096844e+00
# sport                 -3.356062e+01
# mulberry              -2.291334e+01
# tobacco               -3.074793e+00
# steel                  2.889532e+00
# linen                  2.004236e+01
# sequins/gold           3.485514e+01
# mustard               -2.017719e+01
# rainbow               -6.063967e-01
# sparkle                6.113244e+00
# paris                 -7.205333e+00
# mesh                  -9.769814e+00
# fabric/gore            3.643507e+01
# cherry                -6.672450e+00
# toffee                -1.841416e+01
# silver,                2.792664e+00
# white/navy            -7.694834e+00
# blue/silver            3.705857e+01
# wb2                   -7.901888e+00
# royal                 -6.928115e+00
# knit                   4.062231e+01
# suedette              -2.344921e+01
# bm2                   -1.509336e+01
# patent/black           2.389789e+01
# oyster/gold           -1.733053e+01
# theatrical            -1.121467e+01
# has_description        0.000000e+00
# Train Root Mean Squared Error: 26.580185659130056
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-1ccda25f7202> in <module>
# ----> 1 lr(X_train_encoded, X_test_encoded, features, target)
#
# <ipython-input-38-dbcce80dd1f6> in lr(X_train, X_val, features, target)
#      14
#      15     print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train, y_pred_train)))
# ---> 16     print('Test Root Mean Square Error:', np.sqrt(mean_squared_error(y_val, y_pred_val)))
#      17     print('Train Mean Absolute Error:', mean_absolute_error(y_train, y_pred_train))
#      18     print('Test Mean Absolute Error:', mean_absolute_error(y_val, y_pred_val))
#
# E:\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     239     """
#     240     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 241         y_true, y_pred, multioutput)
#     242     check_consistent_length(y_true, y_pred, sample_weight)
#     243     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# E:\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75
#      76     """
# ---> 77     check_consistent_length(y_true, y_pred)
#      78     y_true = check_array(y_true, ensure_2d=False)
#      79     y_pred = check_array(y_pred, ensure_2d=False)
#
# E:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [1592, 1990]
