# %% [markdown]
# <a href="https://colab.research.google.com/github/Mike-Xie/DS-Unit-2-Applied-Modeling/blob/master/module2/Mike_Xie_assignment_applied_modeling_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 1*
#
# ---
#
#
# # Define ML problems
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your decisions.
#
# - [ ] Choose your target. Which column in your tabular dataset will you predict?
# - [ ] Is your problem regression or classification?
# - [ ] How is your target distributed?
#     - Classification: How many classes? Are the classes imbalanced?
#     - Regression: Is the target right-skewed? If so, you may want to log transform the target.
# - [ ] Choose your evaluation metric(s).
#     - Classification: Is your majority class frequency >= 50% and < 70% ? If so, you can just use accuracy if you want. Outside that range, accuracy could be misleading. What evaluation metric will you choose, in addition to or instead of accuracy?
#     - Regression: Will you use mean absolute error, root mean squared error, R^2, or other regression metrics?
# - [ ] Choose which observations you will use to train, validate, and test your model.
#     - Are some observations outliers? Will you exclude them?
#     - Will you do a random split or a time-based split?
# - [ ] Begin to clean and explore your data.
# - [ ] Begin to choose which features, if any, to exclude. Would some features "leak" future information?
#
# If you haven't found a dataset yet, do that today. [Review requirements for your portfolio project](https://lambdaschool.github.io/ds/unit2) and choose your dataset.

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 2*
#
# ---
#
# # Wrangle ML datasets
#
# - [ ] Continue to clean and explore your data.
# - [ ] For the evaluation metric you chose, what score would you get just by guessing?
# - [ ] Can you make a fast, first model that beats guessing?
#
# **We recommend that you use your portfolio project dataset for all assignments this sprint.**
#
# **But if you aren't ready yet, or you want more practice, then use the New York City property sales dataset for today's assignment.** Follow the instructions below, to just keep a subset for the Tribeca neighborhood, and remove outliers or dirty data. [Here's a video walkthrough](https://youtu.be/pPWFw8UtBVg?t=584) you can refer to if you get stuck or want hints!
#
# - Data Source: [NYC OpenData: NYC Citywide Rolling Calendar Sales](https://data.cityofnewyork.us/dataset/NYC-Citywide-Rolling-Calendar-Sales/usep-8jbt)
# - Glossary: [NYC Department of Finance: Rolling Sales Data](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page)

# %%
# %%capture
import sys

if 'google.colab' in sys.modules:
    # Install packages in Colab
    # !pip install category_encoders==2.*
    # !pip install pandas-profiling==2.*

# %%
# !wget https://github.com/bowswung/voobly-scraper/raw/master/data/MatchData/20190208/matchDump.csv.zip
# Out:
# --2019-12-18 00:00:59--  https://github.com/bowswung/voobly-scraper/raw/master/data/MatchData/20190208/matchDump.csv.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/bowswung/voobly-scraper/master/data/MatchData/20190208/matchDump.csv.zip [following]
# --2019-12-18 00:00:59--  https://media.githubusercontent.com/media/bowswung/voobly-scraper/master/data/MatchData/20190208/matchDump.csv.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49029198 (47M) [application/zip]
# Saving to: ‘matchDump.csv.zip’
#
# matchDump.csv.zip   100%[===================>]  46.76M   108MB/s    in 0.4s
#
# 2019-12-18 00:01:01 (108 MB/s) - ‘matchDump.csv.zip’ saved [49029198/49029198]

# %%
# !unzip matchDump.csv.zip
# Out:
# Archive:  matchDump.csv.zip
#   inflating: matchDump.csv

# %%
# !head matchDump.csv
# Out:
# MatchId,MatchUrl,MatchDate,MatchDuration,MatchLadder,MatchMap,MatchMods,MatchPlayerId,MatchPlayerName,MatchPlayerTeam,MatchPlayerCivId,MatchPlayerCivName,MatchPlayerWinner,MatchPlayerPreRating,MatchPlayerPostRating,MatchPlayerRecording
# 17827685,https://www.voobly.com/match/view/17827685,2018-05-27T18:14:00,520,Match Stats Only,=V= CBA Hero AC V13.scx,v1.5 Beta R6,123972487,___Oreo,1,9,Saracens,1,1584,1600,
# 17827685,https://www.voobly.com/match/view/17827685,2018-05-27T18:14:00,520,Match Stats Only,=V= CBA Hero AC V13.scx,v1.5 Beta R6,125049367,___Dm,2,9,Saracens,0,1616,1600,
# 17827728,https://www.voobly.com/match/view/17827728,2018-05-27T18:21:00,661,Match Stats Only,=V= CBA Hero AC V13.scx,v1.5 Beta R6,123972487,___Oreo,1,13,Celts,1,1584,1600,
# 17827728,https://www.voobly.com/match/view/17827728,2018-05-27T18:21:00,661,Match Stats Only,=V= CBA Hero AC V13.scx,v1.5 Beta R6,125049367,___Dm,2,13,Celts,0,1616,1600,
# 17832641,https://www.voobly.com/match/view/17832641,2018-05-28T11:25:00,762,Match Stats Only,=V= CBA Hero AC V13.scx,v1.5 Beta R6,124815560,SOOR_DARA,1,14,Spanish,1,1584,1600,
# 17832641,https://www.voobly.com/match/view/17832641,2018-05-28T11:25:00,762,Match Stats Only,=V= CBA Hero AC V13.scx,v1.5 Beta R6,124693469,danyal__,2,14,Spanish,0,1616,1600,
# 17839373,https://www.voobly.com/match/view/17839373,2018-05-29T17:04:00,1073,Match Stats Only,=V= TDII TeamBonus v3.scx,"v1.5 Beta R6, TDII TeamBonus",125043437,cRiukc,1,17,Huns,1,1584,1600,
# 17839373,https://www.voobly.com/match/view/17839373,2018-05-29T17:04:00,1073,Match Stats Only,=V= TDII TeamBonus v3.scx,"v1.5 Beta R6, TDII TeamBonus",124157048,_SickBoy,2,16,Mayans,0,1616,1600,
# 17839373,https://www.voobly.com/match/view/17839373,2018-05-29T17:04:00,1073,Match Stats Only,=V= TDII TeamBonus v3.scx,"v1.5 Beta R6, TDII TeamBonus",*VooblyErrorPlayerNotFound*,"<td valign=""bottom"">Atabeg Zangi (Computer)</td>",*VooblyErrorPlayerNotFound*,*VooblyErrorPlayerNotFound*,*VooblyErrorPlayerNotFound*,*VooblyErrorPlayerNotFound*,*VooblyErrorPlayerNotFound*,*VooblyErrorPlayerNotFound*,*VooblyErrorPlayerNotFound*

# %%
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 100

df = pd.read_csv('matchDump.csv', header=0, engine='python')
df.shape
# Out:
# (1263808, 16)

# %%
df.head(30)
# Out:
#      MatchId                                    MatchUrl            MatchDate  \
# 0   17827685  https://www.voobly.com/match/view/17827685  2018-05-27T18:14:00
# 1   17827685  https://www.voobly.com/match/view/17827685  2018-05-27T18:14:00
# 2   17827728  https://www.voobly.com/match/view/17827728  2018-05-27T18:21:00
# 3   17827728  https://www.voobly.com/match/view/17827728  2018-05-27T18:21:00
# 4   17832641  https://www.voobly.com/match/view/17832641  2018-05-28T11:25:00
# 5   17832641  https://www.voobly.com/match/view/17832641  2018-05-28T11:25:00
# 6   17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 7   17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 8   17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 9   17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 10  17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 11  17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 12  17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 13  17839373  https://www.voobly.com/match/view/17839373  2018-05-29T17:04:00
# 14  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 15  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 16  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 17  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 18  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 19  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 20  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 21  17841936  https://www.voobly.com/match/view/17841936  2018-05-30T01:02:00
# 22  17846464  https://www.voobly.com/match/view/17846464  2018-05-30T21:50:00
# 23  17846464  https://www.voobly.com/match/view/17846464  2018-05-30T21:50:00
# 24  17851757  https://www.voobly.com/match/view/17851757  2018-05-31T20:19:00
# 25  17851757  https://www.voobly.com/match/view/17851757  2018-05-31T20:19:00
# 26  17851807  https://www.voobly.com/match/view/17851807  2018-05-31T20:26:00
# 27  17851807  https://www.voobly.com/match/view/17851807  2018-05-31T20:26:00
# 28  17851835  https://www.voobly.com/match/view/17851835  2018-05-31T20:31:00
# 29  17851835  https://www.voobly.com/match/view/17851835  2018-05-31T20:31:00
#
#     MatchDuration       MatchLadder                        MatchMap  \
# 0             520  Match Stats Only         =V= CBA Hero AC V13.scx
# 1             520  Match Stats Only         =V= CBA Hero AC V13.scx
# 2             661  Match Stats Only         =V= CBA Hero AC V13.scx
# 3             661  Match Stats Only         =V= CBA Hero AC V13.scx
# 4             762  Match Stats Only         =V= CBA Hero AC V13.scx
# 5             762  Match Stats Only         =V= CBA Hero AC V13.scx
# 6            1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 7            1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 8            1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 9            1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 10           1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 11           1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 12           1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 13           1073  Match Stats Only       =V= TDII TeamBonus v3.scx
# 14           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 15           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 16           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 17           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 18           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 19           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 20           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 21           5560  Match Stats Only  (IGZ) Ancient TD 21 Kings 1000
# 22           4165  Match Stats Only    =V= Roll The Dice v14.9d.scx
# 23           4165  Match Stats Only    =V= Roll The Dice v14.9d.scx
# 24           1293  Match Stats Only                  =V= CBAv19.scx
# 25           1293  Match Stats Only                  =V= CBAv19.scx
# 26            735  Match Stats Only                  =V= CBAv19.scx
# 27            735  Match Stats Only                  =V= CBAv19.scx
# 28            349  Match Stats Only         =V= RCB 2016 League.scx
# 29            349  Match Stats Only         =V= RCB 2016 League.scx
#
#                         MatchMods                MatchPlayerId  \
# 0                    v1.5 Beta R6                    123972487
# 1                    v1.5 Beta R6                    125049367
# 2                    v1.5 Beta R6                    123972487
# 3                    v1.5 Beta R6                    125049367
# 4                    v1.5 Beta R6                    124815560
# 5                    v1.5 Beta R6                    124693469
# 6    v1.5 Beta R6, TDII TeamBonus                    125043437
# 7    v1.5 Beta R6, TDII TeamBonus                    124157048
# 8    v1.5 Beta R6, TDII TeamBonus  *VooblyErrorPlayerNotFound*
# 9    v1.5 Beta R6, TDII TeamBonus  *VooblyErrorPlayerNotFound*
# 10   v1.5 Beta R6, TDII TeamBonus  *VooblyErrorPlayerNotFound*
# 11   v1.5 Beta R6, TDII TeamBonus  *VooblyErrorPlayerNotFound*
# 12   v1.5 Beta R6, TDII TeamBonus  *VooblyErrorPlayerNotFound*
# 13   v1.5 Beta R6, TDII TeamBonus  *VooblyErrorPlayerNotFound*
# 14                   v1.5 Beta R6                         5855
# 15                   v1.5 Beta R6  *VooblyErrorPlayerNotFound*
# 16                   v1.5 Beta R6  *VooblyErrorPlayerNotFound*
# 17                   v1.5 Beta R6                    123274739
# 18                   v1.5 Beta R6  *VooblyErrorPlayerNotFound*
# 19                   v1.5 Beta R6  *VooblyErrorPlayerNotFound*
# 20                   v1.5 Beta R6  *VooblyErrorPlayerNotFound*
# 21                   v1.5 Beta R6  *VooblyErrorPlayerNotFound*
# 22                   v1.5 Beta R6                    125043437
# 23                   v1.5 Beta R6                    125014674
# 24  v1.5 Beta R6, Advanced Statis                    123376603
# 25  v1.5 Beta R6, Advanced Statis                    125043347
# 26  v1.5 Beta R6, Advanced Statis                    123376603
# 27  v1.5 Beta R6, Advanced Statis                    125043347
# 28     v1.5 Beta R6, RCB Fair Mod                    123376603
# 29     v1.5 Beta R6, RCB Fair Mod                    125043347
#
#                                       MatchPlayerName  \
# 0                                             ___Oreo
# 1                                               ___Dm
# 2                                             ___Oreo
# 3                                               ___Dm
# 4                                           SOOR_DARA
# 5                                            danyal__
# 6                                              cRiukc
# 7                                            _SickBoy
# 8    <td valign="bottom">Atabeg Zangi (Computer)</td>
# 9   <td valign="bottom">Rey Alarico II (Computer)<...
# 10  <td valign="bottom">Rey Leovigildo (Computer)<...
# 11  <td valign="bottom">General Shirkuh (Computer)...
# 12  <td valign="bottom">Dios del Cielo d (Computer...
# 13  <td valign="bottom">Atila el huno (Computer)</td>
# 14                                            _SpiNNa
# 15  <td valign="bottom">Sultan Malik-sha (Computer...
# 16  <td valign="bottom">Charles the Bold (Computer...
# 17                                       Amon__Amarth
# 18                <td valign="bottom">(Computer)</td>
# 19  <td valign="bottom">Bleda the Hun (Computer)</td>
# 20  <td valign="bottom">Flint Sky God (Computer)</td>
# 21  <td valign="bottom">supersmashbroth (Computer)...
# 22                                             cRiukc
# 23                                          Jorgiitho
# 24                                          290Zanchy
# 25                                            Ausaf__
# 26                                          290Zanchy
# 27                                            Ausaf__
# 28                                          290Zanchy
# 29                                            Ausaf__
#
#                 MatchPlayerTeam             MatchPlayerCivId  \
# 0                             1                            9
# 1                             2                            9
# 2                             1                           13
# 3                             2                           13
# 4                             1                           14
# 5                             2                           14
# 6                             1                           17
# 7                             2                           16
# 8   *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 9   *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 10  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 11  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 12  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 13  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 14                            1                            4
# 15  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 16  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 17                            2                            9
# 18  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 19  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 20  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 21  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 22                            1                            7
# 23                            2                           12
# 24                            1                            5
# 25                            2                            5
# 26                            1                           12
# 27                            2                           12
# 28                            1                           13
# 29                            2                           13
#
#              MatchPlayerCivName            MatchPlayerWinner  \
# 0                      Saracens                            1
# 1                      Saracens                            0
# 2                         Celts                            1
# 3                         Celts                            0
# 4                       Spanish                            1
# 5                       Spanish                            0
# 6                          Huns                            1
# 7                        Mayans                            0
# 8   *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 9   *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 10  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 11  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 12  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 13  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 14                      Teutons                            1
# 15  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 16  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 17                     Saracens                            0
# 18  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 19  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 20  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 21  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 22                   Byzantines                            1
# 23                      Mongols                            0
# 24                     Japanese                            1
# 25                     Japanese                            0
# 26                      Mongols                            1
# 27                      Mongols                            0
# 28                        Celts                            1
# 29                        Celts                            0
#
#            MatchPlayerPreRating        MatchPlayerPostRating  \
# 0                          1584                         1600
# 1                          1616                         1600
# 2                          1584                         1600
# 3                          1616                         1600
# 4                          1584                         1600
# 5                          1616                         1600
# 6                          1584                         1600
# 7                          1616                         1600
# 8   *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 9   *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 10  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 11  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 12  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 13  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 14                         1584                         1600
# 15  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 16  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 17                         1616                         1600
# 18  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 19  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 20  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 21  *VooblyErrorPlayerNotFound*  *VooblyErrorPlayerNotFound*
# 22                         1584                         1600
# 23                         1616                         1600
# 24                         1584                         1600
# 25                         1616                         1600
# 26                         1584                         1600
# 27                         1616                         1600
# 28                         1584                         1600
# 29                         1616                         1600
#
#            MatchPlayerRecording
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8   *VooblyErrorPlayerNotFound*
# 9   *VooblyErrorPlayerNotFound*
# 10  *VooblyErrorPlayerNotFound*
# 11  *VooblyErrorPlayerNotFound*
# 12  *VooblyErrorPlayerNotFound*
# 13  *VooblyErrorPlayerNotFound*
# 14                          NaN
# 15  *VooblyErrorPlayerNotFound*
# 16  *VooblyErrorPlayerNotFound*
# 17                          NaN
# 18  *VooblyErrorPlayerNotFound*
# 19  *VooblyErrorPlayerNotFound*
# 20  *VooblyErrorPlayerNotFound*
# 21  *VooblyErrorPlayerNotFound*
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN

# %% [markdown]
# # Choose Target

# %%
# I want to predict which player wins

target = 'MatchPlayerWinner'

# %%
df[target].describe()
# Out:
# count     1263808
# unique          3
# top             0
# freq       647589
# Name: MatchPlayerWinner, dtype: object

# %%
df['MatchLadder'].value_counts()
# Out:
# RM - Team           723786
# RM - 1v1            411718
# Match Stats Only     81083
# DM - Team            40249
# DM - 1v1              6972
# Name: MatchLadder, dtype: int64

# %%
rm_1v1 = df[df['MatchLadder'] == 'RM - 1v1']

rm_1v1.shape
# Out:
# (411718, 16)

# %%
rm_1v1.head()
# Out:
#       MatchId                                    MatchUrl  \
# 728  18658367  https://www.voobly.com/match/view/18658367
# 729  18658367  https://www.voobly.com/match/view/18658367
# 730  18658419  https://www.voobly.com/match/view/18658419
# 731  18658419  https://www.voobly.com/match/view/18658419
# 732  18658476  https://www.voobly.com/match/view/18658476
#
#                MatchDate  MatchDuration MatchLadder MatchMap  \
# 728  2018-10-26T14:19:00           1055    RM - 1v1   Arabia
# 729  2018-10-26T14:19:00           1055    RM - 1v1   Arabia
# 730  2018-10-26T14:38:00           3361    RM - 1v1   Custom
# 731  2018-10-26T14:38:00           3361    RM - 1v1   Custom
# 732  2018-10-26T14:55:00           3369    RM - 1v1    Nomad
#
#                         MatchMods MatchPlayerId MatchPlayerName  \
# 728  v1.5 Beta R7, WololoKingdoms     125152121        Tuborger
# 729  v1.5 Beta R7, WololoKingdoms     125151302       Sarah1409
# 730                        1.4 RC     123628860    PL_Hitorek__
# 731                        1.4 RC     123805002            n30n
# 732  v1.5 Beta R7, WololoKingdoms     123834564          ppwudi
#
#     MatchPlayerTeam MatchPlayerCivId MatchPlayerCivName MatchPlayerWinner  \
# 728               1               16             Mayans                 1
# 729               2               11            Vikings                 0
# 730               1               18            Koreans                 1
# 731               2               17               Huns                 0
# 732               1                6            Chinese                 1
#
#     MatchPlayerPreRating MatchPlayerPostRating MatchPlayerRecording
# 728                 1599                  1615                  NaN
# 729                 1600                  1584                  NaN
# 730                 1629                  1642                  NaN
# 731                 1548                  1535                  NaN
# 732                 1975                  1995                  NaN

# %%
rm_1v1.tail()
# Out:
#           MatchId                                    MatchUrl  \
# 1263771  19250562  https://www.voobly.com/match/view/19250562
# 1263772  19250571  https://www.voobly.com/match/view/19250571
# 1263773  19250571  https://www.voobly.com/match/view/19250571
# 1263774  19250581  https://www.voobly.com/match/view/19250581
# 1263775  19250581  https://www.voobly.com/match/view/19250581
#
#                    MatchDate  MatchDuration MatchLadder MatchMap  \
# 1263771  2019-02-07T19:44:00           4797    RM - 1v1   Arabia
# 1263772  2019-02-07T19:45:00           2501    RM - 1v1   Custom
# 1263773  2019-02-07T19:45:00           2501    RM - 1v1   Custom
# 1263774  2019-02-07T19:47:00           4080    RM - 1v1   Custom
# 1263775  2019-02-07T19:47:00           4080    RM - 1v1   Custom
#
#                             MatchMods MatchPlayerId MatchPlayerName  \
# 1263771  v1.5 Beta R7, WololoKingdoms     123904589       YYY___YYY
# 1263772  v1.5 Beta R7, WololoKingdoms     125198457      killpigboy
# 1263773  v1.5 Beta R7, WololoKingdoms     124772915            BarT
# 1263774  v1.5 Beta R7, WololoKingdoms        156947           Krok_
# 1263775  v1.5 Beta R7, WololoKingdoms     125214232          Thendo
#
#         MatchPlayerTeam MatchPlayerCivId MatchPlayerCivName MatchPlayerWinner  \
# 1263771               2                8           Persians                 0
# 1263772               1               13              Celts                 1
# 1263773               2               12            Mongols                 0
# 1263774               1               24         Portuguese                 1
# 1263775               2               19           Italians                 0
#
#         MatchPlayerPreRating MatchPlayerPostRating  \
# 1263771                 1695                  1678
# 1263772                 1933                  1948
# 1263773                 1909                  1894
# 1263774                 1542                  1555
# 1263775                 1479                  1466
#
#                                       MatchPlayerRecording
# 1263771  https://www.voobly.com/files/view/51848193/82v...
# 1263772  https://www.voobly.com/files/view/51848229/e9x...
# 1263773  https://www.voobly.com/files/view/51848226/2cx...
# 1263774  https://www.voobly.com/files/view/51848307/pva...
# 1263775  https://www.voobly.com/files/view/51848258/uwe...

# %%
y = rm_1v1[target]

y.nunique()
# Out:
# 3

# %%
y.value_counts() # baseline is 50/50 since only P1 or P2 can win a 1v1
# Out:
# 1                              205816
# 0                              205816
# *VooblyErrorPlayerNotFound*        86
# Name: MatchPlayerWinner, dtype: int64

# %%
z = df[target]

z.value_counts()
# Out:
# 0                              647589
# 1                              613547
# *VooblyErrorPlayerNotFound*      2672
# Name: MatchPlayerWinner, dtype: int64

# %%
rm_1v1['MatchPlayerPostRating'].isnull().sum() # ok so we can manually fix the 86 missing ones since winners gain rating and loses lose rating

# do it tomorrow, lazy
# Out:
# 0

# %%
rm_1v1.columns
# Out:
# Index(['MatchId', 'MatchUrl', 'MatchDate', 'MatchDuration', 'MatchLadder',
#        'MatchMap', 'MatchMods', 'MatchPlayerId', 'MatchPlayerName',
#        'MatchPlayerTeam', 'MatchPlayerCivId', 'MatchPlayerCivName',
#        'MatchPlayerWinner', 'MatchPlayerPreRating', 'MatchPlayerPostRating',
#        'MatchPlayerRecording'],
#       dtype='object')

# %%
# so we prob need to drop matchplayerpost rating after using it to fix our empty player error not founds since that leaks
# matchID, matchURL, matchplayerRecording are probably useless
# civname and civID are 1:1, perfectly collinear so need to drop those
# nvm just drop

# %% [markdown]
# # Feature Engineering TO DO LIST

# %%
# do this later to feature engineer relative rating by getting P1 and P2 ratings on same row after merge

evens = df.iloc[list(range(0, len(df), 2))]
odds =  df.iloc[list(range(1, len(df), 2))]

# do a feature of tier list ranking of the user civ

# do some features of if they have good:
# eco, cavalry, archers, seige, etc. using some source somewhere

# %% [markdown]
# # FIT MODEL

# %%
rm_1v1.describe()

from sklearn.model_selection import train_test_split

train, val = train_test_split(rm_1v1, train_size = 0.8, test_size = 0.2)

train.shape, val.shape
# Out:
# ((329374, 16), (82344, 16))

# %%
# run a model better than baseline 
target = 'MatchPlayerWinner'
features = ['MatchDuration', 'MatchDate','MatchMap','MatchMods','MatchPlayerCivId','MatchPlayerPreRating']

# looks sparse need to make a lot of feature engineering later
X_train = train[features]
y_train = train[target]

X_val = val[features]
y_val = val[target]

# %%
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline

# %%
pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    RandomForestClassifier(n_estimators = 100, n_jobs=-1)
)

pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_val)

print('Train Accuracy', pipeline.score(X_train, y_train))

# well, that's, not good
# Out:
# Train Accuracy 0.9998239083837825

# %%
print('Validation Accuracy', pipeline.score(X_val, y_val))

# fail
# Out:
# Validation Accuracy 0.4987612940833576
