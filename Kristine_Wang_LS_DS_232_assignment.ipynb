# %% [markdown]
# <a href="https://colab.research.google.com/github/KristineYW/DS-Unit-2-Applied-Modeling/blob/master/Kristine_Wang_LS_DS_232_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 2*
#
# ---
#
#
# # Wrangle ML datasets
#
# - [ ] Continue to clean and explore your data.
# - [ ] For the evaluation metric you chose, what score would you get just by guessing?
# - [ ] Can you make a fast, first model that beats guessing?
#
# **We recommend that you use your portfolio project dataset for all assignments this sprint.**
#
# **But if you aren't ready yet, or you want more practice, then use the New York City property sales dataset for today's assignment.** Follow the instructions below, to just keep a subset for the Tribeca neighborhood, and remove outliers or dirty data. [Here's a video walkthrough](https://youtu.be/pPWFw8UtBVg?t=584) you can refer to if you get stuck or want hints!
#
# - Data Source: [NYC OpenData: NYC Citywide Rolling Calendar Sales](https://data.cityofnewyork.us/dataset/NYC-Citywide-Rolling-Calendar-Sales/usep-8jbt)
# - Glossary: [NYC Department of Finance: Rolling Sales Data](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page)

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Applied-Modeling/master/data/'
    # !pip install category_encoders==2.*
    # !pip install pandas-profiling==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
# # Read New York City property sales data
# import pandas as pd
# df = pd.read_csv(DATA_PATH+'condos/NYC_Citywide_Rolling_Calendar_Sales.csv')

# %% [markdown]
# Your code starts here:

# %%
# Change column names: replace spaces with underscores

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sc1 = pd.read_csv('https://raw.githubusercontent.com/KristineYW/DS-Unit-2-Applied-Modeling/master/SCDB_2019_01_justiceCentered_LegalProvision_1.csv', encoding = "ISO-8859-1")

sc1.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... Unnamed: 47  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
#
#   Unnamed: 48 Unnamed: 49  Unnamed: 50  Unnamed: 51  Unnamed: 52  Unnamed: 53  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 54  firstAgreement  secondAgreement
# 0          NaN             NaN              NaN
# 1          NaN             NaN              NaN
# 2          NaN             NaN              NaN
# 3          NaN             NaN              NaN
# 4          NaN             NaN              NaN
#
# [5 rows x 57 columns]

# %%
sc2 = pd.read_csv('https://raw.githubusercontent.com/KristineYW/DS-Unit-2-Applied-Modeling/master/SCDB_2019_01_justiceCentered_LegalProvision_2.csv', encoding = "ISO-8859-1")

sc2.head()
# Out:
#    ï»¿certReason  lcDisposition  lcDispositionDirection  declarationUncon  \
# 0           11.0            2.0                     1.0               1.0
# 1           11.0            2.0                     1.0               1.0
# 2           11.0            2.0                     1.0               1.0
# 3           11.0            2.0                     1.0               1.0
# 4           11.0            2.0                     1.0               1.0
#
#    caseDisposition  caseDispositionUnusual  partyWinning  precedentAlteration  \
# 0              3.0                     0.0           1.0                  1.0
# 1              3.0                     0.0           1.0                  1.0
# 2              3.0                     0.0           1.0                  1.0
# 3              3.0                     0.0           1.0                  1.0
# 4              3.0                     0.0           1.0                  1.0
#
#    voteUnclear    issue  ...  majOpinAssigner  splitVote  majVotes  minVotes  \
# 0          0.0  80180.0  ...             78.0          1         8         1
# 1          0.0  80180.0  ...             78.0          1         8         1
# 2          0.0  80180.0  ...             78.0          1         8         1
# 3          0.0  80180.0  ...             78.0          1         8         1
# 4          0.0  80180.0  ...             78.0          1         8         1
#
#    justice   justiceName  vote opinion  direction  majority
# 0       86      HHBurton   2.0     1.0        1.0       1.0
# 1       84     RHJackson   1.0     1.0        2.0       2.0
# 2       81     WODouglas   1.0     1.0        2.0       2.0
# 3       80  FFrankfurter   4.0     2.0        2.0       2.0
# 4       79        SFReed   1.0     1.0        2.0       2.0
#
# [5 rows x 29 columns]

# %%
# Join the two large datasets into one dataframe

sc = pd.concat([sc1,sc2], axis=1)

sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... majOpinAssigner  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
#
#   splitVote majVotes  minVotes  justice   justiceName  vote  opinion  \
# 0         1        8         1       86      HHBurton   2.0      1.0
# 1         1        8         1       84     RHJackson   1.0      1.0
# 2         1        8         1       81     WODouglas   1.0      1.0
# 3         1        8         1       80  FFrankfurter   4.0      2.0
# 4         1        8         1       79        SFReed   1.0      1.0
#
#    direction  majority
# 0        1.0       1.0
# 1        2.0       2.0
# 2        2.0       2.0
# 3        2.0       2.0
# 4        2.0       2.0
#
# [5 rows x 86 columns]

# %%
sc = sc.drop(['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 
              'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 
              'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 
              'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 
              'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 
              'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54'], axis=1)

sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... majOpinAssigner  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
#
#   splitVote majVotes  minVotes  justice   justiceName  vote  opinion  \
# 0         1        8         1       86      HHBurton   2.0      1.0
# 1         1        8         1       84     RHJackson   1.0      1.0
# 2         1        8         1       81     WODouglas   1.0      1.0
# 3         1        8         1       80  FFrankfurter   4.0      2.0
# 4         1        8         1       79        SFReed   1.0      1.0
#
#    direction  majority
# 0        1.0       1.0
# 1        2.0       2.0
# 2        2.0       2.0
# 3        2.0       2.0
# 4        2.0       2.0
#
# [5 rows x 57 columns]

# %%
import datetime

# %%
sc['dateDecision'][7]
# Out:
# '11/18/46'

# %%
sc.sample(10)
# Out:
#           caseId     docketId                voteId dateDecision  \
# 86592   1988-030  1988-030-02  1988-030-02-01-01-05      2/21/89
# 96858   1994-080  1994-080-01  1994-080-01-01-01-07      6/19/95
# 118479  2016-027  2016-027-01  2016-027-01-01-01-06      3/28/17
# 26080   1960-125  1960-125-02  1960-125-02-01-01-05      6/12/61
# 47416   1971-027  1971-027-01  1971-027-01-01-01-02     12/20/71
# 86102   1987-154  1987-154-01  1987-154-01-01-01-01      6/29/88
# 70322   1981-022  1981-022-01  1981-022-01-02-01-08      1/11/82
# 79546   1985-023  1985-023-01  1985-023-01-01-01-07      1/21/86
# 29163   1962-079  1962-079-01  1962-079-01-01-01-07      4/22/63
# 23480   1959-072  1959-072-01  1959-072-01-01-01-06       5/2/60
#
#         decisionType            ledCite  term  naturalCourt      chief  \
# 86592              1   103 L. Ed. 2d 34  1988          1603  Rehnquist
# 96858              1  132 L. Ed. 2d 418  1994          1607  Rehnquist
# 118479             1  197 L. Ed. 2d 416  2016          1705    Roberts
# 26080              1    6 L. Ed. 2d 924  1960          1406     Warren
# 47416              1   30 L. Ed. 2d 438  1971          1503     Burger
# 86102              1  101 L. Ed. 2d 749  1987          1603  Rehnquist
# 70322              2   70 L. Ed. 2d 570  1981          1507     Burger
# 79546              1   88 L. Ed. 2d 640  1985          1507     Burger
# 29163              1    10 L. Ed. 2d 84  1962          1408     Warren
# 23480              1    4 L. Ed. 2d 880  1959          1406     Warren
#
#          docket  ... majOpinAssigner splitVote majVotes  minVotes  justice  \
# 86592    87-614  ...           102.0         1        5         4      100
# 96858   93-1911  ...           102.0         1        5         4      108
# 118479   15-797  ...           106.0         1        5         3      112
# 26080       454  ...            90.0         1        7         2       92
# 47416     70-96  ...            99.0         1        6         1       94
# 86102    87-712  ...            92.0         1        6         3       98
# 70322    81-255  ...            99.0         1        9         0      103
# 79546   84-1361  ...            99.0         1        5         4      102
# 29163       146  ...            90.0         1        9         0       90
# 23480        62  ...            90.0         1        9         0       90
#
#         justiceName  vote  opinion  direction  majority
# 86592    HABlackmun   3.0      2.0        1.0       2.0
# 96858       CThomas   1.0      1.0        1.0       2.0
# 118479      SAAlito   2.0      1.0        1.0       1.0
# 26080     WJBrennan   1.0      2.0        1.0       2.0
# 47416      PStewart   1.0      1.0        1.0       2.0
# 86102     TMarshall   1.0      1.0        2.0       2.0
# 70322     JPStevens   1.0      1.0        1.0       2.0
# 79546   WHRehnquist   1.0      1.0        1.0       2.0
# 29163       EWarren   1.0      1.0        1.0       2.0
# 23480       EWarren   1.0      1.0        2.0       2.0
#
# [10 rows x 57 columns]

# %%
# Change dateDecision to datetime data type 


def yearConvert(date):
    year_int = int(date[-2:])
    if year_int > 20:
        edited_str = date[:-2] + '19' + date[-2:]
    else:
        edited_str = date[:-2] + '20' + date[-2:]
    return(pd.to_datetime(edited_str))
sc['dateDecision'] = [yearConvert(i) for i in sc['dateDecision']]
sc['dateDecision'].describe
# Out:
# <bound method NDFrame.describe of 0        1946-11-18
# 1        1946-11-18
# 2        1946-11-18
# 3        1946-11-18
# 4        1946-11-18
#             ...
# 120553   2019-05-28
# 120554   2019-05-28
# 120555   2019-05-28
# 120556   2019-05-28
# 120557   2019-05-28
# Name: dateDecision, Length: 120558, dtype: datetime64[ns]>

# %%
# Introduce new features for senate majority party and presidential party

# sc['partyOfPresident'] = sc['dateDecision'].apply(lambda x: 'Democratic' if (('1953-01-19' < x) | 
#                                                                             ('1961-01-20' < x < '1969-01-19') |
#                                                                             ('1977-01-20' < x < '1981-01-19') |
#                                                                             ('1993-01-20' < x < '2001-01-19') |
#                                                                             ('2009-01-20' < x < '2017-01-20')
#                                                                             else 'Republican')

# sc.loc[(sc['dateDecision'] < '1953-01-19') | ('1961-01-20' < sc['dateDecision'] < '1969-01-19') | 
#        ('1977-01-20' < sc['dateDecision'] < '1981-01-19') | ('1993-01-20' < sc['dateDecision'] < '2001-01-19') |
#        ('2009-01-20' < sc['dateDecision'] < '2017-01-20'), 'partyOfPresident'] = 'Democratic'


sc['partyOfPresident'] = np.where((sc['dateDecision'] < '1953-01-19') | ('1961-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '1969-01-19') | 
                                  ('1977-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '1981-01-19') | 
                                  ('1993-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '2001-01-19') | 
                                  ('2009-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '2017-01-20'), 
                                  'Democratic','Republican')

# %%
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  ... splitVote majVotes  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...         1        8
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...         1        8
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...         1        8
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...         1        8
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...         1        8
#
#   minVotes  justice   justiceName  vote  opinion  direction  majority  \
# 0        1       86      HHBurton   2.0      1.0        1.0       1.0
# 1        1       84     RHJackson   1.0      1.0        2.0       2.0
# 2        1       81     WODouglas   1.0      1.0        2.0       2.0
# 3        1       80  FFrankfurter   4.0      2.0        2.0       2.0
# 4        1       79        SFReed   1.0      1.0        2.0       2.0
#
#    partyOfPresident
# 0        Democratic
# 1        Democratic
# 2        Democratic
# 3        Democratic
# 4        Democratic
#
# [5 rows x 58 columns]

# %%
sc['partyOfPresident'].value_counts(normalize=True)
# Out:
# Republican    0.551909
# Democratic    0.448091
# Name: partyOfPresident, dtype: float64

# %%
sc['partyOfSenate'] = np.where((sc['dateDecision'] < '1947-01-03') | ('1949-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1953-01-02') | 
                                  ('1955-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1981-01-02') | 
                                  ('1987-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1995-01-02') |
                                  ('2001-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '2002-11-11') | 
                                  ('2007-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '2017-01-02'),
                                  'Democratic','Republican')

sc['partyOfSenate'].value_counts(normalize=True)
# Out:
# Democratic    0.712404
# Republican    0.287596
# Name: partyOfSenate, dtype: float64

# %%
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  ... majVotes minVotes  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
#
#   justice   justiceName  vote  opinion  direction  majority  partyOfPresident  \
# 0      86      HHBurton   2.0      1.0        1.0       1.0        Democratic
# 1      84     RHJackson   1.0      1.0        2.0       2.0        Democratic
# 2      81     WODouglas   1.0      1.0        2.0       2.0        Democratic
# 3      80  FFrankfurter   4.0      2.0        2.0       2.0        Democratic
# 4      79        SFReed   1.0      1.0        2.0       2.0        Democratic
#
#    partyOfSenate
# 0     Democratic
# 1     Democratic
# 2     Democratic
# 3     Democratic
# 4     Democratic
#
# [5 rows x 59 columns]

# %%
pd.set_option('display.max_columns',100)
    
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24
# 1  91 L. Ed. 3  1946          1301  Vinson     24
# 2  91 L. Ed. 3  1946          1301  Vinson     24
# 3  91 L. Ed. 3  1946          1301  Vinson     24
# 4  91 L. Ed. 3  1946          1301  Vinson     24
#
#                                             caseName dateArgument dateRearg  \
# 0  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 1  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 2  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 3  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 4  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
#
#    petitioner  petitionerState  respondent  respondentState  jurisdiction  \
# 0       198.0              NaN       172.0              NaN             6
# 1       198.0              NaN       172.0              NaN             6
# 2       198.0              NaN       172.0              NaN             6
# 3       198.0              NaN       172.0              NaN             6
# 4       198.0              NaN       172.0              NaN             6
#
#    adminAction  adminActionState  threeJudgeFdc  caseOrigin  caseOriginState  \
# 0          NaN               NaN            0.0        51.0              6.0
# 1          NaN               NaN            0.0        51.0              6.0
# 2          NaN               NaN            0.0        51.0              6.0
# 3          NaN               NaN            0.0        51.0              6.0
# 4          NaN               NaN            0.0        51.0              6.0
#
#    caseSource  caseSourceState  lcDisagreement  firstAgreement  \
# 0        29.0              NaN             0.0             NaN
# 1        29.0              NaN             0.0             NaN
# 2        29.0              NaN             0.0             NaN
# 3        29.0              NaN             0.0             NaN
# 4        29.0              NaN             0.0             NaN
#
#    secondAgreement  ï»¿certReason  lcDisposition  lcDispositionDirection  \
# 0              NaN           11.0            2.0                     1.0
# 1              NaN           11.0            2.0                     1.0
# 2              NaN           11.0            2.0                     1.0
# 3              NaN           11.0            2.0                     1.0
# 4              NaN           11.0            2.0                     1.0
#
#    declarationUncon  caseDisposition  caseDispositionUnusual  partyWinning  \
# 0               1.0              3.0                     0.0           1.0
# 1               1.0              3.0                     0.0           1.0
# 2               1.0              3.0                     0.0           1.0
# 3               1.0              3.0                     0.0           1.0
# 4               1.0              3.0                     0.0           1.0
#
#    precedentAlteration  voteUnclear    issue  issueArea  decisionDirection  \
# 0                  1.0          0.0  80180.0        8.0                2.0
# 1                  1.0          0.0  80180.0        8.0                2.0
# 2                  1.0          0.0  80180.0        8.0                2.0
# 3                  1.0          0.0  80180.0        8.0                2.0
# 4                  1.0          0.0  80180.0        8.0                2.0
#
#    decisionDirectionDissent  authorityDecision1  authorityDecision2  lawType  \
# 0                       0.0                 4.0                 NaN      6.0
# 1                       0.0                 4.0                 NaN      6.0
# 2                       0.0                 4.0                 NaN      6.0
# 3                       0.0                 4.0                 NaN      6.0
# 4                       0.0                 4.0                 NaN      6.0
#
#    lawSupp         lawMinor  majOpinWriter  majOpinAssigner  splitVote  \
# 0    600.0  35 U.S.C. Ã 33           78.0             78.0          1
# 1    600.0  35 U.S.C. Ã 33           78.0             78.0          1
# 2    600.0  35 U.S.C. Ã 33           78.0             78.0          1
# 3    600.0  35 U.S.C. Ã 33           78.0             78.0          1
# 4    600.0  35 U.S.C. Ã 33           78.0             78.0          1
#
#    majVotes  minVotes  justice   justiceName  vote  opinion  direction  \
# 0         8         1       86      HHBurton   2.0      1.0        1.0
# 1         8         1       84     RHJackson   1.0      1.0        2.0
# 2         8         1       81     WODouglas   1.0      1.0        2.0
# 3         8         1       80  FFrankfurter   4.0      2.0        2.0
# 4         8         1       79        SFReed   1.0      1.0        2.0
#
#    majority partyOfPresident partyOfSenate
# 0       1.0       Democratic    Democratic
# 1       2.0       Democratic    Democratic
# 2       2.0       Democratic    Democratic
# 3       2.0       Democratic    Democratic
# 4       2.0       Democratic    Democratic

# %%
# Retrain features to be categorical for OneHotEncoding

all_columns = list(sc)
sc[all_columns] = sc[all_columns].astype(str)

# %%
sc.isnull().sum()
# Out:
# caseId                      0
# docketId                    0
# voteId                      0
# dateDecision                0
# decisionType                0
# ledCite                     0
# term                        0
# naturalCourt                0
# chief                       0
# docket                      0
# caseName                    0
# dateArgument                0
# dateRearg                   0
# petitioner                  0
# petitionerState             0
# respondent                  0
# respondentState             0
# jurisdiction                0
# adminAction                 0
# adminActionState            0
# threeJudgeFdc               0
# caseOrigin                  0
# caseOriginState             0
# caseSource                  0
# caseSourceState             0
# lcDisagreement              0
# firstAgreement              0
# secondAgreement             0
# ï»¿certReason               0
# lcDisposition               0
# lcDispositionDirection      0
# declarationUncon            0
# caseDisposition             0
# caseDispositionUnusual      0
# partyWinning                0
# precedentAlteration         0
# voteUnclear                 0
# issue                       0
# issueArea                   0
# decisionDirection           0
# decisionDirectionDissent    0
# authorityDecision1          0
# authorityDecision2          0
# lawType                     0
# lawSupp                     0
# lawMinor                    0
# majOpinWriter               0
# majOpinAssigner             0
# splitVote                   0
# majVotes                    0
# minVotes                    0
# justice                     0
# justiceName                 0
# vote                        0
# opinion                     0
# direction                   0
# majority                    0
# partyOfPresident            0
# partyOfSenate               0
# dtype: int64

# %%
sc = sc.fillna(0)

# %%
sc.shape
# Out:
# (120558, 59)

# %%
# Split the dataframe into train and test sets 

from sklearn.model_selection import train_test_split

train, test = train_test_split(sc, train_size=0.9, test_size=0.10, 
                              stratify=sc['decisionDirection'], random_state=42)

# %%
train, val = train_test_split(train, train_size=0.85, test_size=0.15, 
                              stratify=train['decisionDirection'], random_state=42)

# %%
train.shape, val.shape, test.shape
# Out:
# ((92226, 59), (16276, 59), (12056, 59))

# %%
# Define target feature

target = 'decisionDirection'

X_train = train.drop(columns=target)
y_train = train[target]
X_val = val.drop(columns=target)
y_val = val[target]
X_test = test

# %%
import numpy as np
import category_encoders as ce
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

# %%
def encoder(df):
  target = 'status_group'
  if target in df.columns:
    df_features = df.drop(columns=[target])
  else:
    df_features = df
  numeric_features = df_features.select_dtypes(include='number')
  categorical = df_features.select_dtypes(exclude='number').nunique()
  cat_features = categorical[categorical <=50].index.tolist()
  high_cardinality_features = pd.DataFrame(categorical[categorical > 50])
  df_high = df[high_cardinality_features.T.columns]
  one_hot_encode = ce.OneHotEncoder(use_cat_names=True)
  one_hot_encode.fit(df[cat_features])
  low_cardinality_features = one_hot_encode.transform(df[cat_features])
  df1 = numeric_features.join(low_cardinality_features, how='outer')
  df2 = df1.join(df_high, how='outer')


  return df2

# %%
X_train = encoder(train)

X_train.head()
# Out:
#         decisionType_1  decisionType_6  decisionType_2  decisionType_7  \
# 114629               1               0               0               0
# 81122                1               0               0               0
# 13365                0               1               0               0
# 94308                1               0               0               0
# 41384                0               0               1               0
#
#         decisionType_5  decisionType_4  naturalCourt_1704  naturalCourt_1507  \
# 114629               0               0                  1                  0
# 81122                0               0                  0                  1
# 13365                0               0                  0                  0
# 94308                0               0                  0                  0
# 41384                0               0                  0                  0
#
#         naturalCourt_1401  naturalCourt_1605  naturalCourt_1410  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   1                  0                  0
# 94308                   0                  1                  0
# 41384                   0                  0                  1
#
#         naturalCourt_1504  naturalCourt_1607  naturalCourt_1506  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1601  naturalCourt_1303  naturalCourt_1706  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1409  naturalCourt_1406  naturalCourt_1702  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1603  naturalCourt_1502  naturalCourt_1703  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1403  naturalCourt_1301  naturalCourt_1405  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1408  naturalCourt_1606  naturalCourt_1404  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1501  naturalCourt_1604  naturalCourt_1705  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1411  naturalCourt_1407  naturalCourt_1707  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1701  naturalCourt_1602  naturalCourt_1402  \
# 114629                  0                  0                  0
# 81122                   0                  0                  0
# 13365                   0                  0                  0
# 94308                   0                  0                  0
# 41384                   0                  0                  0
#
#         naturalCourt_1503  naturalCourt_1505  chief_Roberts  chief_Burger  \
# 114629                  0                  0              1             0
# 81122                   0                  0              0             1
# 13365                   0                  0              0             0
# 94308                   0                  0              0             0
# 41384                   0                  0              0             0
#
#         chief_Warren  chief_Rehnquist  chief_Vinson  jurisdiction_1  \
# 114629             0                0             0               1
# 81122              0                0             0               0
# 13365              1                0             0               1
# 94308              0                1             0               1
# 41384              1                0             0               1
#
#         jurisdiction_2  jurisdiction_5  jurisdiction_9  jurisdiction_4  ...  \
# 114629               0               0               0               0  ...
# 81122                1               0               0               0  ...
# 13365                0               0               0               0  ...
# 94308                0               0               0               0  ...
# 41384                0               0               0               0  ...
#
#         justiceName_BMKavanaugh  justiceName_RHJackson  justiceName_FMurphy  \
# 114629                        0                      0                    0
# 81122                         0                      0                    0
# 13365                         0                      0                    0
# 94308                         0                      0                    0
# 41384                         0                      0                    0
#
#         justiceName_JGRoberts  vote_1.0  vote_3.0  vote_2.0  vote_4.0  \
# 114629                      0         1         0         0         0
# 81122                       0         0         1         0         0
# 13365                       0         0         0         1         0
# 94308                       0         1         0         0         0
# 41384                       0         1         0         0         0
#
#         vote_8.0  vote_nan  vote_7.0  vote_5.0  vote_6.0  opinion_1.0  \
# 114629         0         0         0         0         0            1
# 81122          0         0         0         0         0            1
# 13365          0         0         0         0         0            1
# 94308          0         0         0         0         0            1
# 41384          0         0         0         0         0            1
#
#         opinion_2.0  opinion_nan  opinion_3.0  direction_2.0  direction_1.0  \
# 114629            0            0            0              1              0
# 81122             0            0            0              0              1
# 13365             0            0            0              1              0
# 94308             0            0            0              1              0
# 41384             0            0            0              1              0
#
#         direction_nan  majority_2.0  majority_1.0  majority_nan  \
# 114629              0             1             0             0
# 81122               0             1             0             0
# 13365               0             0             1             0
# 94308               0             1             0             0
# 41384               0             1             0             0
#
#         partyOfPresident_Democratic  partyOfPresident_Republican  \
# 114629                            1                            0
# 81122                             0                            1
# 13365                             0                            1
# 94308                             1                            0
# 41384                             1                            0
#
#         partyOfSenate_Democratic  partyOfSenate_Republican    caseId  \
# 114629                         1                         0  2011-051
# 81122                          0                         1  1985-143
# 13365                          0                         1  1953-029
# 94308                          1                         0  1992-086
# 41384                          1                         0  1968-002
#
#            docketId                voteId  dateDecision            ledCite  \
# 114629  2011-051-01  2011-051-01-01-01-09    2012-04-24  182 L. Ed. 2d 733
# 81122   1985-143-01  1985-143-01-01-01-08    1986-06-30    92 L. Ed. 2d 85
# 13365   1953-029-01  1953-029-01-01-01-02    1953-12-07   98 L. Ed. 2d 405
# 94308   1992-086-01  1992-086-01-01-01-03    1993-06-07  124 L. Ed. 2d 352
# 41384   1968-002-01  1968-002-01-01-01-07    1968-10-14     21 L. Ed. 2d 5
#
#         term   docket                                           caseName  \
# 114629  2011   Oct-95  PATRICK WOOD, PETITIONER v. KEVIN MILYARD, WAR...
# 81122   1985  84-1244                    DAVIS et al. v. BANDEMER et al.
# 13365   1953      241  TOM WE SHUNG v. BROWNELL, ATTORNEY GENERAL, et...
# 94308   1992  91-2024  LAMB'S CHAPEL AND JOHN STEIGERWALD v. CENTER M...
# 41384   1968    187 M                         ARSENAULT v. MASSACHUSETTS
#
#         dateArgument  dateRearg  petitioner  petitionerState  respondent  \
# 114629       2/27/12        nan       215.0              nan        28.0
# 81122        10/7/85        nan        28.0             18.0       211.0
# 13365        12/3/53        nan       106.0              nan         1.0
# 94308        2/24/93        nan       130.0              nan        21.0
# 41384            nan        nan       126.0              nan        28.0
#
#         respondentState  adminAction  adminActionState  caseOrigin  \
# 114629              7.0          nan               nan        52.0
# 81122               nan          nan               nan        69.0
# 13365               nan          nan               nan        55.0
# 94308              37.0          nan               nan        94.0
# 41384              26.0          nan               nan       302.0
#
#         caseOriginState  caseSource  caseSourceState    issue  lawSupp  \
# 114629              nan        30.0              nan  10020.0    341.0
# 81122               nan        69.0              nan  20090.0    231.0
# 13365               nan        32.0              nan  20110.0      nan
# 94308               nan        22.0              nan  30160.0    200.0
# 41384              26.0       300.0             26.0  10040.0    214.0
#
#         lawMinor
# 114629       nan
# 81122        nan
# 13365        nan
# 94308        nan
# 41384        nan
#
# [5 rows x 445 columns]

# %%
X_val = encoder(val)

X_val.head()
# Out:
#        decisionType_1  decisionType_5  decisionType_2  decisionType_6  \
# 50988               1               0               0               0
# 81281               1               0               0               0
# 25572               1               0               0               0
# 67211               1               0               0               0
# 83356               1               0               0               0
#
#        decisionType_7  decisionType_4  naturalCourt_1504  naturalCourt_1507  \
# 50988               0               0                  1                  0
# 81281               0               0                  0                  1
# 25572               0               0                  0                  0
# 67211               0               0                  0                  0
# 83356               0               0                  0                  0
#
#        naturalCourt_1406  naturalCourt_1506  naturalCourt_1601  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  1                  0                  0
# 67211                  0                  1                  0
# 83356                  0                  0                  1
#
#        naturalCourt_1607  naturalCourt_1501  naturalCourt_1405  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1409  naturalCourt_1407  naturalCourt_1702  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1605  naturalCourt_1502  naturalCourt_1603  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1303  naturalCourt_1701  naturalCourt_1410  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1401  naturalCourt_1301  naturalCourt_1403  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1408  naturalCourt_1706  naturalCourt_1606  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1604  naturalCourt_1402  naturalCourt_1707  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1704  naturalCourt_1404  naturalCourt_1505  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1411  naturalCourt_1602  naturalCourt_1705  \
# 50988                  0                  0                  0
# 81281                  0                  0                  0
# 25572                  0                  0                  0
# 67211                  0                  0                  0
# 83356                  0                  0                  0
#
#        naturalCourt_1703  naturalCourt_1503  chief_Burger  chief_Warren  \
# 50988                  0                  0             1             0
# 81281                  0                  0             1             0
# 25572                  0                  0             0             1
# 67211                  0                  0             1             0
# 83356                  0                  0             0             0
#
#        chief_Rehnquist  chief_Roberts  chief_Vinson  jurisdiction_1  \
# 50988                0              0             0               1
# 81281                0              0             0               1
# 25572                0              0             0               1
# 67211                0              0             0               1
# 83356                1              0             0               1
#
#        jurisdiction_2  jurisdiction_8  jurisdiction_5  jurisdiction_9  ...  \
# 50988               0               0               0               0  ...
# 81281               0               0               0               0  ...
# 25572               0               0               0               0  ...
# 67211               0               0               0               0  ...
# 83356               0               0               0               0  ...
#
#        justiceName_FMVinson  justiceName_FMurphy  justiceName_EKagan  \
# 50988                     0                    0                   0
# 81281                     0                    0                   0
# 25572                     0                    0                   0
# 67211                     0                    0                   0
# 83356                     0                    0                   0
#
#        justiceName_JGRoberts  vote_1.0  vote_2.0  vote_8.0  vote_3.0  \
# 50988                      0         1         0         0         0
# 81281                      0         0         1         0         0
# 25572                      0         1         0         0         0
# 67211                      0         1         0         0         0
# 83356                      0         1         0         0         0
#
#        vote_4.0  vote_nan  vote_7.0  vote_6.0  vote_5.0  opinion_1.0  \
# 50988         0         0         0         0         0            1
# 81281         0         0         0         0         0            1
# 25572         0         0         0         0         0            1
# 67211         0         0         0         0         0            0
# 83356         0         0         0         0         0            1
#
#        opinion_2.0  opinion_nan  opinion_3.0  direction_1.0  direction_2.0  \
# 50988            0            0            0              1              0
# 81281            0            0            0              0              1
# 25572            0            0            0              0              1
# 67211            1            0            0              1              0
# 83356            0            0            0              1              0
#
#        direction_nan  majority_2.0  majority_1.0  majority_nan  \
# 50988              0             1             0             0
# 81281              0             0             1             0
# 25572              0             1             0             0
# 67211              0             1             0             0
# 83356              0             1             0             0
#
#        partyOfPresident_Republican  partyOfPresident_Democratic  \
# 50988                            1                            0
# 81281                            1                            0
# 25572                            0                            1
# 67211                            0                            1
# 83356                            1                            0
#
#        partyOfSenate_Democratic  partyOfSenate_Republican    caseId  \
# 50988                         1                         0  1972-125
# 81281                         0                         1  1985-151
# 25572                         1                         0  1960-095
# 67211                         1                         0  1979-125
# 83356                         1                         0  1986-122
#
#           docketId                voteId  dateDecision           ledCite  \
# 50988  1972-125-04  1972-125-04-01-01-09    1973-05-29  36 L. Ed. 2d 772
# 81281  1985-151-01  1985-151-01-01-01-05    1986-07-01  92 L. Ed. 2d 296
# 25572  1960-095-01  1960-095-01-01-01-01    1961-05-22   6 L. Ed. 2d 306
# 67211  1979-125-01  1979-125-01-01-01-02    1980-06-20  65 L. Ed. 2d 289
# 83356  1986-122-01  1986-122-01-01-01-01    1987-06-09  96 L. Ed. 2d 332
#
#        term   docket                                           caseName  \
# 50988  1972   71-866  AMERICAN BROADCASTING COS., INC. v. DEMOCRATIC...
# 81281  1985  85-5404                                  ALLEN v. ILLINOIS
# 25572  1960      376         COMMISSIONER OF INTERNAL REVENUE v. LESTER
# 67211  1979  79-1082  NATIONAL LABOR RELATIONS BOARD v. INTERNATIONA...
# 83356  1986   86-381  CALIFORNIA v. SUPERIOR COURT OF CALIFORNIA, SA...
#
#        dateArgument  dateRearg  petitioner  petitionerState  respondent  \
# 50988      10/16/72        nan       191.0              nan       211.0
# 81281       4/30/86        nan       136.0              nan        28.0
# 25572       4/25/61        nan       369.0              nan       240.0
# 67211       4/22/80        nan       382.0              nan       249.0
# 83356       4/22/87        nan        28.0              6.0         6.0
#
#        respondentState  adminAction  adminActionState  caseOrigin  \
# 50988              nan         38.0               nan        32.0
# 81281             17.0          nan               nan       302.0
# 25572              nan         69.0               nan         9.0
# 67211              nan         82.0               nan        32.0
# 83356              6.0          nan               nan       302.0
#
#        caseOriginState  caseSource  caseSourceState     issue  lawSupp  \
# 50988              nan        32.0              nan   30010.0    200.0
# 81281             17.0       300.0             17.0   10090.0    210.0
# 25572              nan        22.0              nan  120020.0    345.0
# 67211              nan        32.0              nan   70020.0    356.0
# 83356              6.0       300.0              6.0   10320.0    600.0
#
#                 lawMinor
# 50988                nan
# 81281                nan
# 25572                nan
# 67211                nan
# 83356  18 U.S.C. Ã 3182
#
# [5 rows x 433 columns]

# %%
X_train.shape
# Out:
# (92226, 445)

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
print('Validation Accuracy', pipeline.score(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-9082b6e3b5d3> in <module>
#      13 # Fit on train, score on val
#      14 pipeline.fit(X_train, y_train)
# ---> 15 print('Validation Accuracy', pipeline.score(X_val, y_val))
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in score(self, X, y, sample_weight)
#     613         Xt = X
#     614         for _, name, transform in self._iter(with_final=False):
# --> 615             Xt = transform.transform(Xt)
#     616         score_params = {}
#     617         if sample_weight is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/category_encoders/ordinal.py in transform(self, X, override_return_df)
#     196         # then make sure that it is the right size
#     197         if X.shape[1] != self._dim:
# --> 198             raise ValueError('Unexpected input dimension %d, expected %d' % (X.shape[1], self._dim,))
#     199
#     200         if not list(self.cols):
#
# ValueError: Unexpected input dimension 433, expected 445

# %%
X_val.shape

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
print('Validation Accuracy', pipeline.score(X_val, y_val)) 
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
print('Validation Accuracy', pipeline.score(X_val, y_val))

# %%
# Get Pandas Profiling Report

# !pip install pandas-profiling==2.*

# %%
# Write a function to add column with party in power information

# %%
# # Check out the profile 

# from pandas_profiling import ProfileReport

# profile = ProfileReport(sc)

# profile.to_file(output_file='output.html')

# %%
# from google.colab import files
# files.download('output.html')

# %%
# Keep just the subset of data for the Tribeca neighborhood
# Check how many rows you have now. (Should go down from > 20k rows to 146)

# %%
# Q. What's the date range of these property sales in Tribeca?

# %%
# The Pandas Profiling Report showed that SALE_PRICE was read as strings
# Convert it to integers

# %%
# Q. What is the maximum SALE_PRICE in this dataset?

# %%
# Look at the row with the max SALE_PRICE

# %%
# Get value counts of TOTAL_UNITS
# Q. How many property sales were for multiple units?

# %%
# Keep only the single units

# %%
# Q. Now what is the max sales price? How many square feet does it have?

# %%
# Q. How often did $0 sales occur in this subset of the data?

# There's a glossary here: 
# https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page

# It says:
# A $0 sale indicates that there was a transfer of ownership without a 
# cash consideration. There can be a number of reasons for a $0 sale including 
# transfers of ownership from parents to children.

# %%
# Look at property sales for > 5,000 square feet
# Q. What is the highest square footage you see?

# %%
# What are the building class categories?
# How frequently does each occur?

# %%
# Keep subset of rows:
# Sale price more than $0, 
# Building class category = Condos - Elevator Apartments

# Check how many rows you have now. (Should be 106 rows.)

# %%
# Make a Plotly Express scatter plot of GROSS_SQUARE_FEET vs SALE_PRICE

# %%
# Add an OLS (Ordinary Least Squares) trendline,
# to see how the outliers influence the "line of best fit"

# %%
# Look at sales for more than $35 million

# All are at 70 Vestry Street
# All but one have the same SALE_PRICE & SALE_DATE
# Was the SALE_PRICE for each? Or in total?
# Is this dirty data?

# %%
# Make a judgment call:
# Keep rows where sale price was < $35 million

# Check how many rows you have now. (Should be down to 90 rows.)

# %%
# Now that you've removed outliers,
# Look again at a scatter plot with OLS (Ordinary Least Squares) trendline

# %%
# Select these columns, then write to a csv file named tribeca.csv. Don't include the index.
